# %%
from climada.engine import Impact

# %%
import itertools
from climada.engine import Impact

country = 'global'
warming_levels = ['1', '2']
dir_impacts = {}
dir_impacts['pop'] = '/Users/szelie/OneDrive - ETH Zurich/data/impacts_multi_risk/results3/compound/'
dir_impacts['assets'] = '/Users/szelie/OneDrive - ETH Zurich/data/impacts_multi_risk/results3/compound/'
    
exposures = ['assets', 'pop']
hazards = ['TC', 'RF']
combinations = list(itertools.combinations(hazards, 2))

impact_combined_ordered = {warming: {exposure: {combi: 
                   Impact.from_csv(
                       "".join([dir_impacts[exposure], exposure,"_combined_impact_ordered_","_".join(combi), "_150arcsec_", warming, "_", country, ".csv"]))
                   for combi in combinations} for exposure in exposures} for warming in warming_levels}

impact_combined = {warming: {exposure: {combi: 
                   Impact.from_csv(
                       "".join([dir_impacts[exposure], exposure,"_combined_impact_","_".join(combi), "_150arcsec_", warming, "_", country, ".csv"]))
                   for combi in combinations} for exposure in exposures} for warming in warming_levels}
# Out:
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)

# %%
impact_df
# Out:
#                       model  impacts_combined
# 0     2006_gfdl-esm2m_rcp26      4.309712e+07
# 1     2006_gfdl-esm2m_rcp26      6.421136e+09
# 2     2006_gfdl-esm2m_rcp26      1.989055e+09
# 3     2006_gfdl-esm2m_rcp26      5.898249e+09
# 4     2006_gfdl-esm2m_rcp26      7.455888e+08
# ...                     ...               ...
# 5345      2033_miroc5_rcp60      2.489036e+10
# 5346      2033_miroc5_rcp60      3.687436e+10
# 5347      2033_miroc5_rcp60      5.208178e+09
# 5348      2033_miroc5_rcp60      1.448930e+10
# 5349      2033_miroc5_rcp60      4.386558e+10
#
# [5350 rows x 2 columns]

# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

ds = xr.open_dataset("/Users/szelie/Downloads/climate_index.nc")
df = ds.to_dataframe().reset_index()
df = df.groupby(['rcp','gcm','year']).mean().reset_index()
df['model'] = df['year'].astype('str') + '_' + df['gcm'].str.lower() + '_' + df['rcp']
for exp in ['assets','pop']:
    for temp in ['1','2']:
        models = ["_".join(event.split("_")[0:3]) for event in impact_combined_ordered[temp][exp][('TC','RF')].event_name]
        impact_df = pd.DataFrame({'model':models, 'impacts_compound': impact_combined_ordered[temp][exp][('TC','RF')].at_event}) 
        
        impact_df = impact_df.merge(df)
        impact_df['combined_factor'] = (df.gmt-df.gmt.min())/(df.gmt.max()-df.gmt.min()) + (df.esoi-df.esoi.min())/(df.esoi.max()-df.esoi.min())

        impact_df.plot.scatter('impacts_compound', 'esoi')
        plt.title(" ".join([exp, temp, 'compound']))

        impact_df.plot.scatter('impacts_compound', 'gmt')
        plt.title(" ".join([exp, temp, 'compound']))
        
#         impact_df.plot.scatter('impacts_compound', 'combined_factor')
#         plt.title(" ".join([exp, temp, 'compound']))

# %%
impact_df
# Out:
#                         model  impacts_combined    rcp           gcm  year  \
# 0     2019_ipsl-cm5a-lr_rcp26      3.672166e+06  rcp26  IPSL-CM5A-LR  2019
# 1     2019_ipsl-cm5a-lr_rcp26      1.130080e+06  rcp26  IPSL-CM5A-LR  2019
# 2     2019_ipsl-cm5a-lr_rcp26      2.205267e+06  rcp26  IPSL-CM5A-LR  2019
# 3     2019_ipsl-cm5a-lr_rcp26      3.586088e+06  rcp26  IPSL-CM5A-LR  2019
# 4     2019_ipsl-cm5a-lr_rcp26      3.254596e+06  rcp26  IPSL-CM5A-LR  2019
# ...                       ...               ...    ...           ...   ...
# 5245    2086_gfdl-esm2m_rcp60      1.304905e+07  rcp60    GFDL-ESM2M  2086
# 5246    2086_gfdl-esm2m_rcp60      1.360189e+06  rcp60    GFDL-ESM2M  2086
# 5247    2086_gfdl-esm2m_rcp60      3.283674e+06  rcp60    GFDL-ESM2M  2086
# 5248    2086_gfdl-esm2m_rcp60      1.022868e+07  rcp60    GFDL-ESM2M  2086
# 5249    2086_gfdl-esm2m_rcp60      2.741253e+06  rcp60    GFDL-ESM2M  2086
#
#       month       gmt      esoi
# 0       6.5  1.825932  0.527948
# 1       6.5  1.825932  0.527948
# 2       6.5  1.825932  0.527948
# 3       6.5  1.825932  0.527948
# 4       6.5  1.825932  0.527948
# ...     ...       ...       ...
# 5245    6.5  2.201485 -0.360862
# 5246    6.5  2.201485 -0.360862
# 5247    6.5  2.201485 -0.360862
# 5248    6.5  2.201485 -0.360862
# 5249    6.5  2.201485 -0.360862
#
# [5250 rows x 8 columns]

# %%
from climada.engine import Impact

dir_impacts = "/Users/szelie/Library/CloudStorage/OneDrive-ETHZurich/data/impacts_multi_risk/results3/yearsets/"

hazards = ['TC', 'RF']
exposures = ['pop', 'assets']
warming_levels = ['1','2']
country = 'global'

impacts_yearsets = {warming: {exposure: {hazard: 
                   Impact.from_csv(
                       "".join([dir_impacts, hazard, '_', exposure,"_impacts_yearsets_150arcsec_", warming, "_", country, "_test.csv"]))
                   for hazard in hazards} for exposure in exposures} for warming in warming_levels}
# Out:
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)
# /Users/szelie/python_projects/climada_python/climada/engine/impact.py:912: DtypeWarning: Columns (0,1,2,3,7,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   imp_df = pd.read_csv(file_name)

# %%
plt.scatter(impacts_yearsets['1']['assets']['TC'].at_event, impacts_yearsets['1']['assets']['RF'].at_event)

# %%
impacts_yearsets['1']['assets']['RF'].event_name
# Out:
# ['2006_gfdl-esm2m_rcp26_watergap2',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_watergap2',
#  '2006_gfdl-esm2m_rcp26_watergap2',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_watergap2',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_watergap2',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_watergap2',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_matsiro',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_cwatm',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_clm45',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp26_h08',
#  '2006_gfdl-esm2m_rcp26_lpjml',
#  '2006_gfdl-esm2m_rcp60_watergap2',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_h08',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_watergap2',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_h08',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_watergap2',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_h08',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_watergap2',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_h08',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_h08',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_clm45',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_watergap2',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_matsiro',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_gfdl-esm2m_rcp60_cwatm',
#  '2006_gfdl-esm2m_rcp60_lpjml',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_matsiro',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_matsiro',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_matsiro',
#  '2006_hadgem2-es_rcp26_matsiro',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_matsiro',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_cwatm',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_matsiro',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_cwatm',
#  '2006_hadgem2-es_rcp26_lpjml',
#  '2006_hadgem2-es_rcp26_cwatm',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp26_clm45',
#  '2006_hadgem2-es_rcp26_watergap2',
#  '2006_hadgem2-es_rcp26_h08',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_h08',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_clm45',
#  '2006_hadgem2-es_rcp60_lpjml',
#  '2006_hadgem2-es_rcp60_watergap2',
#  '2006_hadgem2-es_rcp60_cwatm',
#  '2006_hadgem2-es_rcp60_matsiro',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_watergap2',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_h08',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_lpjml',
#  '2006_miroc5_rcp26_cwatm',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_clm45',
#  '2006_miroc5_rcp26_matsiro',
#  '2006_miroc5_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_matsiro',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_matsiro',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_matsiro',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_matsiro',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp26_cwatm',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_lpjml',
#  '2007_gfdl-esm2m_rcp26_h08',
#  '2007_gfdl-esm2m_rcp26_watergap2',
#  '2007_gfdl-esm2m_rcp26_clm45',
#  '2007_gfdl-esm2m_rcp60_h08',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_h08',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_watergap2',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_h08',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_matsiro',
#  '2007_gfdl-esm2m_rcp60_lpjml',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_clm45',
#  '2007_gfdl-esm2m_rcp60_h08',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_gfdl-esm2m_rcp60_cwatm',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_matsiro',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_matsiro',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_lpjml',
#  '2007_hadgem2-es_rcp26_matsiro',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_cwatm',
#  '2007_hadgem2-es_rcp26_matsiro',
#  '2007_hadgem2-es_rcp26_matsiro',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_matsiro',
#  '2007_hadgem2-es_rcp26_h08',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_watergap2',
#  '2007_hadgem2-es_rcp26_clm45',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_h08',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_h08',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_h08',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_h08',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_h08',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_h08',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_watergap2',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_cwatm',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_hadgem2-es_rcp60_matsiro',
#  '2007_hadgem2-es_rcp60_lpjml',
#  '2007_hadgem2-es_rcp60_clm45',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_lpjml',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_lpjml',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_lpjml',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_matsiro',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_matsiro',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_lpjml',
#  '2007_miroc5_rcp26_matsiro',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_matsiro',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_cwatm',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_watergap2',
#  '2007_miroc5_rcp26_lpjml',
#  '2007_miroc5_rcp26_lpjml',
#  '2007_miroc5_rcp26_h08',
#  '2007_miroc5_rcp26_clm45',
#  '2007_miroc5_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_watergap2',
#  '2008_gfdl-esm2m_rcp26_matsiro',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_cwatm',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_clm45',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_lpjml',
#  '2008_gfdl-esm2m_rcp26_h08',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_matsiro',
#  '2008_gfdl-esm2m_rcp60_h08',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_lpjml',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_lpjml',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_clm45',
#  '2008_gfdl-esm2m_rcp60_cwatm',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_gfdl-esm2m_rcp60_watergap2',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_h08',
#  '2008_hadgem2-es_rcp26_h08',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_h08',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_matsiro',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp26_h08',
#  '2008_hadgem2-es_rcp26_h08',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_lpjml',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_clm45',
#  '2008_hadgem2-es_rcp26_cwatm',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp26_watergap2',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_watergap2',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_watergap2',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_lpjml',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_watergap2',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_watergap2',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_watergap2',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_lpjml',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_h08',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_lpjml',
#  '2008_hadgem2-es_rcp60_matsiro',
#  '2008_hadgem2-es_rcp60_clm45',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_hadgem2-es_rcp60_watergap2',
#  '2008_hadgem2-es_rcp60_cwatm',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_h08',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_h08',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_h08',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_h08',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_h08',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_h08',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_cwatm',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_clm45',
#  '2008_miroc5_rcp26_matsiro',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_lpjml',
#  '2008_miroc5_rcp26_watergap2',
#  '2008_miroc5_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_cwatm',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_cwatm',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_cwatm',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_cwatm',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_cwatm',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_clm45',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_cwatm',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_lpjml',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_matsiro',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_watergap2',
#  '2009_gfdl-esm2m_rcp26_h08',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_watergap2',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_watergap2',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_h08',
#  '2009_gfdl-esm2m_rcp60_watergap2',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_lpjml',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_clm45',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_gfdl-esm2m_rcp60_matsiro',
#  '2009_gfdl-esm2m_rcp60_cwatm',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_h08',
#  '2009_hadgem2-es_rcp26_cwatm',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_matsiro',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp26_lpjml',
#  '2009_hadgem2-es_rcp26_watergap2',
#  '2009_hadgem2-es_rcp26_clm45',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_h08',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_h08',
#  '2009_hadgem2-es_rcp60_cwatm',
#  '2009_hadgem2-es_rcp60_lpjml',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_lpjml',
#  '2009_hadgem2-es_rcp60_lpjml',
#  '2009_hadgem2-es_rcp60_cwatm',
#  '2009_hadgem2-es_rcp60_h08',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_cwatm',
#  '2009_hadgem2-es_rcp60_h08',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_h08',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_cwatm',
#  '2009_hadgem2-es_rcp60_matsiro',
#  '2009_hadgem2-es_rcp60_lpjml',
#  '2009_hadgem2-es_rcp60_lpjml',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_clm45',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_h08',
#  '2009_hadgem2-es_rcp60_watergap2',
#  '2009_hadgem2-es_rcp60_cwatm',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_clm45',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_clm45',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_clm45',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_lpjml',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_clm45',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_h08',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_matsiro',
#  '2009_miroc5_rcp26_cwatm',
#  '2009_miroc5_rcp26_watergap2',
#  '2009_miroc5_rcp26_clm45',
#  '2009_miroc5_rcp26_cwatm',
#  ...]

# %%
impacts_yearsets['1']['pop']['TC'].event_name
# Out:
# ['2006_gfdl-esm2m_rcp26_54',
#  '2006_gfdl-esm2m_rcp26_72',
#  '2006_gfdl-esm2m_rcp26_54',
#  '2006_gfdl-esm2m_rcp26_58',
#  '2006_gfdl-esm2m_rcp26_60',
#  '2006_gfdl-esm2m_rcp26_71',
#  '2006_gfdl-esm2m_rcp26_61',
#  '2006_gfdl-esm2m_rcp26_64',
#  '2006_gfdl-esm2m_rcp26_52',
#  '2006_gfdl-esm2m_rcp26_52',
#  '2006_gfdl-esm2m_rcp26_53',
#  '2006_gfdl-esm2m_rcp26_65',
#  '2006_gfdl-esm2m_rcp26_58',
#  '2006_gfdl-esm2m_rcp26_72',
#  '2006_gfdl-esm2m_rcp26_66',
#  '2006_gfdl-esm2m_rcp26_61',
#  '2006_gfdl-esm2m_rcp26_68',
#  '2006_gfdl-esm2m_rcp26_57',
#  '2006_gfdl-esm2m_rcp26_65',
#  '2006_gfdl-esm2m_rcp26_58',
#  '2006_gfdl-esm2m_rcp26_68',
#  '2006_gfdl-esm2m_rcp26_60',
#  '2006_gfdl-esm2m_rcp26_61',
#  '2006_gfdl-esm2m_rcp26_56',
#  '2006_gfdl-esm2m_rcp26_65',
#  '2006_gfdl-esm2m_rcp26_68',
#  '2006_gfdl-esm2m_rcp26_75',
#  '2006_gfdl-esm2m_rcp26_58',
#  '2006_gfdl-esm2m_rcp26_71',
#  '2006_gfdl-esm2m_rcp26_55',
#  '2006_gfdl-esm2m_rcp26_65',
#  '2006_gfdl-esm2m_rcp26_63',
#  '2006_gfdl-esm2m_rcp26_51',
#  '2006_gfdl-esm2m_rcp26_74',
#  '2006_gfdl-esm2m_rcp26_51',
#  '2006_gfdl-esm2m_rcp26_60',
#  '2006_gfdl-esm2m_rcp26_57',
#  '2006_gfdl-esm2m_rcp26_71',
#  '2006_gfdl-esm2m_rcp26_63',
#  '2006_gfdl-esm2m_rcp26_70',
#  '2006_gfdl-esm2m_rcp26_72',
#  '2006_gfdl-esm2m_rcp26_57',
#  '2006_gfdl-esm2m_rcp26_54',
#  '2006_gfdl-esm2m_rcp26_51',
#  '2006_gfdl-esm2m_rcp26_68',
#  '2006_gfdl-esm2m_rcp26_56',
#  '2006_gfdl-esm2m_rcp26_53',
#  '2006_gfdl-esm2m_rcp26_60',
#  '2006_gfdl-esm2m_rcp26_71',
#  '2006_gfdl-esm2m_rcp26_58',
#  '2006_gfdl-esm2m_rcp60_60',
#  '2006_gfdl-esm2m_rcp60_58',
#  '2006_gfdl-esm2m_rcp60_70',
#  '2006_gfdl-esm2m_rcp60_68',
#  '2006_gfdl-esm2m_rcp60_68',
#  '2006_gfdl-esm2m_rcp60_75',
#  '2006_gfdl-esm2m_rcp60_71',
#  '2006_gfdl-esm2m_rcp60_59',
#  '2006_gfdl-esm2m_rcp60_52',
#  '2006_gfdl-esm2m_rcp60_73',
#  '2006_gfdl-esm2m_rcp60_64',
#  '2006_gfdl-esm2m_rcp60_52',
#  '2006_gfdl-esm2m_rcp60_63',
#  '2006_gfdl-esm2m_rcp60_65',
#  '2006_gfdl-esm2m_rcp60_61',
#  '2006_gfdl-esm2m_rcp60_54',
#  '2006_gfdl-esm2m_rcp60_56',
#  '2006_gfdl-esm2m_rcp60_73',
#  '2006_gfdl-esm2m_rcp60_59',
#  '2006_gfdl-esm2m_rcp60_67',
#  '2006_gfdl-esm2m_rcp60_75',
#  '2006_gfdl-esm2m_rcp60_72',
#  '2006_gfdl-esm2m_rcp60_68',
#  '2006_gfdl-esm2m_rcp60_66',
#  '2006_gfdl-esm2m_rcp60_52',
#  '2006_gfdl-esm2m_rcp60_69',
#  '2006_gfdl-esm2m_rcp60_61',
#  '2006_gfdl-esm2m_rcp60_65',
#  '2006_gfdl-esm2m_rcp60_65',
#  '2006_gfdl-esm2m_rcp60_74',
#  '2006_gfdl-esm2m_rcp60_54',
#  '2006_gfdl-esm2m_rcp60_51',
#  '2006_gfdl-esm2m_rcp60_54',
#  '2006_gfdl-esm2m_rcp60_58',
#  '2006_gfdl-esm2m_rcp60_53',
#  '2006_gfdl-esm2m_rcp60_61',
#  '2006_gfdl-esm2m_rcp60_69',
#  '2006_gfdl-esm2m_rcp60_72',
#  '2006_gfdl-esm2m_rcp60_72',
#  '2006_gfdl-esm2m_rcp60_67',
#  '2006_gfdl-esm2m_rcp60_73',
#  '2006_gfdl-esm2m_rcp60_73',
#  '2006_gfdl-esm2m_rcp60_68',
#  '2006_gfdl-esm2m_rcp60_63',
#  '2006_gfdl-esm2m_rcp60_52',
#  '2006_gfdl-esm2m_rcp60_65',
#  '2006_gfdl-esm2m_rcp60_51',
#  '2006_gfdl-esm2m_rcp60_51',
#  '2006_gfdl-esm2m_rcp60_63',
#  '2006_gfdl-esm2m_rcp60_53',
#  '2006_hadgem2-es_rcp26_56',
#  '2006_hadgem2-es_rcp26_58',
#  '2006_hadgem2-es_rcp26_66',
#  '2006_hadgem2-es_rcp26_57',
#  '2006_hadgem2-es_rcp26_57',
#  '2006_hadgem2-es_rcp26_67',
#  '2006_hadgem2-es_rcp26_59',
#  '2006_hadgem2-es_rcp26_52',
#  '2006_hadgem2-es_rcp26_61',
#  '2006_hadgem2-es_rcp26_54',
#  '2006_hadgem2-es_rcp26_74',
#  '2006_hadgem2-es_rcp26_59',
#  '2006_hadgem2-es_rcp26_68',
#  '2006_hadgem2-es_rcp26_59',
#  '2006_hadgem2-es_rcp26_64',
#  '2006_hadgem2-es_rcp26_62',
#  '2006_hadgem2-es_rcp26_53',
#  '2006_hadgem2-es_rcp26_73',
#  '2006_hadgem2-es_rcp26_66',
#  '2006_hadgem2-es_rcp26_70',
#  '2006_hadgem2-es_rcp26_65',
#  '2006_hadgem2-es_rcp26_75',
#  '2006_hadgem2-es_rcp26_75',
#  '2006_hadgem2-es_rcp26_62',
#  '2006_hadgem2-es_rcp26_73',
#  '2006_hadgem2-es_rcp26_55',
#  '2006_hadgem2-es_rcp26_75',
#  '2006_hadgem2-es_rcp26_73',
#  '2006_hadgem2-es_rcp26_56',
#  '2006_hadgem2-es_rcp26_68',
#  '2006_hadgem2-es_rcp26_73',
#  '2006_hadgem2-es_rcp26_56',
#  '2006_hadgem2-es_rcp26_63',
#  '2006_hadgem2-es_rcp26_61',
#  '2006_hadgem2-es_rcp26_52',
#  '2006_hadgem2-es_rcp26_73',
#  '2006_hadgem2-es_rcp26_54',
#  '2006_hadgem2-es_rcp26_62',
#  '2006_hadgem2-es_rcp26_51',
#  '2006_hadgem2-es_rcp26_57',
#  '2006_hadgem2-es_rcp26_58',
#  '2006_hadgem2-es_rcp26_51',
#  '2006_hadgem2-es_rcp26_67',
#  '2006_hadgem2-es_rcp26_65',
#  '2006_hadgem2-es_rcp26_63',
#  '2006_hadgem2-es_rcp26_61',
#  '2006_hadgem2-es_rcp26_64',
#  '2006_hadgem2-es_rcp26_66',
#  '2006_hadgem2-es_rcp26_66',
#  '2006_hadgem2-es_rcp26_57',
#  '2006_hadgem2-es_rcp60_74',
#  '2006_hadgem2-es_rcp60_72',
#  '2006_hadgem2-es_rcp60_55',
#  '2006_hadgem2-es_rcp60_74',
#  '2006_hadgem2-es_rcp60_70',
#  '2006_hadgem2-es_rcp60_60',
#  '2006_hadgem2-es_rcp60_54',
#  '2006_hadgem2-es_rcp60_74',
#  '2006_hadgem2-es_rcp60_58',
#  '2006_hadgem2-es_rcp60_75',
#  '2006_hadgem2-es_rcp60_64',
#  '2006_hadgem2-es_rcp60_51',
#  '2006_hadgem2-es_rcp60_68',
#  '2006_hadgem2-es_rcp60_75',
#  '2006_hadgem2-es_rcp60_61',
#  '2006_hadgem2-es_rcp60_70',
#  '2006_hadgem2-es_rcp60_57',
#  '2006_hadgem2-es_rcp60_60',
#  '2006_hadgem2-es_rcp60_71',
#  '2006_hadgem2-es_rcp60_61',
#  '2006_hadgem2-es_rcp60_74',
#  '2006_hadgem2-es_rcp60_63',
#  '2006_hadgem2-es_rcp60_53',
#  '2006_hadgem2-es_rcp60_70',
#  '2006_hadgem2-es_rcp60_71',
#  '2006_hadgem2-es_rcp60_57',
#  '2006_hadgem2-es_rcp60_69',
#  '2006_hadgem2-es_rcp60_53',
#  '2006_hadgem2-es_rcp60_73',
#  '2006_hadgem2-es_rcp60_53',
#  '2006_hadgem2-es_rcp60_72',
#  '2006_hadgem2-es_rcp60_53',
#  '2006_hadgem2-es_rcp60_53',
#  '2006_hadgem2-es_rcp60_68',
#  '2006_hadgem2-es_rcp60_59',
#  '2006_hadgem2-es_rcp60_70',
#  '2006_hadgem2-es_rcp60_62',
#  '2006_hadgem2-es_rcp60_69',
#  '2006_hadgem2-es_rcp60_66',
#  '2006_hadgem2-es_rcp60_63',
#  '2006_hadgem2-es_rcp60_55',
#  '2006_hadgem2-es_rcp60_51',
#  '2006_hadgem2-es_rcp60_69',
#  '2006_hadgem2-es_rcp60_69',
#  '2006_hadgem2-es_rcp60_51',
#  '2006_hadgem2-es_rcp60_71',
#  '2006_hadgem2-es_rcp60_60',
#  '2006_hadgem2-es_rcp60_56',
#  '2006_hadgem2-es_rcp60_72',
#  '2006_hadgem2-es_rcp60_68',
#  '2006_miroc5_rcp26_51',
#  '2006_miroc5_rcp26_61',
#  '2006_miroc5_rcp26_51',
#  '2006_miroc5_rcp26_62',
#  '2006_miroc5_rcp26_58',
#  '2006_miroc5_rcp26_57',
#  '2006_miroc5_rcp26_68',
#  '2006_miroc5_rcp26_64',
#  '2006_miroc5_rcp26_74',
#  '2006_miroc5_rcp26_57',
#  '2006_miroc5_rcp26_59',
#  '2006_miroc5_rcp26_54',
#  '2006_miroc5_rcp26_71',
#  '2006_miroc5_rcp26_63',
#  '2006_miroc5_rcp26_54',
#  '2006_miroc5_rcp26_60',
#  '2006_miroc5_rcp26_73',
#  '2006_miroc5_rcp26_66',
#  '2006_miroc5_rcp26_75',
#  '2006_miroc5_rcp26_72',
#  '2006_miroc5_rcp26_53',
#  '2006_miroc5_rcp26_51',
#  '2006_miroc5_rcp26_70',
#  '2006_miroc5_rcp26_58',
#  '2006_miroc5_rcp26_54',
#  '2006_miroc5_rcp26_55',
#  '2006_miroc5_rcp26_62',
#  '2006_miroc5_rcp26_63',
#  '2006_miroc5_rcp26_59',
#  '2006_miroc5_rcp26_64',
#  '2006_miroc5_rcp26_61',
#  '2006_miroc5_rcp26_72',
#  '2006_miroc5_rcp26_58',
#  '2006_miroc5_rcp26_56',
#  '2006_miroc5_rcp26_59',
#  '2006_miroc5_rcp26_74',
#  '2006_miroc5_rcp26_57',
#  '2006_miroc5_rcp26_70',
#  '2006_miroc5_rcp26_64',
#  '2006_miroc5_rcp26_64',
#  '2006_miroc5_rcp26_73',
#  '2006_miroc5_rcp26_72',
#  '2006_miroc5_rcp26_75',
#  '2006_miroc5_rcp26_63',
#  '2006_miroc5_rcp26_60',
#  '2006_miroc5_rcp26_66',
#  '2006_miroc5_rcp26_74',
#  '2006_miroc5_rcp26_66',
#  '2006_miroc5_rcp26_51',
#  '2006_miroc5_rcp26_69',
#  '2007_gfdl-esm2m_rcp26_57',
#  '2007_gfdl-esm2m_rcp26_58',
#  '2007_gfdl-esm2m_rcp26_69',
#  '2007_gfdl-esm2m_rcp26_56',
#  '2007_gfdl-esm2m_rcp26_69',
#  '2007_gfdl-esm2m_rcp26_72',
#  '2007_gfdl-esm2m_rcp26_63',
#  '2007_gfdl-esm2m_rcp26_58',
#  '2007_gfdl-esm2m_rcp26_59',
#  '2007_gfdl-esm2m_rcp26_58',
#  '2007_gfdl-esm2m_rcp26_57',
#  '2007_gfdl-esm2m_rcp26_68',
#  '2007_gfdl-esm2m_rcp26_58',
#  '2007_gfdl-esm2m_rcp26_56',
#  '2007_gfdl-esm2m_rcp26_66',
#  '2007_gfdl-esm2m_rcp26_64',
#  '2007_gfdl-esm2m_rcp26_57',
#  '2007_gfdl-esm2m_rcp26_68',
#  '2007_gfdl-esm2m_rcp26_56',
#  '2007_gfdl-esm2m_rcp26_70',
#  '2007_gfdl-esm2m_rcp26_75',
#  '2007_gfdl-esm2m_rcp26_62',
#  '2007_gfdl-esm2m_rcp26_75',
#  '2007_gfdl-esm2m_rcp26_75',
#  '2007_gfdl-esm2m_rcp26_55',
#  '2007_gfdl-esm2m_rcp26_63',
#  '2007_gfdl-esm2m_rcp26_61',
#  '2007_gfdl-esm2m_rcp26_70',
#  '2007_gfdl-esm2m_rcp26_55',
#  '2007_gfdl-esm2m_rcp26_68',
#  '2007_gfdl-esm2m_rcp26_57',
#  '2007_gfdl-esm2m_rcp26_71',
#  '2007_gfdl-esm2m_rcp26_71',
#  '2007_gfdl-esm2m_rcp26_67',
#  '2007_gfdl-esm2m_rcp26_60',
#  '2007_gfdl-esm2m_rcp26_71',
#  '2007_gfdl-esm2m_rcp26_62',
#  '2007_gfdl-esm2m_rcp26_61',
#  '2007_gfdl-esm2m_rcp26_57',
#  '2007_gfdl-esm2m_rcp26_67',
#  '2007_gfdl-esm2m_rcp26_62',
#  '2007_gfdl-esm2m_rcp26_63',
#  '2007_gfdl-esm2m_rcp26_65',
#  '2007_gfdl-esm2m_rcp26_66',
#  '2007_gfdl-esm2m_rcp26_56',
#  '2007_gfdl-esm2m_rcp26_67',
#  '2007_gfdl-esm2m_rcp26_66',
#  '2007_gfdl-esm2m_rcp26_69',
#  '2007_gfdl-esm2m_rcp26_71',
#  '2007_gfdl-esm2m_rcp26_56',
#  '2007_gfdl-esm2m_rcp60_51',
#  '2007_gfdl-esm2m_rcp60_73',
#  '2007_gfdl-esm2m_rcp60_56',
#  '2007_gfdl-esm2m_rcp60_60',
#  '2007_gfdl-esm2m_rcp60_66',
#  '2007_gfdl-esm2m_rcp60_73',
#  '2007_gfdl-esm2m_rcp60_69',
#  '2007_gfdl-esm2m_rcp60_55',
#  '2007_gfdl-esm2m_rcp60_64',
#  '2007_gfdl-esm2m_rcp60_61',
#  '2007_gfdl-esm2m_rcp60_59',
#  '2007_gfdl-esm2m_rcp60_73',
#  '2007_gfdl-esm2m_rcp60_66',
#  '2007_gfdl-esm2m_rcp60_71',
#  '2007_gfdl-esm2m_rcp60_67',
#  '2007_gfdl-esm2m_rcp60_60',
#  '2007_gfdl-esm2m_rcp60_70',
#  '2007_gfdl-esm2m_rcp60_65',
#  '2007_gfdl-esm2m_rcp60_65',
#  '2007_gfdl-esm2m_rcp60_55',
#  '2007_gfdl-esm2m_rcp60_65',
#  '2007_gfdl-esm2m_rcp60_53',
#  '2007_gfdl-esm2m_rcp60_74',
#  '2007_gfdl-esm2m_rcp60_65',
#  '2007_gfdl-esm2m_rcp60_59',
#  '2007_gfdl-esm2m_rcp60_67',
#  '2007_gfdl-esm2m_rcp60_56',
#  '2007_gfdl-esm2m_rcp60_61',
#  '2007_gfdl-esm2m_rcp60_55',
#  '2007_gfdl-esm2m_rcp60_54',
#  '2007_gfdl-esm2m_rcp60_74',
#  '2007_gfdl-esm2m_rcp60_63',
#  '2007_gfdl-esm2m_rcp60_52',
#  '2007_gfdl-esm2m_rcp60_55',
#  '2007_gfdl-esm2m_rcp60_57',
#  '2007_gfdl-esm2m_rcp60_65',
#  '2007_gfdl-esm2m_rcp60_71',
#  '2007_gfdl-esm2m_rcp60_65',
#  '2007_gfdl-esm2m_rcp60_62',
#  '2007_gfdl-esm2m_rcp60_56',
#  '2007_gfdl-esm2m_rcp60_55',
#  '2007_gfdl-esm2m_rcp60_51',
#  '2007_gfdl-esm2m_rcp60_66',
#  '2007_gfdl-esm2m_rcp60_52',
#  '2007_gfdl-esm2m_rcp60_60',
#  '2007_gfdl-esm2m_rcp60_70',
#  '2007_gfdl-esm2m_rcp60_68',
#  '2007_gfdl-esm2m_rcp60_74',
#  '2007_gfdl-esm2m_rcp60_67',
#  '2007_gfdl-esm2m_rcp60_74',
#  '2007_hadgem2-es_rcp26_72',
#  '2007_hadgem2-es_rcp26_64',
#  '2007_hadgem2-es_rcp26_61',
#  '2007_hadgem2-es_rcp26_51',
#  '2007_hadgem2-es_rcp26_61',
#  '2007_hadgem2-es_rcp26_71',
#  '2007_hadgem2-es_rcp26_57',
#  '2007_hadgem2-es_rcp26_73',
#  '2007_hadgem2-es_rcp26_67',
#  '2007_hadgem2-es_rcp26_60',
#  '2007_hadgem2-es_rcp26_72',
#  '2007_hadgem2-es_rcp26_69',
#  '2007_hadgem2-es_rcp26_66',
#  '2007_hadgem2-es_rcp26_74',
#  '2007_hadgem2-es_rcp26_69',
#  '2007_hadgem2-es_rcp26_69',
#  '2007_hadgem2-es_rcp26_74',
#  '2007_hadgem2-es_rcp26_60',
#  '2007_hadgem2-es_rcp26_51',
#  '2007_hadgem2-es_rcp26_58',
#  '2007_hadgem2-es_rcp26_66',
#  '2007_hadgem2-es_rcp26_64',
#  '2007_hadgem2-es_rcp26_55',
#  '2007_hadgem2-es_rcp26_68',
#  '2007_hadgem2-es_rcp26_68',
#  '2007_hadgem2-es_rcp26_61',
#  '2007_hadgem2-es_rcp26_75',
#  '2007_hadgem2-es_rcp26_74',
#  '2007_hadgem2-es_rcp26_72',
#  '2007_hadgem2-es_rcp26_61',
#  '2007_hadgem2-es_rcp26_58',
#  '2007_hadgem2-es_rcp26_75',
#  '2007_hadgem2-es_rcp26_53',
#  '2007_hadgem2-es_rcp26_57',
#  '2007_hadgem2-es_rcp26_51',
#  '2007_hadgem2-es_rcp26_59',
#  '2007_hadgem2-es_rcp26_67',
#  '2007_hadgem2-es_rcp26_71',
#  '2007_hadgem2-es_rcp26_57',
#  '2007_hadgem2-es_rcp26_68',
#  '2007_hadgem2-es_rcp26_51',
#  '2007_hadgem2-es_rcp26_70',
#  '2007_hadgem2-es_rcp26_57',
#  '2007_hadgem2-es_rcp26_75',
#  '2007_hadgem2-es_rcp26_51',
#  '2007_hadgem2-es_rcp26_64',
#  '2007_hadgem2-es_rcp26_53',
#  '2007_hadgem2-es_rcp26_70',
#  '2007_hadgem2-es_rcp26_53',
#  '2007_hadgem2-es_rcp26_57',
#  '2007_hadgem2-es_rcp60_59',
#  '2007_hadgem2-es_rcp60_63',
#  '2007_hadgem2-es_rcp60_75',
#  '2007_hadgem2-es_rcp60_53',
#  '2007_hadgem2-es_rcp60_68',
#  '2007_hadgem2-es_rcp60_57',
#  '2007_hadgem2-es_rcp60_56',
#  '2007_hadgem2-es_rcp60_64',
#  '2007_hadgem2-es_rcp60_68',
#  '2007_hadgem2-es_rcp60_63',
#  '2007_hadgem2-es_rcp60_69',
#  '2007_hadgem2-es_rcp60_70',
#  '2007_hadgem2-es_rcp60_57',
#  '2007_hadgem2-es_rcp60_70',
#  '2007_hadgem2-es_rcp60_54',
#  '2007_hadgem2-es_rcp60_67',
#  '2007_hadgem2-es_rcp60_60',
#  '2007_hadgem2-es_rcp60_59',
#  '2007_hadgem2-es_rcp60_66',
#  '2007_hadgem2-es_rcp60_61',
#  '2007_hadgem2-es_rcp60_52',
#  '2007_hadgem2-es_rcp60_72',
#  '2007_hadgem2-es_rcp60_72',
#  '2007_hadgem2-es_rcp60_57',
#  '2007_hadgem2-es_rcp60_74',
#  '2007_hadgem2-es_rcp60_71',
#  '2007_hadgem2-es_rcp60_58',
#  '2007_hadgem2-es_rcp60_57',
#  '2007_hadgem2-es_rcp60_64',
#  '2007_hadgem2-es_rcp60_56',
#  '2007_hadgem2-es_rcp60_54',
#  '2007_hadgem2-es_rcp60_60',
#  '2007_hadgem2-es_rcp60_51',
#  '2007_hadgem2-es_rcp60_51',
#  '2007_hadgem2-es_rcp60_54',
#  '2007_hadgem2-es_rcp60_51',
#  '2007_hadgem2-es_rcp60_55',
#  '2007_hadgem2-es_rcp60_52',
#  '2007_hadgem2-es_rcp60_73',
#  '2007_hadgem2-es_rcp60_73',
#  '2007_hadgem2-es_rcp60_54',
#  '2007_hadgem2-es_rcp60_55',
#  '2007_hadgem2-es_rcp60_59',
#  '2007_hadgem2-es_rcp60_69',
#  '2007_hadgem2-es_rcp60_65',
#  '2007_hadgem2-es_rcp60_69',
#  '2007_hadgem2-es_rcp60_68',
#  '2007_hadgem2-es_rcp60_57',
#  '2007_hadgem2-es_rcp60_68',
#  '2007_hadgem2-es_rcp60_72',
#  '2007_miroc5_rcp26_65',
#  '2007_miroc5_rcp26_74',
#  '2007_miroc5_rcp26_53',
#  '2007_miroc5_rcp26_55',
#  '2007_miroc5_rcp26_58',
#  '2007_miroc5_rcp26_65',
#  '2007_miroc5_rcp26_73',
#  '2007_miroc5_rcp26_65',
#  '2007_miroc5_rcp26_56',
#  '2007_miroc5_rcp26_55',
#  '2007_miroc5_rcp26_71',
#  '2007_miroc5_rcp26_63',
#  '2007_miroc5_rcp26_73',
#  '2007_miroc5_rcp26_69',
#  '2007_miroc5_rcp26_71',
#  '2007_miroc5_rcp26_62',
#  '2007_miroc5_rcp26_70',
#  '2007_miroc5_rcp26_60',
#  '2007_miroc5_rcp26_63',
#  '2007_miroc5_rcp26_51',
#  '2007_miroc5_rcp26_56',
#  '2007_miroc5_rcp26_71',
#  '2007_miroc5_rcp26_61',
#  '2007_miroc5_rcp26_66',
#  '2007_miroc5_rcp26_61',
#  '2007_miroc5_rcp26_54',
#  '2007_miroc5_rcp26_54',
#  '2007_miroc5_rcp26_65',
#  '2007_miroc5_rcp26_61',
#  '2007_miroc5_rcp26_61',
#  '2007_miroc5_rcp26_59',
#  '2007_miroc5_rcp26_52',
#  '2007_miroc5_rcp26_65',
#  '2007_miroc5_rcp26_52',
#  '2007_miroc5_rcp26_58',
#  '2007_miroc5_rcp26_53',
#  '2007_miroc5_rcp26_66',
#  '2007_miroc5_rcp26_56',
#  '2007_miroc5_rcp26_52',
#  '2007_miroc5_rcp26_66',
#  '2007_miroc5_rcp26_59',
#  '2007_miroc5_rcp26_73',
#  '2007_miroc5_rcp26_68',
#  '2007_miroc5_rcp26_64',
#  '2007_miroc5_rcp26_71',
#  '2007_miroc5_rcp26_60',
#  '2007_miroc5_rcp26_65',
#  '2007_miroc5_rcp26_60',
#  '2007_miroc5_rcp26_61',
#  '2007_miroc5_rcp26_59',
#  '2008_gfdl-esm2m_rcp26_58',
#  '2008_gfdl-esm2m_rcp26_52',
#  '2008_gfdl-esm2m_rcp26_70',
#  '2008_gfdl-esm2m_rcp26_56',
#  '2008_gfdl-esm2m_rcp26_58',
#  '2008_gfdl-esm2m_rcp26_56',
#  '2008_gfdl-esm2m_rcp26_57',
#  '2008_gfdl-esm2m_rcp26_72',
#  '2008_gfdl-esm2m_rcp26_54',
#  '2008_gfdl-esm2m_rcp26_52',
#  '2008_gfdl-esm2m_rcp26_64',
#  '2008_gfdl-esm2m_rcp26_69',
#  '2008_gfdl-esm2m_rcp26_57',
#  '2008_gfdl-esm2m_rcp26_70',
#  '2008_gfdl-esm2m_rcp26_67',
#  '2008_gfdl-esm2m_rcp26_52',
#  '2008_gfdl-esm2m_rcp26_60',
#  '2008_gfdl-esm2m_rcp26_60',
#  '2008_gfdl-esm2m_rcp26_51',
#  '2008_gfdl-esm2m_rcp26_57',
#  '2008_gfdl-esm2m_rcp26_68',
#  '2008_gfdl-esm2m_rcp26_62',
#  '2008_gfdl-esm2m_rcp26_64',
#  '2008_gfdl-esm2m_rcp26_55',
#  '2008_gfdl-esm2m_rcp26_64',
#  '2008_gfdl-esm2m_rcp26_63',
#  '2008_gfdl-esm2m_rcp26_56',
#  '2008_gfdl-esm2m_rcp26_69',
#  '2008_gfdl-esm2m_rcp26_58',
#  '2008_gfdl-esm2m_rcp26_73',
#  '2008_gfdl-esm2m_rcp26_75',
#  '2008_gfdl-esm2m_rcp26_66',
#  '2008_gfdl-esm2m_rcp26_53',
#  '2008_gfdl-esm2m_rcp26_65',
#  '2008_gfdl-esm2m_rcp26_65',
#  '2008_gfdl-esm2m_rcp26_61',
#  '2008_gfdl-esm2m_rcp26_74',
#  '2008_gfdl-esm2m_rcp26_62',
#  '2008_gfdl-esm2m_rcp26_73',
#  '2008_gfdl-esm2m_rcp26_65',
#  '2008_gfdl-esm2m_rcp26_69',
#  '2008_gfdl-esm2m_rcp26_63',
#  '2008_gfdl-esm2m_rcp26_68',
#  '2008_gfdl-esm2m_rcp26_67',
#  '2008_gfdl-esm2m_rcp26_54',
#  '2008_gfdl-esm2m_rcp26_58',
#  '2008_gfdl-esm2m_rcp26_68',
#  '2008_gfdl-esm2m_rcp26_70',
#  '2008_gfdl-esm2m_rcp26_61',
#  '2008_gfdl-esm2m_rcp26_75',
#  '2008_gfdl-esm2m_rcp60_60',
#  '2008_gfdl-esm2m_rcp60_58',
#  '2008_gfdl-esm2m_rcp60_64',
#  '2008_gfdl-esm2m_rcp60_66',
#  '2008_gfdl-esm2m_rcp60_62',
#  '2008_gfdl-esm2m_rcp60_67',
#  '2008_gfdl-esm2m_rcp60_72',
#  '2008_gfdl-esm2m_rcp60_73',
#  '2008_gfdl-esm2m_rcp60_56',
#  '2008_gfdl-esm2m_rcp60_55',
#  '2008_gfdl-esm2m_rcp60_69',
#  '2008_gfdl-esm2m_rcp60_66',
#  '2008_gfdl-esm2m_rcp60_53',
#  '2008_gfdl-esm2m_rcp60_63',
#  '2008_gfdl-esm2m_rcp60_62',
#  '2008_gfdl-esm2m_rcp60_64',
#  '2008_gfdl-esm2m_rcp60_63',
#  '2008_gfdl-esm2m_rcp60_68',
#  '2008_gfdl-esm2m_rcp60_59',
#  '2008_gfdl-esm2m_rcp60_66',
#  '2008_gfdl-esm2m_rcp60_51',
#  '2008_gfdl-esm2m_rcp60_52',
#  '2008_gfdl-esm2m_rcp60_64',
#  '2008_gfdl-esm2m_rcp60_59',
#  '2008_gfdl-esm2m_rcp60_60',
#  '2008_gfdl-esm2m_rcp60_64',
#  '2008_gfdl-esm2m_rcp60_62',
#  '2008_gfdl-esm2m_rcp60_69',
#  '2008_gfdl-esm2m_rcp60_64',
#  '2008_gfdl-esm2m_rcp60_56',
#  '2008_gfdl-esm2m_rcp60_51',
#  '2008_gfdl-esm2m_rcp60_70',
#  '2008_gfdl-esm2m_rcp60_75',
#  '2008_gfdl-esm2m_rcp60_52',
#  '2008_gfdl-esm2m_rcp60_60',
#  '2008_gfdl-esm2m_rcp60_60',
#  '2008_gfdl-esm2m_rcp60_60',
#  '2008_gfdl-esm2m_rcp60_67',
#  '2008_gfdl-esm2m_rcp60_55',
#  '2008_gfdl-esm2m_rcp60_70',
#  '2008_gfdl-esm2m_rcp60_55',
#  '2008_gfdl-esm2m_rcp60_56',
#  '2008_gfdl-esm2m_rcp60_65',
#  '2008_gfdl-esm2m_rcp60_56',
#  '2008_gfdl-esm2m_rcp60_70',
#  '2008_gfdl-esm2m_rcp60_71',
#  '2008_gfdl-esm2m_rcp60_56',
#  '2008_gfdl-esm2m_rcp60_58',
#  '2008_gfdl-esm2m_rcp60_53',
#  '2008_gfdl-esm2m_rcp60_75',
#  '2008_hadgem2-es_rcp26_57',
#  '2008_hadgem2-es_rcp26_56',
#  '2008_hadgem2-es_rcp26_68',
#  '2008_hadgem2-es_rcp26_51',
#  '2008_hadgem2-es_rcp26_68',
#  '2008_hadgem2-es_rcp26_57',
#  '2008_hadgem2-es_rcp26_52',
#  '2008_hadgem2-es_rcp26_55',
#  '2008_hadgem2-es_rcp26_67',
#  '2008_hadgem2-es_rcp26_57',
#  '2008_hadgem2-es_rcp26_65',
#  '2008_hadgem2-es_rcp26_64',
#  '2008_hadgem2-es_rcp26_54',
#  '2008_hadgem2-es_rcp26_67',
#  '2008_hadgem2-es_rcp26_59',
#  '2008_hadgem2-es_rcp26_72',
#  '2008_hadgem2-es_rcp26_70',
#  '2008_hadgem2-es_rcp26_55',
#  '2008_hadgem2-es_rcp26_53',
#  '2008_hadgem2-es_rcp26_75',
#  '2008_hadgem2-es_rcp26_54',
#  '2008_hadgem2-es_rcp26_52',
#  '2008_hadgem2-es_rcp26_63',
#  '2008_hadgem2-es_rcp26_52',
#  '2008_hadgem2-es_rcp26_55',
#  '2008_hadgem2-es_rcp26_72',
#  '2008_hadgem2-es_rcp26_53',
#  '2008_hadgem2-es_rcp26_58',
#  '2008_hadgem2-es_rcp26_54',
#  '2008_hadgem2-es_rcp26_54',
#  '2008_hadgem2-es_rcp26_68',
#  '2008_hadgem2-es_rcp26_63',
#  '2008_hadgem2-es_rcp26_52',
#  '2008_hadgem2-es_rcp26_74',
#  '2008_hadgem2-es_rcp26_72',
#  '2008_hadgem2-es_rcp26_71',
#  '2008_hadgem2-es_rcp26_71',
#  '2008_hadgem2-es_rcp26_70',
#  '2008_hadgem2-es_rcp26_61',
#  '2008_hadgem2-es_rcp26_75',
#  '2008_hadgem2-es_rcp26_68',
#  '2008_hadgem2-es_rcp26_70',
#  '2008_hadgem2-es_rcp26_55',
#  '2008_hadgem2-es_rcp26_61',
#  '2008_hadgem2-es_rcp26_73',
#  '2008_hadgem2-es_rcp26_51',
#  '2008_hadgem2-es_rcp26_51',
#  '2008_hadgem2-es_rcp26_71',
#  '2008_hadgem2-es_rcp26_65',
#  '2008_hadgem2-es_rcp26_71',
#  '2008_hadgem2-es_rcp60_64',
#  '2008_hadgem2-es_rcp60_52',
#  '2008_hadgem2-es_rcp60_52',
#  '2008_hadgem2-es_rcp60_57',
#  '2008_hadgem2-es_rcp60_51',
#  '2008_hadgem2-es_rcp60_55',
#  '2008_hadgem2-es_rcp60_64',
#  '2008_hadgem2-es_rcp60_61',
#  '2008_hadgem2-es_rcp60_61',
#  '2008_hadgem2-es_rcp60_74',
#  '2008_hadgem2-es_rcp60_68',
#  '2008_hadgem2-es_rcp60_54',
#  '2008_hadgem2-es_rcp60_51',
#  '2008_hadgem2-es_rcp60_74',
#  '2008_hadgem2-es_rcp60_69',
#  '2008_hadgem2-es_rcp60_58',
#  '2008_hadgem2-es_rcp60_73',
#  '2008_hadgem2-es_rcp60_57',
#  '2008_hadgem2-es_rcp60_53',
#  '2008_hadgem2-es_rcp60_65',
#  '2008_hadgem2-es_rcp60_57',
#  '2008_hadgem2-es_rcp60_64',
#  '2008_hadgem2-es_rcp60_64',
#  '2008_hadgem2-es_rcp60_60',
#  '2008_hadgem2-es_rcp60_58',
#  '2008_hadgem2-es_rcp60_61',
#  '2008_hadgem2-es_rcp60_65',
#  '2008_hadgem2-es_rcp60_68',
#  '2008_hadgem2-es_rcp60_60',
#  '2008_hadgem2-es_rcp60_55',
#  '2008_hadgem2-es_rcp60_61',
#  '2008_hadgem2-es_rcp60_64',
#  '2008_hadgem2-es_rcp60_51',
#  '2008_hadgem2-es_rcp60_63',
#  '2008_hadgem2-es_rcp60_73',
#  '2008_hadgem2-es_rcp60_51',
#  '2008_hadgem2-es_rcp60_63',
#  '2008_hadgem2-es_rcp60_56',
#  '2008_hadgem2-es_rcp60_58',
#  '2008_hadgem2-es_rcp60_56',
#  '2008_hadgem2-es_rcp60_70',
#  '2008_hadgem2-es_rcp60_59',
#  '2008_hadgem2-es_rcp60_52',
#  '2008_hadgem2-es_rcp60_62',
#  '2008_hadgem2-es_rcp60_72',
#  '2008_hadgem2-es_rcp60_59',
#  '2008_hadgem2-es_rcp60_71',
#  '2008_hadgem2-es_rcp60_60',
#  '2008_hadgem2-es_rcp60_54',
#  '2008_hadgem2-es_rcp60_74',
#  '2008_miroc5_rcp26_72',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_65',
#  '2008_miroc5_rcp26_75',
#  '2008_miroc5_rcp26_58',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_59',
#  '2008_miroc5_rcp26_72',
#  '2008_miroc5_rcp26_55',
#  '2008_miroc5_rcp26_62',
#  '2008_miroc5_rcp26_73',
#  '2008_miroc5_rcp26_71',
#  '2008_miroc5_rcp26_70',
#  '2008_miroc5_rcp26_66',
#  '2008_miroc5_rcp26_71',
#  '2008_miroc5_rcp26_60',
#  '2008_miroc5_rcp26_57',
#  '2008_miroc5_rcp26_68',
#  '2008_miroc5_rcp26_69',
#  '2008_miroc5_rcp26_54',
#  '2008_miroc5_rcp26_55',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_62',
#  '2008_miroc5_rcp26_64',
#  '2008_miroc5_rcp26_54',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_54',
#  '2008_miroc5_rcp26_73',
#  '2008_miroc5_rcp26_55',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_71',
#  '2008_miroc5_rcp26_64',
#  '2008_miroc5_rcp26_61',
#  '2008_miroc5_rcp26_69',
#  '2008_miroc5_rcp26_70',
#  '2008_miroc5_rcp26_67',
#  '2008_miroc5_rcp26_52',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_72',
#  '2008_miroc5_rcp26_58',
#  '2008_miroc5_rcp26_57',
#  '2008_miroc5_rcp26_56',
#  '2008_miroc5_rcp26_72',
#  '2008_miroc5_rcp26_56',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_62',
#  '2008_miroc5_rcp26_71',
#  '2008_miroc5_rcp26_51',
#  '2008_miroc5_rcp26_54',
#  '2008_miroc5_rcp26_67',
#  '2009_gfdl-esm2m_rcp26_58',
#  '2009_gfdl-esm2m_rcp26_54',
#  '2009_gfdl-esm2m_rcp26_55',
#  '2009_gfdl-esm2m_rcp26_55',
#  '2009_gfdl-esm2m_rcp26_63',
#  '2009_gfdl-esm2m_rcp26_73',
#  '2009_gfdl-esm2m_rcp26_60',
#  '2009_gfdl-esm2m_rcp26_59',
#  '2009_gfdl-esm2m_rcp26_62',
#  '2009_gfdl-esm2m_rcp26_51',
#  '2009_gfdl-esm2m_rcp26_72',
#  '2009_gfdl-esm2m_rcp26_60',
#  '2009_gfdl-esm2m_rcp26_57',
#  '2009_gfdl-esm2m_rcp26_68',
#  '2009_gfdl-esm2m_rcp26_58',
#  '2009_gfdl-esm2m_rcp26_75',
#  '2009_gfdl-esm2m_rcp26_56',
#  '2009_gfdl-esm2m_rcp26_71',
#  '2009_gfdl-esm2m_rcp26_71',
#  '2009_gfdl-esm2m_rcp26_74',
#  '2009_gfdl-esm2m_rcp26_67',
#  '2009_gfdl-esm2m_rcp26_74',
#  '2009_gfdl-esm2m_rcp26_69',
#  '2009_gfdl-esm2m_rcp26_70',
#  '2009_gfdl-esm2m_rcp26_64',
#  '2009_gfdl-esm2m_rcp26_61',
#  '2009_gfdl-esm2m_rcp26_62',
#  '2009_gfdl-esm2m_rcp26_68',
#  '2009_gfdl-esm2m_rcp26_74',
#  '2009_gfdl-esm2m_rcp26_53',
#  '2009_gfdl-esm2m_rcp26_62',
#  '2009_gfdl-esm2m_rcp26_51',
#  '2009_gfdl-esm2m_rcp26_62',
#  '2009_gfdl-esm2m_rcp26_71',
#  '2009_gfdl-esm2m_rcp26_54',
#  '2009_gfdl-esm2m_rcp26_51',
#  '2009_gfdl-esm2m_rcp26_72',
#  '2009_gfdl-esm2m_rcp26_70',
#  '2009_gfdl-esm2m_rcp26_63',
#  '2009_gfdl-esm2m_rcp26_72',
#  '2009_gfdl-esm2m_rcp26_60',
#  '2009_gfdl-esm2m_rcp26_73',
#  '2009_gfdl-esm2m_rcp26_63',
#  '2009_gfdl-esm2m_rcp26_69',
#  '2009_gfdl-esm2m_rcp26_74',
#  '2009_gfdl-esm2m_rcp26_74',
#  '2009_gfdl-esm2m_rcp26_74',
#  '2009_gfdl-esm2m_rcp26_68',
#  '2009_gfdl-esm2m_rcp26_53',
#  '2009_gfdl-esm2m_rcp26_55',
#  '2009_gfdl-esm2m_rcp60_75',
#  '2009_gfdl-esm2m_rcp60_54',
#  '2009_gfdl-esm2m_rcp60_66',
#  '2009_gfdl-esm2m_rcp60_57',
#  '2009_gfdl-esm2m_rcp60_74',
#  '2009_gfdl-esm2m_rcp60_54',
#  '2009_gfdl-esm2m_rcp60_57',
#  '2009_gfdl-esm2m_rcp60_60',
#  '2009_gfdl-esm2m_rcp60_74',
#  '2009_gfdl-esm2m_rcp60_67',
#  '2009_gfdl-esm2m_rcp60_70',
#  '2009_gfdl-esm2m_rcp60_58',
#  '2009_gfdl-esm2m_rcp60_62',
#  '2009_gfdl-esm2m_rcp60_64',
#  '2009_gfdl-esm2m_rcp60_73',
#  '2009_gfdl-esm2m_rcp60_64',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_53',
#  '2009_gfdl-esm2m_rcp60_61',
#  '2009_gfdl-esm2m_rcp60_54',
#  '2009_gfdl-esm2m_rcp60_60',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_63',
#  '2009_gfdl-esm2m_rcp60_73',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_73',
#  '2009_gfdl-esm2m_rcp60_61',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_68',
#  '2009_gfdl-esm2m_rcp60_64',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_71',
#  '2009_gfdl-esm2m_rcp60_51',
#  '2009_gfdl-esm2m_rcp60_65',
#  '2009_gfdl-esm2m_rcp60_70',
#  '2009_gfdl-esm2m_rcp60_56',
#  '2009_gfdl-esm2m_rcp60_68',
#  '2009_gfdl-esm2m_rcp60_71',
#  '2009_gfdl-esm2m_rcp60_56',
#  '2009_gfdl-esm2m_rcp60_67',
#  '2009_gfdl-esm2m_rcp60_63',
#  '2009_gfdl-esm2m_rcp60_63',
#  '2009_gfdl-esm2m_rcp60_73',
#  '2009_gfdl-esm2m_rcp60_51',
#  '2009_gfdl-esm2m_rcp60_75',
#  '2009_gfdl-esm2m_rcp60_57',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_55',
#  '2009_gfdl-esm2m_rcp60_57',
#  '2009_gfdl-esm2m_rcp60_63',
#  '2009_hadgem2-es_rcp26_66',
#  '2009_hadgem2-es_rcp26_72',
#  '2009_hadgem2-es_rcp26_70',
#  '2009_hadgem2-es_rcp26_51',
#  '2009_hadgem2-es_rcp26_60',
#  '2009_hadgem2-es_rcp26_53',
#  '2009_hadgem2-es_rcp26_73',
#  '2009_hadgem2-es_rcp26_62',
#  '2009_hadgem2-es_rcp26_52',
#  '2009_hadgem2-es_rcp26_62',
#  '2009_hadgem2-es_rcp26_54',
#  '2009_hadgem2-es_rcp26_63',
#  '2009_hadgem2-es_rcp26_54',
#  '2009_hadgem2-es_rcp26_67',
#  '2009_hadgem2-es_rcp26_62',
#  '2009_hadgem2-es_rcp26_75',
#  '2009_hadgem2-es_rcp26_73',
#  '2009_hadgem2-es_rcp26_67',
#  '2009_hadgem2-es_rcp26_64',
#  '2009_hadgem2-es_rcp26_68',
#  '2009_hadgem2-es_rcp26_73',
#  '2009_hadgem2-es_rcp26_61',
#  '2009_hadgem2-es_rcp26_65',
#  '2009_hadgem2-es_rcp26_71',
#  '2009_hadgem2-es_rcp26_58',
#  '2009_hadgem2-es_rcp26_52',
#  '2009_hadgem2-es_rcp26_69',
#  '2009_hadgem2-es_rcp26_51',
#  '2009_hadgem2-es_rcp26_65',
#  '2009_hadgem2-es_rcp26_68',
#  '2009_hadgem2-es_rcp26_72',
#  '2009_hadgem2-es_rcp26_55',
#  '2009_hadgem2-es_rcp26_71',
#  '2009_hadgem2-es_rcp26_72',
#  '2009_hadgem2-es_rcp26_67',
#  '2009_hadgem2-es_rcp26_71',
#  '2009_hadgem2-es_rcp26_62',
#  '2009_hadgem2-es_rcp26_68',
#  '2009_hadgem2-es_rcp26_65',
#  '2009_hadgem2-es_rcp26_55',
#  '2009_hadgem2-es_rcp26_59',
#  '2009_hadgem2-es_rcp26_73',
#  '2009_hadgem2-es_rcp26_67',
#  '2009_hadgem2-es_rcp26_65',
#  '2009_hadgem2-es_rcp26_53',
#  '2009_hadgem2-es_rcp26_66',
#  '2009_hadgem2-es_rcp26_60',
#  '2009_hadgem2-es_rcp26_56',
#  '2009_hadgem2-es_rcp26_55',
#  '2009_hadgem2-es_rcp26_74',
#  '2009_hadgem2-es_rcp60_59',
#  '2009_hadgem2-es_rcp60_58',
#  '2009_hadgem2-es_rcp60_71',
#  '2009_hadgem2-es_rcp60_67',
#  '2009_hadgem2-es_rcp60_64',
#  '2009_hadgem2-es_rcp60_63',
#  '2009_hadgem2-es_rcp60_55',
#  '2009_hadgem2-es_rcp60_67',
#  '2009_hadgem2-es_rcp60_67',
#  '2009_hadgem2-es_rcp60_68',
#  '2009_hadgem2-es_rcp60_56',
#  '2009_hadgem2-es_rcp60_58',
#  '2009_hadgem2-es_rcp60_55',
#  '2009_hadgem2-es_rcp60_52',
#  '2009_hadgem2-es_rcp60_73',
#  '2009_hadgem2-es_rcp60_68',
#  '2009_hadgem2-es_rcp60_70',
#  '2009_hadgem2-es_rcp60_69',
#  '2009_hadgem2-es_rcp60_56',
#  '2009_hadgem2-es_rcp60_74',
#  '2009_hadgem2-es_rcp60_55',
#  '2009_hadgem2-es_rcp60_58',
#  '2009_hadgem2-es_rcp60_51',
#  '2009_hadgem2-es_rcp60_56',
#  '2009_hadgem2-es_rcp60_74',
#  '2009_hadgem2-es_rcp60_65',
#  '2009_hadgem2-es_rcp60_69',
#  '2009_hadgem2-es_rcp60_55',
#  '2009_hadgem2-es_rcp60_72',
#  '2009_hadgem2-es_rcp60_74',
#  '2009_hadgem2-es_rcp60_65',
#  '2009_hadgem2-es_rcp60_68',
#  '2009_hadgem2-es_rcp60_74',
#  '2009_hadgem2-es_rcp60_66',
#  '2009_hadgem2-es_rcp60_71',
#  '2009_hadgem2-es_rcp60_72',
#  '2009_hadgem2-es_rcp60_53',
#  '2009_hadgem2-es_rcp60_54',
#  '2009_hadgem2-es_rcp60_71',
#  '2009_hadgem2-es_rcp60_59',
#  '2009_hadgem2-es_rcp60_71',
#  '2009_hadgem2-es_rcp60_75',
#  '2009_hadgem2-es_rcp60_64',
#  '2009_hadgem2-es_rcp60_53',
#  '2009_hadgem2-es_rcp60_71',
#  '2009_hadgem2-es_rcp60_54',
#  '2009_hadgem2-es_rcp60_55',
#  '2009_hadgem2-es_rcp60_60',
#  '2009_hadgem2-es_rcp60_53',
#  '2009_hadgem2-es_rcp60_75',
#  '2009_miroc5_rcp26_71',
#  '2009_miroc5_rcp26_64',
#  '2009_miroc5_rcp26_65',
#  '2009_miroc5_rcp26_52',
#  '2009_miroc5_rcp26_58',
#  '2009_miroc5_rcp26_52',
#  '2009_miroc5_rcp26_65',
#  '2009_miroc5_rcp26_61',
#  '2009_miroc5_rcp26_73',
#  '2009_miroc5_rcp26_68',
#  '2009_miroc5_rcp26_70',
#  '2009_miroc5_rcp26_62',
#  '2009_miroc5_rcp26_52',
#  '2009_miroc5_rcp26_57',
#  '2009_miroc5_rcp26_58',
#  '2009_miroc5_rcp26_72',
#  '2009_miroc5_rcp26_59',
#  '2009_miroc5_rcp26_53',
#  '2009_miroc5_rcp26_73',
#  '2009_miroc5_rcp26_67',
#  '2009_miroc5_rcp26_70',
#  '2009_miroc5_rcp26_58',
#  '2009_miroc5_rcp26_58',
#  '2009_miroc5_rcp26_65',
#  '2009_miroc5_rcp26_53',
#  '2009_miroc5_rcp26_56',
#  '2009_miroc5_rcp26_57',
#  '2009_miroc5_rcp26_66',
#  '2009_miroc5_rcp26_55',
#  '2009_miroc5_rcp26_57',
#  '2009_miroc5_rcp26_55',
#  '2009_miroc5_rcp26_52',
#  '2009_miroc5_rcp26_62',
#  '2009_miroc5_rcp26_57',
#  '2009_miroc5_rcp26_70',
#  '2009_miroc5_rcp26_55',
#  '2009_miroc5_rcp26_55',
#  '2009_miroc5_rcp26_73',
#  '2009_miroc5_rcp26_71',
#  '2009_miroc5_rcp26_62',
#  '2009_miroc5_rcp26_75',
#  '2009_miroc5_rcp26_54',
#  '2009_miroc5_rcp26_62',
#  '2009_miroc5_rcp26_67',
#  '2009_miroc5_rcp26_61',
#  '2009_miroc5_rcp26_59',
#  '2009_miroc5_rcp26_51',
#  '2009_miroc5_rcp26_56',
#  '2009_miroc5_rcp26_55',
#  '2009_miroc5_rcp26_74',
#  ...]

# %%
plt.scatter(impacts_yearsets['1']['assets']['TC'].at_event, impacts_yearsets['1']['assets']['RF'].at_event)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 plt.scatter(impacts_yearsets['1']['assets']['TC'].at_event, impacts_yearsets['1']['assets']['RF'].at_event)
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(impacts_yearsets['2']['assets']['TC'].at_event, impacts_yearsets['2']['assets']['RF'].at_event)

# %%
from sklearn.utils import shuffle
import numpy as np



def order_events_by_indices(impact, indices):
    """
    Order event names based on given strings contained in the event names.

    ----------
    impact: Impact
        with event_name based on the given strings
    n_events: Int
        Number of events in the output. Default: 1
    list_string : list
        A list of string based on which to order the events.
        For example climate models ['miroc5','ipsl-cm5a-lr','gfdl-esm2m','hadgem2-es']
        default is None


    Raises
    ------
    AttributeError
        If no list is providing

    Returns
    -------
    impact : Impact
        Impact yearset.

    """
    impact_ordered = Impact()
    if impact_ordered.imp_mat.shape[0]>0:   
        impact_ordered.imp_mat = impact.imp_mat[indices]
    
    impact_ordered.event_name = [impact.event_name[index] for index in indices]
    impact_ordered.event_id = np.arange(len(impact_ordered.event_name))
    frequency = impact.frequency[indices]
    impact_ordered.frequency = frequency*(len(impact.event_id)/len(impact_ordered.event_id))
    impact_ordered.at_event = impact.at_event[indices]
    impact_ordered.aai_agg = np.median(impact_ordered.at_event)
    impact_ordered.coord_exp = impact.coord_exp
    impact_ordered.date = impact.date[indices]
    return impact_ordered

# %%
def order_events_by_indices(impact, indices):
    """
    Order event names based on given strings contained in the event names.

    Parameters
    ----------
    impact: Impact
        with event_name based on the given strings
    n_events: Int
        Number of events in the output. Default: 1
    list_string : list
        A list of string based on which to order the events.
        For example climate models ['miroc5','ipsl-cm5a-lr','gfdl-esm2m','hadgem2-es']
        default is None


    Raises
    ------
    AttributeError
        If no list is providing

    Returns
    -------
    impact : Impact
        Impact yearset.

    """
    impact_ordered = Impact()
    if impact_ordered.imp_mat.shape[0]>0:   
        impact_ordered.imp_mat = impact.imp_mat[indices]
    
    impact_ordered.event_name = [impact.event_name[index] for index in indices]
    impact_ordered.event_id = np.arange(len(impact_ordered.event_name))
    frequency = impact.frequency[indices]
    impact_ordered.frequency = frequency*(len(impact.event_id)/len(impact_ordered.event_id))
    impact_ordered.at_event = impact.at_event[indices]
    impact_ordered.aai_agg = np.median(impact_ordered.at_event)
    impact_ordered.coord_exp = impact.coord_exp
    impact_ordered.date = impact.date[indices]
    return impact_ordered

fq = impacts_yearsets['1']['assets']['RF'].calc_freq_curve(return_per=np.arange(1,100))
#fq.impact = fq.impact + impacts_yearsets['1980_2010']['assets']['TC'].calc_freq_curve(return_per=np.arange(1,100)).impact

import matplotlib.pyplot as plt
import numpy as np

def make_fq_list(impact, factor):
    fq_list = []
    for n in range(1000):
        imp_sample = order_events_by_indices(impact, shuffle(np.arange(len(impact.event_name)))[0:500])
        fq = imp_sample.calc_freq_curve(np.arange(0,100))
        fq_list.append(fq.impact/factor)
    return fq_list, fq.return_per

def plot_return_period_samples(fq_list, return_per, ax, color, label, range=True, linestyle="solid"):
    ax.plot(fq.return_per,np.median(fq_list,axis=0), color=color, label=label, linestyle=linestyle)
    ax.legend()
    if range:
        ax.fill_between(fq.return_per,np.median(fq_list,axis=0),np.percentile(fq_list,q=95,axis=0), color=color, alpha=0.3)
        ax.fill_between(fq.return_per,np.percentile(fq_list,q=5,axis=0), np.median(fq_list,axis=0),color=color, alpha=0.3)
    return ax

# %%
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np

fq_single_hazard = {}
aai_single_hazard = {}

y100_single_hazard = {}



colors = {'1':'lightblue', '2':'plum', '3':'black'}
factor_dict = {"assets":1e9, "pop":1e6}
ylabel = {"assets":"Impact (Billion USD)","pop":"Impact (Million people affected)"}


for exposure in ["assets", "pop"]:
    fig,ax = plt.subplots(figsize=(5.4,4))

    fq_list, fq.return_per =  make_fq_list(impact_combined_ordered['1'][exposure][('TC', 'RF')],  factor=factor_dict[exposure])
    plot_return_period_samples(fq_list, fq.return_per, ax, color="Violet", label="1$^\circ$C", range=True)

    fq_list_rf, fq.return_per =  make_fq_list(impact_combined_ordered['2'][exposure][('TC', 'RF')], factor=factor_dict[exposure])
    plot_return_period_samples(fq_list_rf, fq.return_per, ax, color="black", label="2$^\circ$C", range=True)

#         fq_list_rf, fq.return_per =  make_fq_list(impact_combined_ordered['3'][exposure][('TC', 'RF')])
#         plot_return_period_samples(fq_list_rf, fq.return_per, ax, color="gray", label="3", range=True)


    #ax.set_ylabel(ylabel[exposure])
    ax.set_xlabel("Return period (Year)")
    
    ax.set_ylabel(ylabel[exposure])

    plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report_SI/figures/compound_ordered_cc_'+exposure+'.pdf', bbox_inches='tight')

    #ax.set_title(" ".join([haz, exposure]))

# %%
fig, ax = plt.subplots()
for n in range(100):
    indice = shuffle(np.arange(5000))[0:400]
    imp_ord_tc = order_events_by_indices(impacts_yearsets[warming][exp]['TC'], indice)
    imp_ord_rf = order_events_by_indices(impacts_yearsets[warming][exp]['RF'], indice)
    p = np.percentile(imp_ord_tc.at_event,0)
    ax.scatter(imp_ord_tc.at_event[imp_ord_tc.at_event>p], imp_ord_rf.at_event[imp_ord_tc.at_event>p], alpha=0.05,color='blue')




fig, ax = plt.subplots()
for n in range(100):
    indice = shuffle(np.arange(5000))[0:400]
    imp_ord_tc = order_events_by_indices(impacts_yearsets[warming][exp]['TC'], indice)
    indice = shuffle(np.arange(5000))[0:400]
    imp_ord_rf = order_events_by_indices(impacts_yearsets[warming][exp]['RF'], indice)
    p = np.percentile(imp_ord_tc.at_event,0)
    ax.scatter(imp_ord_tc.at_event[imp_ord_tc.at_event>p], imp_ord_rf.at_event[imp_ord_tc.at_event>p], alpha=0.05, color='blue')

# %%
p
# Out:
# 42580418759.12401

# %%
impact_combined[warming][exposure][('TC', 'RF')].event_name
# Out:
# ['2019_ipsl-cm5a-lr_rcp60_15',
#  '2019_ipsl-cm5a-lr_rcp60_2',
#  '2019_ipsl-cm5a-lr_rcp60_1',
#  '2019_ipsl-cm5a-lr_rcp26_15',
#  '2019_ipsl-cm5a-lr_rcp26_13',
#  '2019_ipsl-cm5a-lr_rcp60_7',
#  '2019_ipsl-cm5a-lr_rcp60_13',
#  '2019_ipsl-cm5a-lr_rcp26_3',
#  '2019_ipsl-cm5a-lr_rcp60_24',
#  '2019_ipsl-cm5a-lr_rcp26_10',
#  '2019_ipsl-cm5a-lr_rcp60_24',
#  '2019_ipsl-cm5a-lr_rcp26_8',
#  '2019_ipsl-cm5a-lr_rcp60_2',
#  '2019_ipsl-cm5a-lr_rcp26_23',
#  '2019_ipsl-cm5a-lr_rcp60_12',
#  '2019_ipsl-cm5a-lr_rcp26_18',
#  '2019_ipsl-cm5a-lr_rcp60_0',
#  '2019_ipsl-cm5a-lr_rcp60_17',
#  '2019_ipsl-cm5a-lr_rcp26_22',
#  '2019_ipsl-cm5a-lr_rcp60_19',
#  '2019_ipsl-cm5a-lr_rcp60_20',
#  '2019_ipsl-cm5a-lr_rcp60_18',
#  '2019_ipsl-cm5a-lr_rcp60_8',
#  '2019_ipsl-cm5a-lr_rcp26_6',
#  '2019_ipsl-cm5a-lr_rcp60_24',
#  '2019_ipsl-cm5a-lr_rcp60_22',
#  '2019_ipsl-cm5a-lr_rcp26_13',
#  '2019_ipsl-cm5a-lr_rcp60_23',
#  '2019_ipsl-cm5a-lr_rcp60_1',
#  '2019_ipsl-cm5a-lr_rcp60_22',
#  '2019_ipsl-cm5a-lr_rcp60_16',
#  '2019_ipsl-cm5a-lr_rcp26_15',
#  '2019_ipsl-cm5a-lr_rcp60_4',
#  '2019_ipsl-cm5a-lr_rcp60_22',
#  '2019_ipsl-cm5a-lr_rcp60_8',
#  '2019_ipsl-cm5a-lr_rcp60_18',
#  '2019_ipsl-cm5a-lr_rcp60_15',
#  '2019_ipsl-cm5a-lr_rcp26_3',
#  '2019_ipsl-cm5a-lr_rcp60_21',
#  '2019_ipsl-cm5a-lr_rcp60_10',
#  '2019_ipsl-cm5a-lr_rcp26_8',
#  '2019_ipsl-cm5a-lr_rcp60_14',
#  '2019_ipsl-cm5a-lr_rcp60_15',
#  '2019_ipsl-cm5a-lr_rcp26_8',
#  '2019_ipsl-cm5a-lr_rcp60_15',
#  '2019_ipsl-cm5a-lr_rcp60_5',
#  '2019_ipsl-cm5a-lr_rcp26_1',
#  '2019_ipsl-cm5a-lr_rcp60_17',
#  '2019_ipsl-cm5a-lr_rcp60_10',
#  '2019_ipsl-cm5a-lr_rcp60_12',
#  '2019_ipsl-cm5a-lr_rcp26_15',
#  '2019_ipsl-cm5a-lr_rcp60_13',
#  '2019_ipsl-cm5a-lr_rcp60_8',
#  '2019_ipsl-cm5a-lr_rcp60_23',
#  '2019_ipsl-cm5a-lr_rcp26_18',
#  '2019_ipsl-cm5a-lr_rcp26_3',
#  '2019_ipsl-cm5a-lr_rcp26_8',
#  '2019_ipsl-cm5a-lr_rcp60_14',
#  '2019_ipsl-cm5a-lr_rcp60_11',
#  '2019_ipsl-cm5a-lr_rcp26_18',
#  '2019_ipsl-cm5a-lr_rcp60_3',
#  '2019_ipsl-cm5a-lr_rcp60_17',
#  '2019_ipsl-cm5a-lr_rcp26_15',
#  '2019_ipsl-cm5a-lr_rcp60_3',
#  '2019_ipsl-cm5a-lr_rcp26_1',
#  '2019_ipsl-cm5a-lr_rcp60_21',
#  '2019_ipsl-cm5a-lr_rcp26_5',
#  '2019_ipsl-cm5a-lr_rcp26_15',
#  '2019_ipsl-cm5a-lr_rcp60_16',
#  '2019_ipsl-cm5a-lr_rcp60_14',
#  '2019_ipsl-cm5a-lr_rcp26_1',
#  '2019_ipsl-cm5a-lr_rcp60_6',
#  '2019_ipsl-cm5a-lr_rcp26_22',
#  '2019_ipsl-cm5a-lr_rcp26_22',
#  '2019_ipsl-cm5a-lr_rcp26_6',
#  '2019_ipsl-cm5a-lr_rcp60_10',
#  '2019_ipsl-cm5a-lr_rcp60_24',
#  '2019_ipsl-cm5a-lr_rcp60_24',
#  '2019_ipsl-cm5a-lr_rcp26_19',
#  '2019_ipsl-cm5a-lr_rcp26_19',
#  '2020_ipsl-cm5a-lr_rcp26_21',
#  '2020_ipsl-cm5a-lr_rcp60_23',
#  '2020_ipsl-cm5a-lr_rcp60_5',
#  '2020_ipsl-cm5a-lr_rcp26_9',
#  '2020_ipsl-cm5a-lr_rcp60_7',
#  '2020_ipsl-cm5a-lr_rcp26_20',
#  '2020_ipsl-cm5a-lr_rcp60_12',
#  '2020_ipsl-cm5a-lr_rcp26_6',
#  '2020_ipsl-cm5a-lr_rcp26_21',
#  '2020_ipsl-cm5a-lr_rcp60_8',
#  '2020_ipsl-cm5a-lr_rcp26_13',
#  '2020_ipsl-cm5a-lr_rcp26_19',
#  '2020_ipsl-cm5a-lr_rcp60_8',
#  '2020_ipsl-cm5a-lr_rcp60_22',
#  '2020_ipsl-cm5a-lr_rcp26_4',
#  '2020_ipsl-cm5a-lr_rcp60_17',
#  '2020_ipsl-cm5a-lr_rcp26_15',
#  '2020_ipsl-cm5a-lr_rcp60_5',
#  '2020_ipsl-cm5a-lr_rcp26_14',
#  '2020_ipsl-cm5a-lr_rcp26_9',
#  '2020_ipsl-cm5a-lr_rcp60_24',
#  '2020_ipsl-cm5a-lr_rcp60_5',
#  '2020_ipsl-cm5a-lr_rcp26_9',
#  '2020_ipsl-cm5a-lr_rcp60_10',
#  '2020_ipsl-cm5a-lr_rcp26_12',
#  '2020_ipsl-cm5a-lr_rcp26_0',
#  '2020_ipsl-cm5a-lr_rcp60_14',
#  '2020_ipsl-cm5a-lr_rcp26_10',
#  '2020_ipsl-cm5a-lr_rcp26_5',
#  '2020_ipsl-cm5a-lr_rcp60_11',
#  '2020_ipsl-cm5a-lr_rcp26_23',
#  '2020_ipsl-cm5a-lr_rcp26_12',
#  '2020_ipsl-cm5a-lr_rcp26_16',
#  '2020_ipsl-cm5a-lr_rcp26_2',
#  '2020_ipsl-cm5a-lr_rcp26_7',
#  '2020_ipsl-cm5a-lr_rcp26_14',
#  '2020_ipsl-cm5a-lr_rcp26_9',
#  '2020_ipsl-cm5a-lr_rcp60_19',
#  '2020_ipsl-cm5a-lr_rcp26_18',
#  '2020_ipsl-cm5a-lr_rcp60_24',
#  '2020_ipsl-cm5a-lr_rcp26_2',
#  '2020_ipsl-cm5a-lr_rcp60_24',
#  '2020_ipsl-cm5a-lr_rcp26_11',
#  '2020_ipsl-cm5a-lr_rcp60_4',
#  '2020_ipsl-cm5a-lr_rcp60_0',
#  '2020_ipsl-cm5a-lr_rcp26_15',
#  '2020_ipsl-cm5a-lr_rcp26_19',
#  '2020_ipsl-cm5a-lr_rcp26_16',
#  '2020_ipsl-cm5a-lr_rcp26_6',
#  '2020_ipsl-cm5a-lr_rcp26_24',
#  '2020_ipsl-cm5a-lr_rcp26_2',
#  '2020_ipsl-cm5a-lr_rcp26_17',
#  '2020_ipsl-cm5a-lr_rcp26_6',
#  '2020_ipsl-cm5a-lr_rcp26_21',
#  '2020_ipsl-cm5a-lr_rcp60_7',
#  '2020_ipsl-cm5a-lr_rcp26_6',
#  '2020_ipsl-cm5a-lr_rcp26_13',
#  '2020_ipsl-cm5a-lr_rcp26_16',
#  '2020_ipsl-cm5a-lr_rcp60_18',
#  '2020_ipsl-cm5a-lr_rcp26_0',
#  '2020_ipsl-cm5a-lr_rcp26_20',
#  '2020_ipsl-cm5a-lr_rcp26_15',
#  '2020_ipsl-cm5a-lr_rcp26_0',
#  '2020_ipsl-cm5a-lr_rcp60_23',
#  '2020_ipsl-cm5a-lr_rcp60_0',
#  '2020_ipsl-cm5a-lr_rcp60_2',
#  '2020_ipsl-cm5a-lr_rcp60_8',
#  '2020_ipsl-cm5a-lr_rcp60_24',
#  '2020_ipsl-cm5a-lr_rcp60_13',
#  '2020_ipsl-cm5a-lr_rcp26_16',
#  '2020_ipsl-cm5a-lr_rcp60_9',
#  '2020_ipsl-cm5a-lr_rcp60_4',
#  '2020_ipsl-cm5a-lr_rcp26_17',
#  '2020_ipsl-cm5a-lr_rcp26_21',
#  '2020_ipsl-cm5a-lr_rcp60_1',
#  '2020_ipsl-cm5a-lr_rcp26_17',
#  '2020_ipsl-cm5a-lr_rcp60_19',
#  '2020_ipsl-cm5a-lr_rcp60_5',
#  '2020_ipsl-cm5a-lr_rcp60_9',
#  '2020_ipsl-cm5a-lr_rcp26_23',
#  '2021_ipsl-cm5a-lr_rcp26_1',
#  '2021_ipsl-cm5a-lr_rcp26_10',
#  '2021_ipsl-cm5a-lr_rcp26_0',
#  '2021_ipsl-cm5a-lr_rcp60_3',
#  '2021_ipsl-cm5a-lr_rcp26_5',
#  '2021_ipsl-cm5a-lr_rcp60_17',
#  '2021_ipsl-cm5a-lr_rcp26_13',
#  '2021_ipsl-cm5a-lr_rcp26_10',
#  '2021_ipsl-cm5a-lr_rcp26_5',
#  '2021_ipsl-cm5a-lr_rcp60_18',
#  '2021_ipsl-cm5a-lr_rcp26_7',
#  '2021_ipsl-cm5a-lr_rcp26_1',
#  '2021_ipsl-cm5a-lr_rcp60_8',
#  '2021_ipsl-cm5a-lr_rcp60_11',
#  '2021_ipsl-cm5a-lr_rcp60_5',
#  '2021_ipsl-cm5a-lr_rcp60_3',
#  '2021_ipsl-cm5a-lr_rcp26_14',
#  '2021_ipsl-cm5a-lr_rcp60_20',
#  '2021_ipsl-cm5a-lr_rcp60_6',
#  '2021_ipsl-cm5a-lr_rcp26_4',
#  '2021_ipsl-cm5a-lr_rcp26_11',
#  '2021_ipsl-cm5a-lr_rcp26_12',
#  '2021_ipsl-cm5a-lr_rcp60_10',
#  '2021_ipsl-cm5a-lr_rcp26_8',
#  '2021_ipsl-cm5a-lr_rcp60_20',
#  '2021_ipsl-cm5a-lr_rcp26_3',
#  '2021_ipsl-cm5a-lr_rcp26_6',
#  '2021_ipsl-cm5a-lr_rcp60_5',
#  '2021_ipsl-cm5a-lr_rcp60_9',
#  '2021_ipsl-cm5a-lr_rcp26_15',
#  '2021_ipsl-cm5a-lr_rcp26_22',
#  '2021_ipsl-cm5a-lr_rcp60_13',
#  '2021_ipsl-cm5a-lr_rcp60_16',
#  '2021_ipsl-cm5a-lr_rcp60_2',
#  '2021_ipsl-cm5a-lr_rcp26_8',
#  '2021_ipsl-cm5a-lr_rcp60_14',
#  '2021_ipsl-cm5a-lr_rcp26_23',
#  '2021_ipsl-cm5a-lr_rcp60_9',
#  '2021_ipsl-cm5a-lr_rcp26_3',
#  '2021_ipsl-cm5a-lr_rcp60_13',
#  '2021_ipsl-cm5a-lr_rcp26_24',
#  '2021_ipsl-cm5a-lr_rcp60_2',
#  '2021_ipsl-cm5a-lr_rcp60_15',
#  '2021_ipsl-cm5a-lr_rcp60_0',
#  '2021_ipsl-cm5a-lr_rcp26_6',
#  '2021_ipsl-cm5a-lr_rcp26_8',
#  '2021_ipsl-cm5a-lr_rcp60_17',
#  '2021_ipsl-cm5a-lr_rcp26_8',
#  '2021_ipsl-cm5a-lr_rcp26_23',
#  '2021_ipsl-cm5a-lr_rcp26_19',
#  '2021_ipsl-cm5a-lr_rcp60_8',
#  '2021_ipsl-cm5a-lr_rcp60_16',
#  '2021_ipsl-cm5a-lr_rcp26_8',
#  '2021_ipsl-cm5a-lr_rcp60_1',
#  '2021_ipsl-cm5a-lr_rcp60_10',
#  '2021_ipsl-cm5a-lr_rcp60_1',
#  '2021_ipsl-cm5a-lr_rcp60_2',
#  '2021_ipsl-cm5a-lr_rcp60_8',
#  '2021_ipsl-cm5a-lr_rcp60_12',
#  '2021_ipsl-cm5a-lr_rcp60_4',
#  '2021_ipsl-cm5a-lr_rcp60_12',
#  '2021_ipsl-cm5a-lr_rcp26_24',
#  '2021_ipsl-cm5a-lr_rcp60_13',
#  '2021_ipsl-cm5a-lr_rcp26_16',
#  '2021_ipsl-cm5a-lr_rcp26_9',
#  '2021_ipsl-cm5a-lr_rcp26_4',
#  '2021_ipsl-cm5a-lr_rcp60_21',
#  '2021_ipsl-cm5a-lr_rcp60_1',
#  '2021_ipsl-cm5a-lr_rcp26_12',
#  '2021_ipsl-cm5a-lr_rcp26_6',
#  '2021_ipsl-cm5a-lr_rcp26_1',
#  '2021_ipsl-cm5a-lr_rcp26_8',
#  '2021_ipsl-cm5a-lr_rcp26_9',
#  '2021_ipsl-cm5a-lr_rcp60_17',
#  '2021_ipsl-cm5a-lr_rcp60_7',
#  '2021_ipsl-cm5a-lr_rcp60_11',
#  '2021_ipsl-cm5a-lr_rcp26_23',
#  '2021_ipsl-cm5a-lr_rcp60_2',
#  '2021_ipsl-cm5a-lr_rcp26_23',
#  '2021_ipsl-cm5a-lr_rcp26_15',
#  '2022_ipsl-cm5a-lr_rcp26_15',
#  '2022_ipsl-cm5a-lr_rcp60_11',
#  '2022_ipsl-cm5a-lr_rcp60_1',
#  '2022_ipsl-cm5a-lr_rcp60_21',
#  '2022_ipsl-cm5a-lr_rcp26_12',
#  '2022_ipsl-cm5a-lr_rcp26_4',
#  '2022_ipsl-cm5a-lr_rcp60_10',
#  '2022_ipsl-cm5a-lr_rcp26_19',
#  '2022_ipsl-cm5a-lr_rcp60_14',
#  '2022_ipsl-cm5a-lr_rcp26_17',
#  '2022_ipsl-cm5a-lr_rcp60_3',
#  '2022_ipsl-cm5a-lr_rcp26_16',
#  '2022_ipsl-cm5a-lr_rcp60_10',
#  '2022_ipsl-cm5a-lr_rcp26_5',
#  '2022_ipsl-cm5a-lr_rcp26_15',
#  '2022_ipsl-cm5a-lr_rcp26_13',
#  '2022_ipsl-cm5a-lr_rcp26_0',
#  '2022_ipsl-cm5a-lr_rcp26_10',
#  '2022_ipsl-cm5a-lr_rcp26_13',
#  '2022_ipsl-cm5a-lr_rcp60_1',
#  '2022_ipsl-cm5a-lr_rcp26_14',
#  '2022_ipsl-cm5a-lr_rcp26_4',
#  '2022_ipsl-cm5a-lr_rcp60_1',
#  '2022_ipsl-cm5a-lr_rcp26_11',
#  '2022_ipsl-cm5a-lr_rcp60_17',
#  '2022_ipsl-cm5a-lr_rcp26_19',
#  '2022_ipsl-cm5a-lr_rcp60_0',
#  '2022_ipsl-cm5a-lr_rcp26_9',
#  '2022_ipsl-cm5a-lr_rcp26_15',
#  '2022_ipsl-cm5a-lr_rcp60_20',
#  '2022_ipsl-cm5a-lr_rcp26_11',
#  '2022_ipsl-cm5a-lr_rcp26_17',
#  '2022_ipsl-cm5a-lr_rcp60_6',
#  '2022_ipsl-cm5a-lr_rcp60_18',
#  '2022_ipsl-cm5a-lr_rcp26_5',
#  '2022_ipsl-cm5a-lr_rcp26_18',
#  '2022_ipsl-cm5a-lr_rcp60_19',
#  '2022_ipsl-cm5a-lr_rcp60_19',
#  '2022_ipsl-cm5a-lr_rcp26_23',
#  '2022_ipsl-cm5a-lr_rcp60_15',
#  '2022_ipsl-cm5a-lr_rcp26_17',
#  '2022_ipsl-cm5a-lr_rcp26_19',
#  '2022_ipsl-cm5a-lr_rcp26_9',
#  '2022_ipsl-cm5a-lr_rcp26_22',
#  '2022_ipsl-cm5a-lr_rcp60_14',
#  '2022_ipsl-cm5a-lr_rcp60_15',
#  '2022_ipsl-cm5a-lr_rcp26_14',
#  '2022_ipsl-cm5a-lr_rcp60_6',
#  '2022_ipsl-cm5a-lr_rcp26_11',
#  '2022_ipsl-cm5a-lr_rcp26_5',
#  '2022_ipsl-cm5a-lr_rcp26_14',
#  '2022_ipsl-cm5a-lr_rcp26_2',
#  '2022_ipsl-cm5a-lr_rcp60_2',
#  '2022_ipsl-cm5a-lr_rcp26_2',
#  '2022_ipsl-cm5a-lr_rcp26_23',
#  '2022_ipsl-cm5a-lr_rcp60_2',
#  '2022_ipsl-cm5a-lr_rcp26_2',
#  '2022_ipsl-cm5a-lr_rcp26_15',
#  '2022_ipsl-cm5a-lr_rcp26_1',
#  '2022_ipsl-cm5a-lr_rcp60_10',
#  '2022_ipsl-cm5a-lr_rcp26_19',
#  '2022_ipsl-cm5a-lr_rcp26_20',
#  '2022_ipsl-cm5a-lr_rcp60_1',
#  '2022_ipsl-cm5a-lr_rcp26_4',
#  '2022_ipsl-cm5a-lr_rcp26_7',
#  '2022_ipsl-cm5a-lr_rcp26_15',
#  '2022_ipsl-cm5a-lr_rcp60_2',
#  '2022_ipsl-cm5a-lr_rcp60_11',
#  '2022_ipsl-cm5a-lr_rcp60_10',
#  '2022_ipsl-cm5a-lr_rcp60_18',
#  '2022_ipsl-cm5a-lr_rcp26_1',
#  '2022_ipsl-cm5a-lr_rcp60_1',
#  '2022_ipsl-cm5a-lr_rcp26_3',
#  '2022_ipsl-cm5a-lr_rcp60_16',
#  '2022_ipsl-cm5a-lr_rcp26_22',
#  '2022_ipsl-cm5a-lr_rcp26_6',
#  '2022_ipsl-cm5a-lr_rcp60_4',
#  '2022_ipsl-cm5a-lr_rcp60_8',
#  '2022_ipsl-cm5a-lr_rcp60_6',
#  '2022_ipsl-cm5a-lr_rcp60_19',
#  '2023_ipsl-cm5a-lr_rcp26_5',
#  '2023_ipsl-cm5a-lr_rcp60_20',
#  '2023_ipsl-cm5a-lr_rcp60_3',
#  '2023_ipsl-cm5a-lr_rcp60_9',
#  '2023_ipsl-cm5a-lr_rcp26_23',
#  '2023_ipsl-cm5a-lr_rcp60_3',
#  '2023_ipsl-cm5a-lr_rcp60_18',
#  '2023_ipsl-cm5a-lr_rcp60_23',
#  '2023_ipsl-cm5a-lr_rcp60_18',
#  '2023_ipsl-cm5a-lr_rcp60_22',
#  '2023_ipsl-cm5a-lr_rcp60_15',
#  '2023_ipsl-cm5a-lr_rcp26_6',
#  '2023_ipsl-cm5a-lr_rcp26_1',
#  '2023_ipsl-cm5a-lr_rcp60_7',
#  '2023_ipsl-cm5a-lr_rcp26_23',
#  '2023_ipsl-cm5a-lr_rcp26_18',
#  '2023_ipsl-cm5a-lr_rcp26_8',
#  '2023_ipsl-cm5a-lr_rcp60_5',
#  '2023_ipsl-cm5a-lr_rcp26_10',
#  '2023_ipsl-cm5a-lr_rcp60_12',
#  '2023_ipsl-cm5a-lr_rcp60_23',
#  '2023_ipsl-cm5a-lr_rcp60_20',
#  '2023_ipsl-cm5a-lr_rcp26_19',
#  '2023_ipsl-cm5a-lr_rcp60_8',
#  '2023_ipsl-cm5a-lr_rcp26_13',
#  '2023_ipsl-cm5a-lr_rcp60_2',
#  '2023_ipsl-cm5a-lr_rcp60_15',
#  '2023_ipsl-cm5a-lr_rcp26_16',
#  '2023_ipsl-cm5a-lr_rcp26_2',
#  '2023_ipsl-cm5a-lr_rcp60_8',
#  '2023_ipsl-cm5a-lr_rcp26_21',
#  '2023_ipsl-cm5a-lr_rcp26_7',
#  '2023_ipsl-cm5a-lr_rcp60_15',
#  '2023_ipsl-cm5a-lr_rcp26_24',
#  '2023_ipsl-cm5a-lr_rcp60_23',
#  '2023_ipsl-cm5a-lr_rcp26_14',
#  '2023_ipsl-cm5a-lr_rcp60_17',
#  '2023_ipsl-cm5a-lr_rcp26_4',
#  '2023_ipsl-cm5a-lr_rcp60_7',
#  '2023_ipsl-cm5a-lr_rcp60_0',
#  '2023_ipsl-cm5a-lr_rcp60_23',
#  '2023_ipsl-cm5a-lr_rcp60_13',
#  '2023_ipsl-cm5a-lr_rcp26_12',
#  '2023_ipsl-cm5a-lr_rcp26_21',
#  '2023_ipsl-cm5a-lr_rcp26_3',
#  '2023_ipsl-cm5a-lr_rcp26_13',
#  '2023_ipsl-cm5a-lr_rcp60_12',
#  '2023_ipsl-cm5a-lr_rcp26_12',
#  '2023_ipsl-cm5a-lr_rcp60_1',
#  '2023_ipsl-cm5a-lr_rcp26_0',
#  '2023_ipsl-cm5a-lr_rcp26_3',
#  '2023_ipsl-cm5a-lr_rcp26_3',
#  '2023_ipsl-cm5a-lr_rcp60_6',
#  '2023_ipsl-cm5a-lr_rcp60_16',
#  '2023_ipsl-cm5a-lr_rcp26_8',
#  '2023_ipsl-cm5a-lr_rcp60_14',
#  '2023_ipsl-cm5a-lr_rcp60_13',
#  '2023_ipsl-cm5a-lr_rcp60_14',
#  '2023_ipsl-cm5a-lr_rcp60_24',
#  '2023_ipsl-cm5a-lr_rcp26_2',
#  '2023_ipsl-cm5a-lr_rcp60_7',
#  '2023_ipsl-cm5a-lr_rcp60_21',
#  '2023_ipsl-cm5a-lr_rcp60_20',
#  '2023_ipsl-cm5a-lr_rcp26_19',
#  '2023_ipsl-cm5a-lr_rcp60_2',
#  '2023_ipsl-cm5a-lr_rcp60_17',
#  '2023_ipsl-cm5a-lr_rcp26_13',
#  '2023_ipsl-cm5a-lr_rcp60_5',
#  '2023_ipsl-cm5a-lr_rcp60_11',
#  '2023_ipsl-cm5a-lr_rcp60_23',
#  '2023_ipsl-cm5a-lr_rcp26_11',
#  '2023_ipsl-cm5a-lr_rcp26_8',
#  '2023_ipsl-cm5a-lr_rcp60_3',
#  '2023_ipsl-cm5a-lr_rcp26_2',
#  '2023_ipsl-cm5a-lr_rcp60_12',
#  '2023_ipsl-cm5a-lr_rcp60_5',
#  '2023_ipsl-cm5a-lr_rcp26_17',
#  '2023_ipsl-cm5a-lr_rcp60_11',
#  '2023_ipsl-cm5a-lr_rcp26_21',
#  '2023_ipsl-cm5a-lr_rcp26_24',
#  '2024_ipsl-cm5a-lr_rcp26_0',
#  '2024_ipsl-cm5a-lr_rcp60_21',
#  '2024_ipsl-cm5a-lr_rcp26_6',
#  '2024_ipsl-cm5a-lr_rcp60_5',
#  '2024_ipsl-cm5a-lr_rcp26_23',
#  '2024_ipsl-cm5a-lr_rcp26_16',
#  '2024_ipsl-cm5a-lr_rcp60_1',
#  '2024_ipsl-cm5a-lr_rcp26_20',
#  '2024_ipsl-cm5a-lr_rcp60_18',
#  '2024_ipsl-cm5a-lr_rcp26_4',
#  '2024_ipsl-cm5a-lr_rcp60_7',
#  '2024_ipsl-cm5a-lr_rcp60_23',
#  '2024_ipsl-cm5a-lr_rcp26_17',
#  '2024_ipsl-cm5a-lr_rcp60_8',
#  '2024_ipsl-cm5a-lr_rcp60_2',
#  '2024_ipsl-cm5a-lr_rcp60_6',
#  '2024_ipsl-cm5a-lr_rcp26_12',
#  '2024_ipsl-cm5a-lr_rcp60_8',
#  '2024_ipsl-cm5a-lr_rcp26_9',
#  '2024_ipsl-cm5a-lr_rcp60_22',
#  '2024_ipsl-cm5a-lr_rcp26_10',
#  '2024_ipsl-cm5a-lr_rcp60_13',
#  '2024_ipsl-cm5a-lr_rcp60_4',
#  '2024_ipsl-cm5a-lr_rcp26_17',
#  '2024_ipsl-cm5a-lr_rcp60_6',
#  '2024_ipsl-cm5a-lr_rcp60_10',
#  '2024_ipsl-cm5a-lr_rcp60_2',
#  '2024_ipsl-cm5a-lr_rcp60_0',
#  '2024_ipsl-cm5a-lr_rcp60_16',
#  '2024_ipsl-cm5a-lr_rcp60_10',
#  '2024_ipsl-cm5a-lr_rcp26_0',
#  '2024_ipsl-cm5a-lr_rcp60_9',
#  '2024_ipsl-cm5a-lr_rcp60_5',
#  '2024_ipsl-cm5a-lr_rcp26_8',
#  '2024_ipsl-cm5a-lr_rcp60_1',
#  '2024_ipsl-cm5a-lr_rcp60_0',
#  '2024_ipsl-cm5a-lr_rcp60_18',
#  '2024_ipsl-cm5a-lr_rcp26_13',
#  '2024_ipsl-cm5a-lr_rcp26_13',
#  '2024_ipsl-cm5a-lr_rcp26_5',
#  '2024_ipsl-cm5a-lr_rcp60_22',
#  '2024_ipsl-cm5a-lr_rcp60_7',
#  '2024_ipsl-cm5a-lr_rcp26_24',
#  '2024_ipsl-cm5a-lr_rcp60_19',
#  '2024_ipsl-cm5a-lr_rcp26_19',
#  '2024_ipsl-cm5a-lr_rcp26_24',
#  '2024_ipsl-cm5a-lr_rcp26_5',
#  '2024_ipsl-cm5a-lr_rcp26_11',
#  '2024_ipsl-cm5a-lr_rcp26_0',
#  '2024_ipsl-cm5a-lr_rcp60_5',
#  '2024_ipsl-cm5a-lr_rcp60_12',
#  '2024_ipsl-cm5a-lr_rcp26_8',
#  '2024_ipsl-cm5a-lr_rcp26_6',
#  '2024_ipsl-cm5a-lr_rcp26_8',
#  '2024_ipsl-cm5a-lr_rcp26_7',
#  '2024_ipsl-cm5a-lr_rcp26_16',
#  '2024_ipsl-cm5a-lr_rcp26_20',
#  '2024_ipsl-cm5a-lr_rcp60_21',
#  '2024_ipsl-cm5a-lr_rcp26_5',
#  '2024_ipsl-cm5a-lr_rcp60_23',
#  '2024_ipsl-cm5a-lr_rcp26_14',
#  '2024_ipsl-cm5a-lr_rcp26_20',
#  '2024_ipsl-cm5a-lr_rcp60_24',
#  '2024_ipsl-cm5a-lr_rcp26_18',
#  '2024_ipsl-cm5a-lr_rcp60_15',
#  '2024_ipsl-cm5a-lr_rcp26_4',
#  '2024_ipsl-cm5a-lr_rcp26_8',
#  '2024_ipsl-cm5a-lr_rcp60_1',
#  '2024_ipsl-cm5a-lr_rcp60_2',
#  '2024_ipsl-cm5a-lr_rcp60_17',
#  '2024_ipsl-cm5a-lr_rcp26_0',
#  '2024_ipsl-cm5a-lr_rcp26_12',
#  '2024_ipsl-cm5a-lr_rcp60_8',
#  '2024_ipsl-cm5a-lr_rcp26_11',
#  '2024_ipsl-cm5a-lr_rcp26_23',
#  '2024_ipsl-cm5a-lr_rcp26_16',
#  '2024_ipsl-cm5a-lr_rcp26_3',
#  '2024_ipsl-cm5a-lr_rcp26_12',
#  '2024_ipsl-cm5a-lr_rcp26_8',
#  '2024_ipsl-cm5a-lr_rcp60_24',
#  '2025_ipsl-cm5a-lr_rcp26_23',
#  '2025_ipsl-cm5a-lr_rcp60_4',
#  '2025_ipsl-cm5a-lr_rcp26_17',
#  '2025_ipsl-cm5a-lr_rcp26_13',
#  '2025_ipsl-cm5a-lr_rcp26_22',
#  '2025_ipsl-cm5a-lr_rcp60_11',
#  '2025_ipsl-cm5a-lr_rcp60_7',
#  '2025_ipsl-cm5a-lr_rcp26_18',
#  '2025_ipsl-cm5a-lr_rcp26_24',
#  '2025_ipsl-cm5a-lr_rcp26_7',
#  '2025_ipsl-cm5a-lr_rcp26_5',
#  '2025_ipsl-cm5a-lr_rcp26_6',
#  '2025_ipsl-cm5a-lr_rcp60_5',
#  '2025_ipsl-cm5a-lr_rcp60_12',
#  '2025_ipsl-cm5a-lr_rcp26_8',
#  '2025_ipsl-cm5a-lr_rcp26_21',
#  '2025_ipsl-cm5a-lr_rcp60_15',
#  '2025_ipsl-cm5a-lr_rcp60_3',
#  '2025_ipsl-cm5a-lr_rcp60_9',
#  '2025_ipsl-cm5a-lr_rcp60_2',
#  '2025_ipsl-cm5a-lr_rcp60_11',
#  '2025_ipsl-cm5a-lr_rcp26_15',
#  '2025_ipsl-cm5a-lr_rcp60_8',
#  '2025_ipsl-cm5a-lr_rcp60_2',
#  '2025_ipsl-cm5a-lr_rcp26_16',
#  '2025_ipsl-cm5a-lr_rcp60_10',
#  '2025_ipsl-cm5a-lr_rcp26_3',
#  '2025_ipsl-cm5a-lr_rcp60_15',
#  '2025_ipsl-cm5a-lr_rcp60_19',
#  '2025_ipsl-cm5a-lr_rcp60_1',
#  '2025_ipsl-cm5a-lr_rcp26_5',
#  '2025_ipsl-cm5a-lr_rcp26_6',
#  '2025_ipsl-cm5a-lr_rcp60_11',
#  '2025_ipsl-cm5a-lr_rcp26_6',
#  '2025_ipsl-cm5a-lr_rcp26_5',
#  '2025_ipsl-cm5a-lr_rcp26_0',
#  '2025_ipsl-cm5a-lr_rcp26_16',
#  '2025_ipsl-cm5a-lr_rcp60_0',
#  '2025_ipsl-cm5a-lr_rcp26_24',
#  '2025_ipsl-cm5a-lr_rcp26_10',
#  '2025_ipsl-cm5a-lr_rcp60_12',
#  '2025_ipsl-cm5a-lr_rcp26_23',
#  '2025_ipsl-cm5a-lr_rcp26_6',
#  '2025_ipsl-cm5a-lr_rcp26_20',
#  '2025_ipsl-cm5a-lr_rcp60_0',
#  '2025_ipsl-cm5a-lr_rcp60_6',
#  '2025_ipsl-cm5a-lr_rcp26_12',
#  '2025_ipsl-cm5a-lr_rcp60_24',
#  '2025_ipsl-cm5a-lr_rcp60_16',
#  '2025_ipsl-cm5a-lr_rcp26_1',
#  '2025_ipsl-cm5a-lr_rcp60_22',
#  '2025_ipsl-cm5a-lr_rcp26_1',
#  '2025_ipsl-cm5a-lr_rcp60_3',
#  '2025_ipsl-cm5a-lr_rcp26_22',
#  '2025_ipsl-cm5a-lr_rcp26_16',
#  '2025_ipsl-cm5a-lr_rcp60_1',
#  '2025_ipsl-cm5a-lr_rcp26_0',
#  '2025_ipsl-cm5a-lr_rcp60_5',
#  '2025_ipsl-cm5a-lr_rcp26_17',
#  '2025_ipsl-cm5a-lr_rcp60_17',
#  '2025_ipsl-cm5a-lr_rcp60_7',
#  '2025_ipsl-cm5a-lr_rcp60_23',
#  '2025_ipsl-cm5a-lr_rcp60_0',
#  '2025_ipsl-cm5a-lr_rcp60_9',
#  '2025_ipsl-cm5a-lr_rcp60_6',
#  '2025_ipsl-cm5a-lr_rcp60_18',
#  '2025_ipsl-cm5a-lr_rcp60_1',
#  '2025_ipsl-cm5a-lr_rcp26_18',
#  '2025_ipsl-cm5a-lr_rcp26_10',
#  '2025_ipsl-cm5a-lr_rcp60_15',
#  '2025_ipsl-cm5a-lr_rcp60_23',
#  '2025_ipsl-cm5a-lr_rcp26_2',
#  '2025_ipsl-cm5a-lr_rcp60_22',
#  '2025_ipsl-cm5a-lr_rcp26_13',
#  '2025_ipsl-cm5a-lr_rcp60_7',
#  '2025_ipsl-cm5a-lr_rcp60_3',
#  '2025_ipsl-cm5a-lr_rcp26_23',
#  '2025_ipsl-cm5a-lr_rcp26_4',
#  '2025_ipsl-cm5a-lr_rcp26_6',
#  '2025_ipsl-cm5a-lr_rcp60_18',
#  '2026_ipsl-cm5a-lr_rcp60_5',
#  '2026_ipsl-cm5a-lr_rcp26_1',
#  '2026_ipsl-cm5a-lr_rcp26_13',
#  '2026_ipsl-cm5a-lr_rcp60_14',
#  '2026_ipsl-cm5a-lr_rcp26_16',
#  '2026_ipsl-cm5a-lr_rcp26_0',
#  '2026_ipsl-cm5a-lr_rcp26_19',
#  '2026_ipsl-cm5a-lr_rcp26_15',
#  '2026_ipsl-cm5a-lr_rcp26_21',
#  '2026_ipsl-cm5a-lr_rcp60_24',
#  '2026_ipsl-cm5a-lr_rcp26_9',
#  '2026_ipsl-cm5a-lr_rcp26_11',
#  '2026_ipsl-cm5a-lr_rcp26_7',
#  '2026_ipsl-cm5a-lr_rcp26_18',
#  '2026_ipsl-cm5a-lr_rcp60_9',
#  '2026_ipsl-cm5a-lr_rcp60_16',
#  '2026_ipsl-cm5a-lr_rcp26_15',
#  '2026_ipsl-cm5a-lr_rcp60_1',
#  '2026_ipsl-cm5a-lr_rcp60_11',
#  '2026_ipsl-cm5a-lr_rcp60_5',
#  '2026_ipsl-cm5a-lr_rcp26_23',
#  '2026_ipsl-cm5a-lr_rcp60_23',
#  '2026_ipsl-cm5a-lr_rcp60_18',
#  '2026_ipsl-cm5a-lr_rcp26_12',
#  '2026_ipsl-cm5a-lr_rcp26_21',
#  '2026_ipsl-cm5a-lr_rcp26_13',
#  '2026_ipsl-cm5a-lr_rcp26_10',
#  '2026_ipsl-cm5a-lr_rcp60_20',
#  '2026_ipsl-cm5a-lr_rcp60_21',
#  '2026_ipsl-cm5a-lr_rcp26_21',
#  '2026_ipsl-cm5a-lr_rcp60_2',
#  '2026_ipsl-cm5a-lr_rcp26_7',
#  '2026_ipsl-cm5a-lr_rcp60_8',
#  '2026_ipsl-cm5a-lr_rcp26_13',
#  '2026_ipsl-cm5a-lr_rcp60_1',
#  '2026_ipsl-cm5a-lr_rcp26_10',
#  '2026_ipsl-cm5a-lr_rcp26_18',
#  '2026_ipsl-cm5a-lr_rcp26_10',
#  '2026_ipsl-cm5a-lr_rcp26_4',
#  '2026_ipsl-cm5a-lr_rcp26_12',
#  '2026_ipsl-cm5a-lr_rcp60_18',
#  '2026_ipsl-cm5a-lr_rcp60_22',
#  '2026_ipsl-cm5a-lr_rcp26_16',
#  '2026_ipsl-cm5a-lr_rcp60_4',
#  '2026_ipsl-cm5a-lr_rcp26_3',
#  '2026_ipsl-cm5a-lr_rcp26_12',
#  '2026_ipsl-cm5a-lr_rcp26_4',
#  '2026_ipsl-cm5a-lr_rcp26_9',
#  '2026_ipsl-cm5a-lr_rcp26_5',
#  '2026_ipsl-cm5a-lr_rcp26_6',
#  '2026_ipsl-cm5a-lr_rcp26_22',
#  '2026_ipsl-cm5a-lr_rcp60_10',
#  '2026_ipsl-cm5a-lr_rcp26_10',
#  '2026_ipsl-cm5a-lr_rcp60_4',
#  '2026_ipsl-cm5a-lr_rcp60_3',
#  '2026_ipsl-cm5a-lr_rcp26_15',
#  '2026_ipsl-cm5a-lr_rcp26_5',
#  '2026_ipsl-cm5a-lr_rcp26_6',
#  '2026_ipsl-cm5a-lr_rcp26_23',
#  '2026_ipsl-cm5a-lr_rcp60_19',
#  '2026_ipsl-cm5a-lr_rcp26_2',
#  '2026_ipsl-cm5a-lr_rcp60_0',
#  '2026_ipsl-cm5a-lr_rcp26_14',
#  '2026_ipsl-cm5a-lr_rcp26_6',
#  '2026_ipsl-cm5a-lr_rcp26_10',
#  '2026_ipsl-cm5a-lr_rcp26_10',
#  '2026_ipsl-cm5a-lr_rcp60_0',
#  '2026_ipsl-cm5a-lr_rcp60_24',
#  '2026_ipsl-cm5a-lr_rcp60_8',
#  '2026_ipsl-cm5a-lr_rcp26_6',
#  '2026_ipsl-cm5a-lr_rcp26_8',
#  '2026_ipsl-cm5a-lr_rcp26_2',
#  '2026_ipsl-cm5a-lr_rcp60_23',
#  '2026_ipsl-cm5a-lr_rcp26_9',
#  '2026_ipsl-cm5a-lr_rcp60_13',
#  '2026_ipsl-cm5a-lr_rcp26_17',
#  '2026_ipsl-cm5a-lr_rcp26_16',
#  '2026_ipsl-cm5a-lr_rcp26_8',
#  '2026_ipsl-cm5a-lr_rcp60_2',
#  '2026_ipsl-cm5a-lr_rcp26_13',
#  '2027_ipsl-cm5a-lr_rcp60_9',
#  '2027_ipsl-cm5a-lr_rcp26_8',
#  '2027_ipsl-cm5a-lr_rcp60_19',
#  '2027_ipsl-cm5a-lr_rcp26_8',
#  '2027_ipsl-cm5a-lr_rcp60_21',
#  '2027_ipsl-cm5a-lr_rcp60_9',
#  '2027_ipsl-cm5a-lr_rcp26_20',
#  '2027_ipsl-cm5a-lr_rcp26_21',
#  '2027_ipsl-cm5a-lr_rcp26_23',
#  '2027_ipsl-cm5a-lr_rcp60_4',
#  '2027_ipsl-cm5a-lr_rcp60_23',
#  '2027_ipsl-cm5a-lr_rcp60_9',
#  '2027_ipsl-cm5a-lr_rcp60_2',
#  '2027_ipsl-cm5a-lr_rcp60_9',
#  '2027_ipsl-cm5a-lr_rcp26_5',
#  '2027_ipsl-cm5a-lr_rcp60_4',
#  '2027_ipsl-cm5a-lr_rcp60_21',
#  '2027_ipsl-cm5a-lr_rcp26_17',
#  '2027_ipsl-cm5a-lr_rcp26_11',
#  '2027_ipsl-cm5a-lr_rcp60_7',
#  '2027_ipsl-cm5a-lr_rcp26_20',
#  '2027_ipsl-cm5a-lr_rcp26_20',
#  '2027_ipsl-cm5a-lr_rcp60_1',
#  '2027_ipsl-cm5a-lr_rcp26_17',
#  '2027_ipsl-cm5a-lr_rcp26_20',
#  '2027_ipsl-cm5a-lr_rcp60_0',
#  '2027_ipsl-cm5a-lr_rcp26_18',
#  '2027_ipsl-cm5a-lr_rcp60_14',
#  '2027_ipsl-cm5a-lr_rcp26_10',
#  '2027_ipsl-cm5a-lr_rcp60_10',
#  '2027_ipsl-cm5a-lr_rcp26_0',
#  '2027_ipsl-cm5a-lr_rcp26_19',
#  '2027_ipsl-cm5a-lr_rcp60_16',
#  '2027_ipsl-cm5a-lr_rcp26_1',
#  '2027_ipsl-cm5a-lr_rcp60_19',
#  '2027_ipsl-cm5a-lr_rcp26_13',
#  '2027_ipsl-cm5a-lr_rcp60_3',
#  '2027_ipsl-cm5a-lr_rcp26_7',
#  '2027_ipsl-cm5a-lr_rcp26_6',
#  '2027_ipsl-cm5a-lr_rcp26_1',
#  '2027_ipsl-cm5a-lr_rcp60_22',
#  '2027_ipsl-cm5a-lr_rcp60_20',
#  '2027_ipsl-cm5a-lr_rcp60_1',
#  '2027_ipsl-cm5a-lr_rcp26_24',
#  '2027_ipsl-cm5a-lr_rcp60_23',
#  '2027_ipsl-cm5a-lr_rcp60_23',
#  '2027_ipsl-cm5a-lr_rcp26_8',
#  '2027_ipsl-cm5a-lr_rcp26_21',
#  '2027_ipsl-cm5a-lr_rcp60_6',
#  '2027_ipsl-cm5a-lr_rcp60_22',
#  '2027_ipsl-cm5a-lr_rcp60_9',
#  '2027_ipsl-cm5a-lr_rcp60_19',
#  '2027_ipsl-cm5a-lr_rcp60_19',
#  '2027_ipsl-cm5a-lr_rcp26_18',
#  '2027_ipsl-cm5a-lr_rcp26_19',
#  '2027_ipsl-cm5a-lr_rcp60_13',
#  '2027_ipsl-cm5a-lr_rcp60_15',
#  '2027_ipsl-cm5a-lr_rcp60_7',
#  '2027_ipsl-cm5a-lr_rcp60_17',
#  '2027_ipsl-cm5a-lr_rcp60_8',
#  '2027_ipsl-cm5a-lr_rcp60_22',
#  '2027_ipsl-cm5a-lr_rcp26_0',
#  '2027_ipsl-cm5a-lr_rcp26_0',
#  '2027_ipsl-cm5a-lr_rcp60_6',
#  '2027_ipsl-cm5a-lr_rcp26_21',
#  '2027_ipsl-cm5a-lr_rcp26_20',
#  '2027_ipsl-cm5a-lr_rcp60_2',
#  '2027_ipsl-cm5a-lr_rcp60_23',
#  '2027_ipsl-cm5a-lr_rcp60_20',
#  '2027_ipsl-cm5a-lr_rcp26_6',
#  '2027_ipsl-cm5a-lr_rcp26_1',
#  '2027_ipsl-cm5a-lr_rcp60_23',
#  '2027_ipsl-cm5a-lr_rcp60_7',
#  '2027_ipsl-cm5a-lr_rcp60_12',
#  '2027_ipsl-cm5a-lr_rcp26_9',
#  '2027_ipsl-cm5a-lr_rcp26_10',
#  '2027_ipsl-cm5a-lr_rcp60_11',
#  '2027_ipsl-cm5a-lr_rcp60_10',
#  '2027_ipsl-cm5a-lr_rcp26_7',
#  '2027_ipsl-cm5a-lr_rcp26_14',
#  '2028_ipsl-cm5a-lr_rcp26_14',
#  '2028_ipsl-cm5a-lr_rcp60_22',
#  '2028_ipsl-cm5a-lr_rcp60_9',
#  '2028_ipsl-cm5a-lr_rcp60_19',
#  '2028_ipsl-cm5a-lr_rcp26_0',
#  '2028_ipsl-cm5a-lr_rcp60_14',
#  '2028_ipsl-cm5a-lr_rcp26_9',
#  '2028_ipsl-cm5a-lr_rcp60_15',
#  '2028_ipsl-cm5a-lr_rcp60_18',
#  '2028_ipsl-cm5a-lr_rcp60_19',
#  '2028_ipsl-cm5a-lr_rcp60_13',
#  '2028_ipsl-cm5a-lr_rcp60_22',
#  '2028_ipsl-cm5a-lr_rcp26_1',
#  '2028_ipsl-cm5a-lr_rcp60_1',
#  '2028_ipsl-cm5a-lr_rcp60_3',
#  '2028_ipsl-cm5a-lr_rcp60_6',
#  '2028_ipsl-cm5a-lr_rcp26_18',
#  '2028_ipsl-cm5a-lr_rcp26_24',
#  '2028_ipsl-cm5a-lr_rcp26_22',
#  '2028_ipsl-cm5a-lr_rcp26_18',
#  '2028_ipsl-cm5a-lr_rcp26_12',
#  '2028_ipsl-cm5a-lr_rcp26_10',
#  '2028_ipsl-cm5a-lr_rcp60_14',
#  '2028_ipsl-cm5a-lr_rcp26_20',
#  '2028_ipsl-cm5a-lr_rcp26_5',
#  '2028_ipsl-cm5a-lr_rcp26_0',
#  '2028_ipsl-cm5a-lr_rcp26_16',
#  '2028_ipsl-cm5a-lr_rcp26_20',
#  '2028_ipsl-cm5a-lr_rcp26_18',
#  '2028_ipsl-cm5a-lr_rcp26_17',
#  '2028_ipsl-cm5a-lr_rcp60_14',
#  '2028_ipsl-cm5a-lr_rcp60_2',
#  '2028_ipsl-cm5a-lr_rcp60_13',
#  '2028_ipsl-cm5a-lr_rcp26_24',
#  '2028_ipsl-cm5a-lr_rcp60_14',
#  '2028_ipsl-cm5a-lr_rcp60_17',
#  '2028_ipsl-cm5a-lr_rcp60_18',
#  '2028_ipsl-cm5a-lr_rcp60_0',
#  '2028_ipsl-cm5a-lr_rcp26_5',
#  '2028_ipsl-cm5a-lr_rcp60_22',
#  '2028_ipsl-cm5a-lr_rcp60_6',
#  '2028_ipsl-cm5a-lr_rcp60_22',
#  '2028_ipsl-cm5a-lr_rcp60_6',
#  '2028_ipsl-cm5a-lr_rcp60_10',
#  '2028_ipsl-cm5a-lr_rcp60_3',
#  '2028_ipsl-cm5a-lr_rcp26_7',
#  '2028_ipsl-cm5a-lr_rcp60_20',
#  '2028_ipsl-cm5a-lr_rcp26_13',
#  '2028_ipsl-cm5a-lr_rcp60_22',
#  '2028_ipsl-cm5a-lr_rcp26_6',
#  '2028_ipsl-cm5a-lr_rcp60_11',
#  '2028_ipsl-cm5a-lr_rcp26_20',
#  '2028_ipsl-cm5a-lr_rcp26_5',
#  '2028_ipsl-cm5a-lr_rcp26_13',
#  '2028_ipsl-cm5a-lr_rcp60_11',
#  '2028_ipsl-cm5a-lr_rcp26_0',
#  '2028_ipsl-cm5a-lr_rcp60_23',
#  '2028_ipsl-cm5a-lr_rcp26_18',
#  '2028_ipsl-cm5a-lr_rcp26_7',
#  '2028_ipsl-cm5a-lr_rcp26_23',
#  '2028_ipsl-cm5a-lr_rcp60_6',
#  '2028_ipsl-cm5a-lr_rcp60_4',
#  '2028_ipsl-cm5a-lr_rcp26_22',
#  '2028_ipsl-cm5a-lr_rcp26_3',
#  '2028_ipsl-cm5a-lr_rcp60_14',
#  '2028_ipsl-cm5a-lr_rcp60_9',
#  '2028_ipsl-cm5a-lr_rcp26_5',
#  '2028_ipsl-cm5a-lr_rcp26_14',
#  '2028_ipsl-cm5a-lr_rcp60_15',
#  '2028_ipsl-cm5a-lr_rcp26_3',
#  '2028_ipsl-cm5a-lr_rcp60_15',
#  '2028_ipsl-cm5a-lr_rcp60_20',
#  '2028_ipsl-cm5a-lr_rcp26_13',
#  '2028_ipsl-cm5a-lr_rcp60_15',
#  '2028_ipsl-cm5a-lr_rcp60_14',
#  '2028_ipsl-cm5a-lr_rcp26_17',
#  '2028_ipsl-cm5a-lr_rcp26_15',
#  '2028_ipsl-cm5a-lr_rcp60_24',
#  '2028_ipsl-cm5a-lr_rcp60_5',
#  '2028_ipsl-cm5a-lr_rcp60_22',
#  '2029_ipsl-cm5a-lr_rcp60_13',
#  '2029_ipsl-cm5a-lr_rcp60_4',
#  '2029_ipsl-cm5a-lr_rcp26_20',
#  '2029_ipsl-cm5a-lr_rcp60_16',
#  '2029_ipsl-cm5a-lr_rcp26_2',
#  '2029_ipsl-cm5a-lr_rcp26_7',
#  '2029_ipsl-cm5a-lr_rcp26_20',
#  '2029_ipsl-cm5a-lr_rcp60_21',
#  '2029_ipsl-cm5a-lr_rcp26_16',
#  '2029_ipsl-cm5a-lr_rcp26_16',
#  '2029_ipsl-cm5a-lr_rcp26_15',
#  '2029_ipsl-cm5a-lr_rcp26_19',
#  '2029_ipsl-cm5a-lr_rcp60_3',
#  '2029_ipsl-cm5a-lr_rcp26_12',
#  '2029_ipsl-cm5a-lr_rcp60_4',
#  '2029_ipsl-cm5a-lr_rcp60_1',
#  '2029_ipsl-cm5a-lr_rcp60_22',
#  '2029_ipsl-cm5a-lr_rcp60_13',
#  '2029_ipsl-cm5a-lr_rcp26_17',
#  '2029_ipsl-cm5a-lr_rcp60_10',
#  '2029_ipsl-cm5a-lr_rcp60_14',
#  '2029_ipsl-cm5a-lr_rcp60_0',
#  '2029_ipsl-cm5a-lr_rcp60_11',
#  '2029_ipsl-cm5a-lr_rcp60_19',
#  '2029_ipsl-cm5a-lr_rcp26_10',
#  '2029_ipsl-cm5a-lr_rcp26_3',
#  '2029_ipsl-cm5a-lr_rcp60_13',
#  '2029_ipsl-cm5a-lr_rcp26_10',
#  '2029_ipsl-cm5a-lr_rcp26_19',
#  '2029_ipsl-cm5a-lr_rcp60_18',
#  '2029_ipsl-cm5a-lr_rcp60_22',
#  '2029_ipsl-cm5a-lr_rcp26_13',
#  '2029_ipsl-cm5a-lr_rcp60_2',
#  '2029_ipsl-cm5a-lr_rcp60_7',
#  '2029_ipsl-cm5a-lr_rcp60_24',
#  '2029_ipsl-cm5a-lr_rcp60_7',
#  '2029_ipsl-cm5a-lr_rcp26_9',
#  '2029_ipsl-cm5a-lr_rcp26_15',
#  '2029_ipsl-cm5a-lr_rcp60_20',
#  '2029_ipsl-cm5a-lr_rcp60_0',
#  '2029_ipsl-cm5a-lr_rcp60_1',
#  '2029_ipsl-cm5a-lr_rcp26_3',
#  '2029_ipsl-cm5a-lr_rcp60_18',
#  '2029_ipsl-cm5a-lr_rcp60_11',
#  '2029_ipsl-cm5a-lr_rcp26_6',
#  '2029_ipsl-cm5a-lr_rcp60_10',
#  '2029_ipsl-cm5a-lr_rcp60_7',
#  '2029_ipsl-cm5a-lr_rcp26_8',
#  '2029_ipsl-cm5a-lr_rcp60_13',
#  '2029_ipsl-cm5a-lr_rcp26_19',
#  '2029_ipsl-cm5a-lr_rcp26_2',
#  '2029_ipsl-cm5a-lr_rcp60_5',
#  '2029_ipsl-cm5a-lr_rcp60_0',
#  '2029_ipsl-cm5a-lr_rcp26_3',
#  '2029_ipsl-cm5a-lr_rcp26_10',
#  '2029_ipsl-cm5a-lr_rcp26_16',
#  '2029_ipsl-cm5a-lr_rcp60_19',
#  '2029_ipsl-cm5a-lr_rcp60_14',
#  '2029_ipsl-cm5a-lr_rcp26_23',
#  '2029_ipsl-cm5a-lr_rcp60_5',
#  '2029_ipsl-cm5a-lr_rcp26_15',
#  '2029_ipsl-cm5a-lr_rcp60_5',
#  '2029_ipsl-cm5a-lr_rcp26_16',
#  '2029_ipsl-cm5a-lr_rcp26_18',
#  '2029_ipsl-cm5a-lr_rcp26_21',
#  '2029_ipsl-cm5a-lr_rcp60_11',
#  '2029_ipsl-cm5a-lr_rcp60_5',
#  '2029_ipsl-cm5a-lr_rcp60_18',
#  '2029_ipsl-cm5a-lr_rcp60_0',
#  '2029_ipsl-cm5a-lr_rcp26_3',
#  '2029_ipsl-cm5a-lr_rcp60_15',
#  '2029_ipsl-cm5a-lr_rcp26_17',
#  '2029_ipsl-cm5a-lr_rcp60_8',
#  '2029_ipsl-cm5a-lr_rcp26_12',
#  '2029_ipsl-cm5a-lr_rcp60_6',
#  '2029_ipsl-cm5a-lr_rcp26_19',
#  '2029_ipsl-cm5a-lr_rcp60_16',
#  '2029_ipsl-cm5a-lr_rcp60_19',
#  '2029_ipsl-cm5a-lr_rcp60_5',
#  '2029_ipsl-cm5a-lr_rcp60_13',
#  '2030_ipsl-cm5a-lr_rcp26_3',
#  '2030_ipsl-cm5a-lr_rcp60_16',
#  '2030_ipsl-cm5a-lr_rcp60_18',
#  '2030_ipsl-cm5a-lr_rcp60_21',
#  '2030_ipsl-cm5a-lr_rcp26_20',
#  '2030_ipsl-cm5a-lr_rcp26_18',
#  '2030_ipsl-cm5a-lr_rcp26_3',
#  '2030_ipsl-cm5a-lr_rcp26_6',
#  '2030_ipsl-cm5a-lr_rcp26_1',
#  '2030_ipsl-cm5a-lr_rcp60_2',
#  '2030_ipsl-cm5a-lr_rcp26_8',
#  '2030_ipsl-cm5a-lr_rcp26_0',
#  '2030_ipsl-cm5a-lr_rcp60_22',
#  '2030_ipsl-cm5a-lr_rcp26_15',
#  '2030_ipsl-cm5a-lr_rcp26_3',
#  '2030_ipsl-cm5a-lr_rcp26_19',
#  '2030_ipsl-cm5a-lr_rcp26_12',
#  '2030_ipsl-cm5a-lr_rcp26_13',
#  '2030_ipsl-cm5a-lr_rcp26_2',
#  '2030_ipsl-cm5a-lr_rcp26_18',
#  '2030_ipsl-cm5a-lr_rcp60_3',
#  '2030_ipsl-cm5a-lr_rcp60_21',
#  '2030_ipsl-cm5a-lr_rcp60_17',
#  '2030_ipsl-cm5a-lr_rcp60_5',
#  '2030_ipsl-cm5a-lr_rcp60_12',
#  '2030_ipsl-cm5a-lr_rcp60_24',
#  '2030_ipsl-cm5a-lr_rcp60_22',
#  '2030_ipsl-cm5a-lr_rcp60_17',
#  '2030_ipsl-cm5a-lr_rcp60_4',
#  '2030_ipsl-cm5a-lr_rcp60_4',
#  '2030_ipsl-cm5a-lr_rcp26_24',
#  '2030_ipsl-cm5a-lr_rcp26_19',
#  '2030_ipsl-cm5a-lr_rcp26_21',
#  '2030_ipsl-cm5a-lr_rcp26_8',
#  '2030_ipsl-cm5a-lr_rcp26_2',
#  '2030_ipsl-cm5a-lr_rcp26_1',
#  '2030_ipsl-cm5a-lr_rcp60_19',
#  '2030_ipsl-cm5a-lr_rcp26_7',
#  '2030_ipsl-cm5a-lr_rcp60_4',
#  '2030_ipsl-cm5a-lr_rcp60_24',
#  '2030_ipsl-cm5a-lr_rcp60_20',
#  '2030_ipsl-cm5a-lr_rcp26_0',
#  '2030_ipsl-cm5a-lr_rcp26_8',
#  '2030_ipsl-cm5a-lr_rcp60_0',
#  '2030_ipsl-cm5a-lr_rcp26_3',
#  '2030_ipsl-cm5a-lr_rcp26_21',
#  '2030_ipsl-cm5a-lr_rcp26_24',
#  '2030_ipsl-cm5a-lr_rcp26_12',
#  '2030_ipsl-cm5a-lr_rcp60_19',
#  '2030_ipsl-cm5a-lr_rcp60_1',
#  '2030_ipsl-cm5a-lr_rcp60_7',
#  '2030_ipsl-cm5a-lr_rcp26_11',
#  '2030_ipsl-cm5a-lr_rcp60_15',
#  '2030_ipsl-cm5a-lr_rcp26_14',
#  '2030_ipsl-cm5a-lr_rcp26_0',
#  '2030_ipsl-cm5a-lr_rcp26_4',
#  '2030_ipsl-cm5a-lr_rcp26_18',
#  '2030_ipsl-cm5a-lr_rcp26_1',
#  '2030_ipsl-cm5a-lr_rcp26_24',
#  '2030_ipsl-cm5a-lr_rcp26_6',
#  '2030_ipsl-cm5a-lr_rcp60_6',
#  '2030_ipsl-cm5a-lr_rcp26_3',
#  '2030_ipsl-cm5a-lr_rcp26_7',
#  '2030_ipsl-cm5a-lr_rcp26_8',
#  '2030_ipsl-cm5a-lr_rcp26_15',
#  '2030_ipsl-cm5a-lr_rcp26_19',
#  '2030_ipsl-cm5a-lr_rcp60_15',
#  '2030_ipsl-cm5a-lr_rcp60_17',
#  '2030_ipsl-cm5a-lr_rcp26_12',
#  '2030_ipsl-cm5a-lr_rcp26_22',
#  '2030_ipsl-cm5a-lr_rcp60_18',
#  '2030_ipsl-cm5a-lr_rcp60_12',
#  '2030_ipsl-cm5a-lr_rcp26_21',
#  '2030_ipsl-cm5a-lr_rcp60_12',
#  '2030_ipsl-cm5a-lr_rcp60_2',
#  '2030_ipsl-cm5a-lr_rcp60_6',
#  '2030_ipsl-cm5a-lr_rcp60_13',
#  '2030_ipsl-cm5a-lr_rcp60_15',
#  '2030_ipsl-cm5a-lr_rcp26_5',
#  '2030_ipsl-cm5a-lr_rcp26_6',
#  '2031_ipsl-cm5a-lr_rcp26_4',
#  '2031_ipsl-cm5a-lr_rcp60_8',
#  '2031_ipsl-cm5a-lr_rcp26_24',
#  '2031_ipsl-cm5a-lr_rcp26_9',
#  '2031_ipsl-cm5a-lr_rcp60_2',
#  '2031_ipsl-cm5a-lr_rcp60_23',
#  '2031_ipsl-cm5a-lr_rcp26_16',
#  '2031_ipsl-cm5a-lr_rcp26_24',
#  '2031_ipsl-cm5a-lr_rcp26_7',
#  '2031_ipsl-cm5a-lr_rcp60_24',
#  '2031_ipsl-cm5a-lr_rcp26_7',
#  '2031_ipsl-cm5a-lr_rcp26_23',
#  '2031_ipsl-cm5a-lr_rcp60_0',
#  '2031_ipsl-cm5a-lr_rcp26_18',
#  '2031_ipsl-cm5a-lr_rcp26_5',
#  '2031_ipsl-cm5a-lr_rcp26_16',
#  '2031_ipsl-cm5a-lr_rcp60_2',
#  '2031_ipsl-cm5a-lr_rcp26_12',
#  '2031_ipsl-cm5a-lr_rcp60_5',
#  '2031_ipsl-cm5a-lr_rcp60_22',
#  '2031_ipsl-cm5a-lr_rcp26_1',
#  '2031_ipsl-cm5a-lr_rcp60_13',
#  '2031_ipsl-cm5a-lr_rcp26_23',
#  '2031_ipsl-cm5a-lr_rcp60_22',
#  '2031_ipsl-cm5a-lr_rcp60_24',
#  '2031_ipsl-cm5a-lr_rcp26_23',
#  '2031_ipsl-cm5a-lr_rcp60_13',
#  '2031_ipsl-cm5a-lr_rcp60_3',
#  '2031_ipsl-cm5a-lr_rcp26_13',
#  '2031_ipsl-cm5a-lr_rcp60_4',
#  '2031_ipsl-cm5a-lr_rcp60_1',
#  '2031_ipsl-cm5a-lr_rcp26_18',
#  '2031_ipsl-cm5a-lr_rcp60_7',
#  '2031_ipsl-cm5a-lr_rcp26_3',
#  '2031_ipsl-cm5a-lr_rcp60_2',
#  '2031_ipsl-cm5a-lr_rcp60_3',
#  '2031_ipsl-cm5a-lr_rcp60_19',
#  '2031_ipsl-cm5a-lr_rcp26_22',
#  '2031_ipsl-cm5a-lr_rcp26_14',
#  '2031_ipsl-cm5a-lr_rcp60_12',
#  ...]

# %%
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np

fq_single_hazard = {}
aai_single_hazard = {}

y100_single_hazard = {}



colors = {'1':'lightblue', '2':'plum', '3':'black'}

for exposure in ["assets", "pop"]:
    for warming in ["1","2"]:
        fig,ax = plt.subplots(figsize=(5.4,4))

        fq_list, fq.return_per =  make_fq_list(impact_combined_ordered[warming][exposure][('TC', 'RF')], factor=factor_dict[exposure])
        plot_return_period_samples(fq_list, fq.return_per, ax, color="Violet", label="Common drivers", range=True)

        fq_list_rf, fq.return_per =  make_fq_list(impact_combined[warming][exposure][('TC', 'RF')], factor=factor_dict[exposure])
        plot_return_period_samples(fq_list_rf, fq.return_per, ax, color="green", label="Mixed", range=True)

    #         fq_list_rf, fq.return_per =  make_fq_list(impact_combined_ordered['3'][exposure][('TC', 'RF')])
    #         plot_return_period_samples(fq_list_rf, fq.return_per, ax, color="gray", label="3", range=True)


        #ax.set_ylabel(ylabel[exposure])
        ax.set_xlabel("Return period (Year)")
        ax.set_ylabel(ylabel[exposure])
        plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report_SI/figures/compound_ordered_vs_random_'+exposure+'_'+warming+'.pdf', bbox_inches='tight')

        #ax.set_title(" ".join([haz, exposure]))

# %%
import matplotlib
import matplotlib.pyplot as plt

cmap_copy = plt.cm.get_cmap('Blues').copy()
cmap_copy.set_under('lightgray', alpha=1)

ax = impacts_yearsets['1']['assets']['RF'].plot_hexbin_eai_exposure(pop_name=False, cmap=cmap_copy,adapt_fontsize=False, norm=matplotlib.colors.SymLogNorm(vlinthresh=1, vmin=1, vmax=10e4))


cmap_copy = plt.cm.get_cmap('Reds').copy()
cmap_copy.set_under('w', alpha=0)

impacts_yearsets['1']['assets']['TC'].plot_hexbin_eai_exposure(axis=ax, pop_name=False, adapt_fontsize=False, cmap=cmap_copy, norm=matplotlib.colors.SymLogNorm(linthresh=1, vmin=1, vmax=10e4))



cmap_copy = plt.cm.get_cmap('Purples').copy()
cmap_copy.set_under('w', alpha=0)
impact_combined_ordered['1']['assets'][('TC','RF')].coord_exp = impacts_yearsets['1']['assets']['RF'].coord_exp

impact_combined_ordered['1']['assets'][('TC','RF')].plot_hexbin_eai_exposure(pop_name=False, axis=ax, cmap=cmap_copy, norm=matplotlib.colors.SymLogNorm(linthresh=1, vmin=1, vmax=10e4), adapt_fontsize=False)

ax.set_title('')
plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk/figures/compound_map_assets.jpeg', dpi=1200, bbox_inches='tight')

# %%
gdf = impact_combined_ordered['1']['assets'][('TC','RF')]._build_exp().gdf

# %%
gdf = gdf[gdf.value>0]

# %%
gdf
# Out:
#              value   latitude  longitude
# 29172     0.012629  31.770833  62.979167
# 29173     0.012401  31.770833  63.020833
# 29363     0.012755  31.729167  62.979167
# 29364     0.012755  31.729167  63.020833
# 29548     0.006424  31.687500  62.937500
# ...            ...        ...        ...
# 8738058   0.010065 -22.187500  29.354167
# 8738059   0.034964 -22.187500  29.895833
# 8738060  12.105866 -22.187500  29.937500
# 8738061  27.841195 -22.187500  29.979167
# 8738062  25.698794 -22.187500  30.020833
#
# [267892 rows x 3 columns]

# %%
import geopandas as gpd
gdf = gdf[gdf.value>0]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.3)


gdf = impact_combined_ordered['1']['assets'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>100]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='coral', markersize=0.00001,marker='*', label='compound')
ax.legend()

gdf = impact_combined_ordered['2']['assets'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>100]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='purple', markersize=0.00001,marker='*', label='compound')
ax.legend()
#plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report/figures/compound_map_binary_assets_cc.jpeg', dpi=1200)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.3)


gdf = impact_combined_ordered['2']['pop'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>0.1]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='coral', markersize=0.00001,marker='*', label='compound')
ax.legend()

gdf = impact_combined_ordered['1']['pop'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>0.1]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='purple', markersize=0.00001,marker='*', label='compound')
ax.legend()
#plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk/figures/compound_map_binary_pop_cc.jpeg', dpi=1200)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd


fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.1)


gdf = impacts_yearsets['1']['assets']['TC']._build_exp().gdf
gdf = gdf[gdf.value>1000]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
gdf.plot(ax=ax, color='red', markersize=0.0001,marker='.', label='TC', alpha=0.3)

gdf = impacts_yearsets['1']['assets']['RF']._build_exp().gdf
gdf = gdf[gdf.value>1000]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
gdf.plot(ax=ax, color='steelblue', markersize=0.0001,marker='.', label='RF', alpha=0.3)


gdf = impact_combined_ordered['1']['assets'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>1000]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='purple', markersize=0.0001,marker='.', label='Compound')
lgnd = ax.legend(loc="lower left", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [130]
lgnd.legendHandles[1]._sizes = [130]
lgnd.legendHandles[2]._sizes = [130]
plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report/map_compound_assets.jpeg', dpi=1600)

# %%
impact_combined_ordered['1']['assets']['TC'].event_name
# Out:
# ['2006_gfdl-esm2m_rcp26_19',
#  '2006_gfdl-esm2m_rcp26_12',
#  '2006_gfdl-esm2m_rcp60_1',
#  '2006_gfdl-esm2m_rcp60_19',
#  '2006_gfdl-esm2m_rcp26_21',
#  '2006_gfdl-esm2m_rcp60_2',
#  '2006_gfdl-esm2m_rcp60_6',
#  '2006_gfdl-esm2m_rcp60_6',
#  '2006_gfdl-esm2m_rcp26_8',
#  '2006_gfdl-esm2m_rcp26_23',
#  '2006_gfdl-esm2m_rcp26_10',
#  '2006_gfdl-esm2m_rcp26_14',
#  '2006_gfdl-esm2m_rcp26_24',
#  '2006_gfdl-esm2m_rcp26_5',
#  '2006_gfdl-esm2m_rcp26_18',
#  '2006_gfdl-esm2m_rcp26_1',
#  '2006_gfdl-esm2m_rcp60_16',
#  '2006_gfdl-esm2m_rcp26_5',
#  '2006_gfdl-esm2m_rcp26_21',
#  '2006_gfdl-esm2m_rcp60_11',
#  '2006_gfdl-esm2m_rcp60_12',
#  '2006_gfdl-esm2m_rcp26_17',
#  '2006_gfdl-esm2m_rcp60_16',
#  '2006_gfdl-esm2m_rcp60_16',
#  '2006_gfdl-esm2m_rcp26_16',
#  '2006_gfdl-esm2m_rcp60_2',
#  '2006_gfdl-esm2m_rcp26_1',
#  '2006_gfdl-esm2m_rcp26_10',
#  '2006_gfdl-esm2m_rcp26_20',
#  '2006_gfdl-esm2m_rcp60_25',
#  '2006_gfdl-esm2m_rcp26_25',
#  '2006_gfdl-esm2m_rcp60_12',
#  '2006_gfdl-esm2m_rcp60_22',
#  '2006_gfdl-esm2m_rcp60_21',
#  '2006_gfdl-esm2m_rcp26_10',
#  '2006_gfdl-esm2m_rcp26_14',
#  '2006_gfdl-esm2m_rcp26_19',
#  '2006_gfdl-esm2m_rcp26_20',
#  '2006_gfdl-esm2m_rcp60_11',
#  '2006_gfdl-esm2m_rcp60_1',
#  '2006_gfdl-esm2m_rcp26_3',
#  '2006_gfdl-esm2m_rcp60_11',
#  '2006_gfdl-esm2m_rcp26_12',
#  '2006_gfdl-esm2m_rcp60_19',
#  '2006_gfdl-esm2m_rcp60_18',
#  '2006_gfdl-esm2m_rcp60_12',
#  '2006_gfdl-esm2m_rcp26_5',
#  '2006_gfdl-esm2m_rcp60_14',
#  '2006_gfdl-esm2m_rcp60_19',
#  '2006_gfdl-esm2m_rcp60_16',
#  '2006_hadgem2-es_rcp26_21',
#  '2006_hadgem2-es_rcp26_13',
#  '2006_hadgem2-es_rcp26_0',
#  '2006_hadgem2-es_rcp26_15',
#  '2006_hadgem2-es_rcp60_2',
#  '2006_hadgem2-es_rcp60_14',
#  '2006_hadgem2-es_rcp26_11',
#  '2006_hadgem2-es_rcp26_19',
#  '2006_hadgem2-es_rcp60_15',
#  '2006_hadgem2-es_rcp26_2',
#  '2006_hadgem2-es_rcp60_13',
#  '2006_hadgem2-es_rcp26_8',
#  '2006_hadgem2-es_rcp60_17',
#  '2006_hadgem2-es_rcp60_3',
#  '2006_hadgem2-es_rcp26_2',
#  '2006_hadgem2-es_rcp60_15',
#  '2006_hadgem2-es_rcp60_7',
#  '2006_hadgem2-es_rcp26_19',
#  '2006_hadgem2-es_rcp60_6',
#  '2006_hadgem2-es_rcp26_7',
#  '2006_hadgem2-es_rcp60_8',
#  '2006_hadgem2-es_rcp26_20',
#  '2006_hadgem2-es_rcp26_13',
#  '2006_hadgem2-es_rcp26_20',
#  '2006_hadgem2-es_rcp60_6',
#  '2006_hadgem2-es_rcp60_0',
#  '2006_hadgem2-es_rcp26_8',
#  '2006_hadgem2-es_rcp26_9',
#  '2006_hadgem2-es_rcp26_19',
#  '2006_hadgem2-es_rcp60_3',
#  '2006_hadgem2-es_rcp26_13',
#  '2006_hadgem2-es_rcp26_0',
#  '2006_hadgem2-es_rcp26_19',
#  '2006_hadgem2-es_rcp60_21',
#  '2006_hadgem2-es_rcp60_15',
#  '2006_hadgem2-es_rcp26_14',
#  '2006_hadgem2-es_rcp26_0',
#  '2006_hadgem2-es_rcp60_9',
#  '2006_hadgem2-es_rcp60_11',
#  '2006_hadgem2-es_rcp26_18',
#  '2006_hadgem2-es_rcp60_3',
#  '2006_hadgem2-es_rcp26_12',
#  '2006_hadgem2-es_rcp26_10',
#  '2006_hadgem2-es_rcp60_6',
#  '2006_hadgem2-es_rcp26_25',
#  '2006_hadgem2-es_rcp26_2',
#  '2006_hadgem2-es_rcp60_18',
#  '2006_hadgem2-es_rcp60_1',
#  '2006_hadgem2-es_rcp26_25',
#  '2006_hadgem2-es_rcp60_7',
#  '2006_miroc5_rcp26_21',
#  '2006_miroc5_rcp26_12',
#  '2006_miroc5_rcp26_16',
#  '2006_miroc5_rcp26_8',
#  '2006_miroc5_rcp26_19',
#  '2006_miroc5_rcp26_13',
#  '2006_miroc5_rcp26_0',
#  '2006_miroc5_rcp26_24',
#  '2006_miroc5_rcp26_25',
#  '2006_miroc5_rcp26_6',
#  '2006_miroc5_rcp26_13',
#  '2006_miroc5_rcp26_13',
#  '2006_miroc5_rcp26_8',
#  '2006_miroc5_rcp26_13',
#  '2006_miroc5_rcp26_0',
#  '2006_miroc5_rcp26_20',
#  '2006_miroc5_rcp26_9',
#  '2006_miroc5_rcp26_20',
#  '2006_miroc5_rcp26_10',
#  '2006_miroc5_rcp26_16',
#  '2006_miroc5_rcp26_2',
#  '2006_miroc5_rcp26_13',
#  '2006_miroc5_rcp26_12',
#  '2006_miroc5_rcp26_10',
#  '2006_miroc5_rcp26_23',
#  '2006_miroc5_rcp26_18',
#  '2006_miroc5_rcp26_4',
#  '2006_miroc5_rcp26_15',
#  '2006_miroc5_rcp26_15',
#  '2006_miroc5_rcp26_6',
#  '2006_miroc5_rcp26_8',
#  '2006_miroc5_rcp26_18',
#  '2006_miroc5_rcp26_2',
#  '2006_miroc5_rcp26_21',
#  '2006_miroc5_rcp26_24',
#  '2006_miroc5_rcp26_12',
#  '2006_miroc5_rcp26_8',
#  '2006_miroc5_rcp26_0',
#  '2006_miroc5_rcp26_0',
#  '2006_miroc5_rcp26_13',
#  '2006_miroc5_rcp26_2',
#  '2006_miroc5_rcp26_25',
#  '2006_miroc5_rcp26_1',
#  '2006_miroc5_rcp26_1',
#  '2006_miroc5_rcp26_12',
#  '2006_miroc5_rcp26_14',
#  '2006_miroc5_rcp26_17',
#  '2006_miroc5_rcp26_11',
#  '2006_miroc5_rcp26_9',
#  '2006_miroc5_rcp26_15',
#  '2007_gfdl-esm2m_rcp60_8',
#  '2007_gfdl-esm2m_rcp60_21',
#  '2007_gfdl-esm2m_rcp26_4',
#  '2007_gfdl-esm2m_rcp26_3',
#  '2007_gfdl-esm2m_rcp26_6',
#  '2007_gfdl-esm2m_rcp60_5',
#  '2007_gfdl-esm2m_rcp26_13',
#  '2007_gfdl-esm2m_rcp26_9',
#  '2007_gfdl-esm2m_rcp60_15',
#  '2007_gfdl-esm2m_rcp60_9',
#  '2007_gfdl-esm2m_rcp60_4',
#  '2007_gfdl-esm2m_rcp26_23',
#  '2007_gfdl-esm2m_rcp60_10',
#  '2007_gfdl-esm2m_rcp60_19',
#  '2007_gfdl-esm2m_rcp26_7',
#  '2007_gfdl-esm2m_rcp26_8',
#  '2007_gfdl-esm2m_rcp60_15',
#  '2007_gfdl-esm2m_rcp60_11',
#  '2007_gfdl-esm2m_rcp60_10',
#  '2007_gfdl-esm2m_rcp60_14',
#  '2007_gfdl-esm2m_rcp60_15',
#  '2007_gfdl-esm2m_rcp60_5',
#  '2007_gfdl-esm2m_rcp60_16',
#  '2007_gfdl-esm2m_rcp26_24',
#  '2007_gfdl-esm2m_rcp60_4',
#  '2007_gfdl-esm2m_rcp60_3',
#  '2007_gfdl-esm2m_rcp26_25',
#  '2007_gfdl-esm2m_rcp26_7',
#  '2007_gfdl-esm2m_rcp26_9',
#  '2007_gfdl-esm2m_rcp60_12',
#  '2007_gfdl-esm2m_rcp60_13',
#  '2007_gfdl-esm2m_rcp60_16',
#  '2007_gfdl-esm2m_rcp26_3',
#  '2007_gfdl-esm2m_rcp26_9',
#  '2007_gfdl-esm2m_rcp60_13',
#  '2007_gfdl-esm2m_rcp60_16',
#  '2007_gfdl-esm2m_rcp60_6',
#  '2007_gfdl-esm2m_rcp60_1',
#  '2007_gfdl-esm2m_rcp26_19',
#  '2007_gfdl-esm2m_rcp60_24',
#  '2007_gfdl-esm2m_rcp26_8',
#  '2007_gfdl-esm2m_rcp26_7',
#  '2007_gfdl-esm2m_rcp60_15',
#  '2007_gfdl-esm2m_rcp26_25',
#  '2007_gfdl-esm2m_rcp26_10',
#  '2007_gfdl-esm2m_rcp60_9',
#  '2007_gfdl-esm2m_rcp26_18',
#  '2007_gfdl-esm2m_rcp60_10',
#  '2007_gfdl-esm2m_rcp26_24',
#  '2007_gfdl-esm2m_rcp60_14',
#  '2007_hadgem2-es_rcp60_6',
#  '2007_hadgem2-es_rcp60_3',
#  '2007_hadgem2-es_rcp60_17',
#  '2007_hadgem2-es_rcp26_22',
#  '2007_hadgem2-es_rcp26_19',
#  '2007_hadgem2-es_rcp60_12',
#  '2007_hadgem2-es_rcp60_23',
#  '2007_hadgem2-es_rcp60_24',
#  '2007_hadgem2-es_rcp60_17',
#  '2007_hadgem2-es_rcp26_3',
#  '2007_hadgem2-es_rcp26_4',
#  '2007_hadgem2-es_rcp60_4',
#  '2007_hadgem2-es_rcp60_10',
#  '2007_hadgem2-es_rcp60_4',
#  '2007_hadgem2-es_rcp26_23',
#  '2007_hadgem2-es_rcp26_0',
#  '2007_hadgem2-es_rcp26_11',
#  '2007_hadgem2-es_rcp26_15',
#  '2007_hadgem2-es_rcp26_16',
#  '2007_hadgem2-es_rcp26_8',
#  '2007_hadgem2-es_rcp60_2',
#  '2007_hadgem2-es_rcp26_20',
#  '2007_hadgem2-es_rcp60_7',
#  '2007_hadgem2-es_rcp26_2',
#  '2007_hadgem2-es_rcp60_4',
#  '2007_hadgem2-es_rcp60_8',
#  '2007_hadgem2-es_rcp60_0',
#  '2007_hadgem2-es_rcp26_15',
#  '2007_hadgem2-es_rcp26_14',
#  '2007_hadgem2-es_rcp60_2',
#  '2007_hadgem2-es_rcp26_1',
#  '2007_hadgem2-es_rcp26_19',
#  '2007_hadgem2-es_rcp60_13',
#  '2007_hadgem2-es_rcp26_17',
#  '2007_hadgem2-es_rcp60_23',
#  '2007_hadgem2-es_rcp26_6',
#  '2007_hadgem2-es_rcp26_22',
#  '2007_hadgem2-es_rcp60_4',
#  '2007_hadgem2-es_rcp26_14',
#  '2007_hadgem2-es_rcp60_0',
#  '2007_hadgem2-es_rcp26_2',
#  '2007_hadgem2-es_rcp60_2',
#  '2007_hadgem2-es_rcp26_18',
#  '2007_hadgem2-es_rcp60_5',
#  '2007_hadgem2-es_rcp60_11',
#  '2007_hadgem2-es_rcp60_15',
#  '2007_hadgem2-es_rcp60_20',
#  '2007_hadgem2-es_rcp26_9',
#  '2007_hadgem2-es_rcp60_20',
#  '2007_hadgem2-es_rcp26_14',
#  '2007_miroc5_rcp26_13',
#  '2007_miroc5_rcp26_8',
#  '2007_miroc5_rcp26_13',
#  '2007_miroc5_rcp26_10',
#  '2007_miroc5_rcp26_12',
#  '2007_miroc5_rcp26_1',
#  '2007_miroc5_rcp26_8',
#  '2007_miroc5_rcp26_8',
#  '2007_miroc5_rcp26_17',
#  '2007_miroc5_rcp26_15',
#  '2007_miroc5_rcp26_4',
#  '2007_miroc5_rcp26_2',
#  '2007_miroc5_rcp26_15',
#  '2007_miroc5_rcp26_19',
#  '2007_miroc5_rcp26_19',
#  '2007_miroc5_rcp26_20',
#  '2007_miroc5_rcp26_16',
#  '2007_miroc5_rcp26_10',
#  '2007_miroc5_rcp26_16',
#  '2007_miroc5_rcp26_15',
#  '2007_miroc5_rcp26_24',
#  '2007_miroc5_rcp26_19',
#  '2007_miroc5_rcp26_7',
#  '2007_miroc5_rcp26_5',
#  '2007_miroc5_rcp26_1',
#  '2007_miroc5_rcp26_20',
#  '2007_miroc5_rcp26_6',
#  '2007_miroc5_rcp26_10',
#  '2007_miroc5_rcp26_24',
#  '2007_miroc5_rcp26_24',
#  '2007_miroc5_rcp26_11',
#  '2007_miroc5_rcp26_16',
#  '2007_miroc5_rcp26_4',
#  '2007_miroc5_rcp26_23',
#  '2007_miroc5_rcp26_2',
#  '2007_miroc5_rcp26_10',
#  '2007_miroc5_rcp26_6',
#  '2007_miroc5_rcp26_23',
#  '2007_miroc5_rcp26_17',
#  '2007_miroc5_rcp26_3',
#  '2007_miroc5_rcp26_24',
#  '2007_miroc5_rcp26_10',
#  '2007_miroc5_rcp26_11',
#  '2007_miroc5_rcp26_14',
#  '2007_miroc5_rcp26_2',
#  '2007_miroc5_rcp26_3',
#  '2007_miroc5_rcp26_23',
#  '2007_miroc5_rcp26_23',
#  '2007_miroc5_rcp26_19',
#  '2007_miroc5_rcp26_2',
#  '2008_gfdl-esm2m_rcp26_2',
#  '2008_gfdl-esm2m_rcp60_25',
#  '2008_gfdl-esm2m_rcp60_15',
#  '2008_gfdl-esm2m_rcp26_20',
#  '2008_gfdl-esm2m_rcp26_24',
#  '2008_gfdl-esm2m_rcp60_4',
#  '2008_gfdl-esm2m_rcp60_22',
#  '2008_gfdl-esm2m_rcp26_2',
#  '2008_gfdl-esm2m_rcp60_1',
#  '2008_gfdl-esm2m_rcp26_0',
#  '2008_gfdl-esm2m_rcp60_19',
#  '2008_gfdl-esm2m_rcp26_13',
#  '2008_gfdl-esm2m_rcp60_15',
#  '2008_gfdl-esm2m_rcp26_6',
#  '2008_gfdl-esm2m_rcp26_12',
#  '2008_gfdl-esm2m_rcp26_9',
#  '2008_gfdl-esm2m_rcp26_1',
#  '2008_gfdl-esm2m_rcp26_6',
#  '2008_gfdl-esm2m_rcp60_23',
#  '2008_gfdl-esm2m_rcp26_21',
#  '2008_gfdl-esm2m_rcp26_3',
#  '2008_gfdl-esm2m_rcp26_0',
#  '2008_gfdl-esm2m_rcp26_2',
#  '2008_gfdl-esm2m_rcp26_11',
#  '2008_gfdl-esm2m_rcp60_18',
#  '2008_gfdl-esm2m_rcp60_21',
#  '2008_gfdl-esm2m_rcp60_15',
#  '2008_gfdl-esm2m_rcp60_24',
#  '2008_gfdl-esm2m_rcp26_10',
#  '2008_gfdl-esm2m_rcp26_4',
#  '2008_gfdl-esm2m_rcp60_2',
#  '2008_gfdl-esm2m_rcp26_13',
#  '2008_gfdl-esm2m_rcp26_5',
#  '2008_gfdl-esm2m_rcp60_20',
#  '2008_gfdl-esm2m_rcp26_14',
#  '2008_gfdl-esm2m_rcp26_22',
#  '2008_gfdl-esm2m_rcp60_10',
#  '2008_gfdl-esm2m_rcp26_2',
#  '2008_gfdl-esm2m_rcp60_13',
#  '2008_gfdl-esm2m_rcp26_16',
#  '2008_gfdl-esm2m_rcp26_5',
#  '2008_gfdl-esm2m_rcp26_19',
#  '2008_gfdl-esm2m_rcp26_10',
#  '2008_gfdl-esm2m_rcp60_16',
#  '2008_gfdl-esm2m_rcp60_16',
#  '2008_gfdl-esm2m_rcp26_13',
#  '2008_gfdl-esm2m_rcp26_25',
#  '2008_gfdl-esm2m_rcp60_16',
#  '2008_gfdl-esm2m_rcp60_20',
#  '2008_gfdl-esm2m_rcp26_9',
#  '2008_hadgem2-es_rcp26_1',
#  '2008_hadgem2-es_rcp60_13',
#  '2008_hadgem2-es_rcp60_8',
#  '2008_hadgem2-es_rcp26_4',
#  '2008_hadgem2-es_rcp60_3',
#  '2008_hadgem2-es_rcp26_13',
#  '2008_hadgem2-es_rcp26_2',
#  '2008_hadgem2-es_rcp60_4',
#  '2008_hadgem2-es_rcp60_20',
#  '2008_hadgem2-es_rcp26_0',
#  '2008_hadgem2-es_rcp26_5',
#  '2008_hadgem2-es_rcp26_12',
#  '2008_hadgem2-es_rcp26_14',
#  '2008_hadgem2-es_rcp26_2',
#  '2008_hadgem2-es_rcp26_15',
#  '2008_hadgem2-es_rcp60_8',
#  '2008_hadgem2-es_rcp26_23',
#  '2008_hadgem2-es_rcp60_3',
#  '2008_hadgem2-es_rcp60_12',
#  '2008_hadgem2-es_rcp60_22',
#  '2008_hadgem2-es_rcp26_9',
#  '2008_hadgem2-es_rcp26_0',
#  '2008_hadgem2-es_rcp60_22',
#  '2008_hadgem2-es_rcp26_2',
#  '2008_hadgem2-es_rcp26_9',
#  '2008_hadgem2-es_rcp26_17',
#  '2008_hadgem2-es_rcp26_25',
#  '2008_hadgem2-es_rcp60_20',
#  '2008_hadgem2-es_rcp60_22',
#  '2008_hadgem2-es_rcp60_20',
#  '2008_hadgem2-es_rcp60_8',
#  '2008_hadgem2-es_rcp26_1',
#  '2008_hadgem2-es_rcp60_9',
#  '2008_hadgem2-es_rcp26_4',
#  '2008_hadgem2-es_rcp26_0',
#  '2008_hadgem2-es_rcp26_6',
#  '2008_hadgem2-es_rcp26_11',
#  '2008_hadgem2-es_rcp60_23',
#  '2008_hadgem2-es_rcp26_1',
#  '2008_hadgem2-es_rcp26_15',
#  '2008_hadgem2-es_rcp26_11',
#  '2008_hadgem2-es_rcp26_10',
#  '2008_hadgem2-es_rcp60_19',
#  '2008_hadgem2-es_rcp60_20',
#  '2008_hadgem2-es_rcp26_19',
#  '2008_hadgem2-es_rcp26_0',
#  '2008_hadgem2-es_rcp26_7',
#  '2008_hadgem2-es_rcp26_21',
#  '2008_hadgem2-es_rcp60_6',
#  '2008_hadgem2-es_rcp60_19',
#  '2008_miroc5_rcp26_20',
#  '2008_miroc5_rcp26_16',
#  '2008_miroc5_rcp26_12',
#  '2008_miroc5_rcp26_18',
#  '2008_miroc5_rcp26_11',
#  '2008_miroc5_rcp26_10',
#  '2008_miroc5_rcp26_14',
#  '2008_miroc5_rcp26_7',
#  '2008_miroc5_rcp26_0',
#  '2008_miroc5_rcp26_12',
#  '2008_miroc5_rcp26_4',
#  '2008_miroc5_rcp26_0',
#  '2008_miroc5_rcp26_11',
#  '2008_miroc5_rcp26_23',
#  '2008_miroc5_rcp26_5',
#  '2008_miroc5_rcp26_7',
#  '2008_miroc5_rcp26_5',
#  '2008_miroc5_rcp26_13',
#  '2008_miroc5_rcp26_20',
#  '2008_miroc5_rcp26_8',
#  '2008_miroc5_rcp26_23',
#  '2008_miroc5_rcp26_18',
#  '2008_miroc5_rcp26_19',
#  '2008_miroc5_rcp26_7',
#  '2008_miroc5_rcp26_2',
#  '2008_miroc5_rcp26_12',
#  '2008_miroc5_rcp26_11',
#  '2008_miroc5_rcp26_14',
#  '2008_miroc5_rcp26_25',
#  '2008_miroc5_rcp26_5',
#  '2008_miroc5_rcp26_25',
#  '2008_miroc5_rcp26_3',
#  '2008_miroc5_rcp26_5',
#  '2008_miroc5_rcp26_10',
#  '2008_miroc5_rcp26_7',
#  '2008_miroc5_rcp26_6',
#  '2008_miroc5_rcp26_9',
#  '2008_miroc5_rcp26_24',
#  '2008_miroc5_rcp26_23',
#  '2008_miroc5_rcp26_0',
#  '2008_miroc5_rcp26_19',
#  '2008_miroc5_rcp26_11',
#  '2008_miroc5_rcp26_20',
#  '2008_miroc5_rcp26_21',
#  '2008_miroc5_rcp26_20',
#  '2008_miroc5_rcp26_13',
#  '2008_miroc5_rcp26_20',
#  '2008_miroc5_rcp26_17',
#  '2008_miroc5_rcp26_14',
#  '2008_miroc5_rcp26_7',
#  '2009_gfdl-esm2m_rcp60_0',
#  '2009_gfdl-esm2m_rcp26_9',
#  '2009_gfdl-esm2m_rcp60_21',
#  '2009_gfdl-esm2m_rcp60_17',
#  '2009_gfdl-esm2m_rcp60_18',
#  '2009_gfdl-esm2m_rcp60_2',
#  '2009_gfdl-esm2m_rcp60_8',
#  '2009_gfdl-esm2m_rcp60_18',
#  '2009_gfdl-esm2m_rcp26_9',
#  '2009_gfdl-esm2m_rcp60_13',
#  '2009_gfdl-esm2m_rcp60_2',
#  '2009_gfdl-esm2m_rcp60_13',
#  '2009_gfdl-esm2m_rcp26_21',
#  '2009_gfdl-esm2m_rcp60_22',
#  '2009_gfdl-esm2m_rcp26_22',
#  '2009_gfdl-esm2m_rcp26_15',
#  '2009_gfdl-esm2m_rcp26_5',
#  '2009_gfdl-esm2m_rcp60_20',
#  '2009_gfdl-esm2m_rcp60_9',
#  '2009_gfdl-esm2m_rcp26_16',
#  '2009_gfdl-esm2m_rcp26_19',
#  '2009_gfdl-esm2m_rcp26_24',
#  '2009_gfdl-esm2m_rcp60_17',
#  '2009_gfdl-esm2m_rcp26_16',
#  '2009_gfdl-esm2m_rcp60_10',
#  '2009_gfdl-esm2m_rcp26_12',
#  '2009_gfdl-esm2m_rcp60_13',
#  '2009_gfdl-esm2m_rcp60_14',
#  '2009_gfdl-esm2m_rcp26_24',
#  '2009_gfdl-esm2m_rcp60_24',
#  '2009_gfdl-esm2m_rcp60_19',
#  '2009_gfdl-esm2m_rcp60_2',
#  '2009_gfdl-esm2m_rcp60_14',
#  '2009_gfdl-esm2m_rcp60_7',
#  '2009_gfdl-esm2m_rcp26_24',
#  '2009_gfdl-esm2m_rcp60_21',
#  '2009_gfdl-esm2m_rcp60_24',
#  '2009_gfdl-esm2m_rcp60_0',
#  '2009_gfdl-esm2m_rcp26_17',
#  '2009_gfdl-esm2m_rcp26_17',
#  '2009_gfdl-esm2m_rcp26_10',
#  '2009_gfdl-esm2m_rcp60_4',
#  '2009_gfdl-esm2m_rcp26_14',
#  '2009_gfdl-esm2m_rcp26_6',
#  '2009_gfdl-esm2m_rcp26_3',
#  '2009_gfdl-esm2m_rcp26_12',
#  '2009_gfdl-esm2m_rcp26_3',
#  '2009_gfdl-esm2m_rcp60_22',
#  '2009_gfdl-esm2m_rcp26_6',
#  '2009_gfdl-esm2m_rcp26_19',
#  '2009_hadgem2-es_rcp26_3',
#  '2009_hadgem2-es_rcp26_22',
#  '2009_hadgem2-es_rcp26_14',
#  '2009_hadgem2-es_rcp60_20',
#  '2009_hadgem2-es_rcp60_5',
#  '2009_hadgem2-es_rcp60_25',
#  '2009_hadgem2-es_rcp26_15',
#  '2009_hadgem2-es_rcp26_18',
#  '2009_hadgem2-es_rcp26_8',
#  '2009_hadgem2-es_rcp26_2',
#  '2009_hadgem2-es_rcp60_16',
#  '2009_hadgem2-es_rcp60_11',
#  '2009_hadgem2-es_rcp60_11',
#  '2009_hadgem2-es_rcp26_14',
#  '2009_hadgem2-es_rcp60_9',
#  '2009_hadgem2-es_rcp60_21',
#  '2009_hadgem2-es_rcp26_10',
#  '2009_hadgem2-es_rcp26_18',
#  '2009_hadgem2-es_rcp26_11',
#  '2009_hadgem2-es_rcp26_24',
#  '2009_hadgem2-es_rcp26_15',
#  '2009_hadgem2-es_rcp26_25',
#  '2009_hadgem2-es_rcp26_18',
#  '2009_hadgem2-es_rcp26_5',
#  '2009_hadgem2-es_rcp26_19',
#  '2009_hadgem2-es_rcp26_21',
#  '2009_hadgem2-es_rcp60_6',
#  '2009_hadgem2-es_rcp26_17',
#  '2009_hadgem2-es_rcp60_20',
#  '2009_hadgem2-es_rcp60_8',
#  '2009_hadgem2-es_rcp26_4',
#  '2009_hadgem2-es_rcp26_14',
#  '2009_hadgem2-es_rcp60_3',
#  '2009_hadgem2-es_rcp60_25',
#  '2009_hadgem2-es_rcp60_12',
#  '2009_hadgem2-es_rcp26_24',
#  '2009_hadgem2-es_rcp26_18',
#  '2009_hadgem2-es_rcp26_3',
#  '2009_hadgem2-es_rcp60_11',
#  '2009_hadgem2-es_rcp26_20',
#  '2009_hadgem2-es_rcp26_14',
#  '2009_hadgem2-es_rcp26_9',
#  '2009_hadgem2-es_rcp60_11',
#  '2009_hadgem2-es_rcp60_19',
#  '2009_hadgem2-es_rcp60_2',
#  '2009_hadgem2-es_rcp26_13',
#  '2009_hadgem2-es_rcp26_10',
#  '2009_hadgem2-es_rcp26_0',
#  '2009_hadgem2-es_rcp60_21',
#  '2009_hadgem2-es_rcp60_21',
#  '2009_miroc5_rcp26_21',
#  '2009_miroc5_rcp26_3',
#  '2009_miroc5_rcp26_13',
#  '2009_miroc5_rcp26_20',
#  '2009_miroc5_rcp26_12',
#  '2009_miroc5_rcp26_25',
#  '2009_miroc5_rcp26_19',
#  '2009_miroc5_rcp26_21',
#  '2009_miroc5_rcp26_25',
#  '2009_miroc5_rcp26_3',
#  '2009_miroc5_rcp26_12',
#  '2009_miroc5_rcp26_11',
#  '2009_miroc5_rcp26_17',
#  '2009_miroc5_rcp26_23',
#  '2009_miroc5_rcp26_4',
#  '2009_miroc5_rcp26_22',
#  '2009_miroc5_rcp26_20',
#  '2009_miroc5_rcp26_10',
#  '2009_miroc5_rcp26_8',
#  '2009_miroc5_rcp26_18',
#  '2009_miroc5_rcp26_21',
#  '2009_miroc5_rcp26_19',
#  '2009_miroc5_rcp26_18',
#  '2009_miroc5_rcp26_16',
#  '2009_miroc5_rcp26_9',
#  '2009_miroc5_rcp26_16',
#  '2009_miroc5_rcp26_20',
#  '2009_miroc5_rcp26_19',
#  '2009_miroc5_rcp26_20',
#  '2009_miroc5_rcp26_9',
#  '2009_miroc5_rcp26_13',
#  '2009_miroc5_rcp26_21',
#  '2009_miroc5_rcp26_16',
#  '2009_miroc5_rcp26_1',
#  '2009_miroc5_rcp26_4',
#  '2009_miroc5_rcp26_1',
#  '2009_miroc5_rcp26_8',
#  '2009_miroc5_rcp26_6',
#  '2009_miroc5_rcp26_18',
#  '2009_miroc5_rcp26_19',
#  '2009_miroc5_rcp26_21',
#  '2009_miroc5_rcp26_7',
#  '2009_miroc5_rcp26_1',
#  '2009_miroc5_rcp26_4',
#  '2009_miroc5_rcp26_12',
#  '2009_miroc5_rcp26_12',
#  '2009_miroc5_rcp26_23',
#  '2009_miroc5_rcp26_22',
#  '2009_miroc5_rcp26_4',
#  '2009_miroc5_rcp26_14',
#  '2010_gfdl-esm2m_rcp60_25',
#  '2010_gfdl-esm2m_rcp60_9',
#  '2010_gfdl-esm2m_rcp26_13',
#  '2010_gfdl-esm2m_rcp60_1',
#  '2010_gfdl-esm2m_rcp26_0',
#  '2010_gfdl-esm2m_rcp60_18',
#  '2010_gfdl-esm2m_rcp60_3',
#  '2010_gfdl-esm2m_rcp26_5',
#  '2010_gfdl-esm2m_rcp60_7',
#  '2010_gfdl-esm2m_rcp26_1',
#  '2010_gfdl-esm2m_rcp60_21',
#  '2010_gfdl-esm2m_rcp26_2',
#  '2010_gfdl-esm2m_rcp60_16',
#  '2010_gfdl-esm2m_rcp60_4',
#  '2010_gfdl-esm2m_rcp60_3',
#  '2010_gfdl-esm2m_rcp26_19',
#  '2010_gfdl-esm2m_rcp26_8',
#  '2010_gfdl-esm2m_rcp60_18',
#  '2010_gfdl-esm2m_rcp26_11',
#  '2010_gfdl-esm2m_rcp26_22',
#  '2010_gfdl-esm2m_rcp26_14',
#  '2010_gfdl-esm2m_rcp26_1',
#  '2010_gfdl-esm2m_rcp26_23',
#  '2010_gfdl-esm2m_rcp26_22',
#  '2010_gfdl-esm2m_rcp60_2',
#  '2010_gfdl-esm2m_rcp60_19',
#  '2010_gfdl-esm2m_rcp26_17',
#  '2010_gfdl-esm2m_rcp26_15',
#  '2010_gfdl-esm2m_rcp26_15',
#  '2010_gfdl-esm2m_rcp26_1',
#  '2010_gfdl-esm2m_rcp60_3',
#  '2010_gfdl-esm2m_rcp26_16',
#  '2010_gfdl-esm2m_rcp60_15',
#  '2010_gfdl-esm2m_rcp60_19',
#  '2010_gfdl-esm2m_rcp60_13',
#  '2010_gfdl-esm2m_rcp60_11',
#  '2010_gfdl-esm2m_rcp26_23',
#  '2010_gfdl-esm2m_rcp60_2',
#  '2010_gfdl-esm2m_rcp60_23',
#  '2010_gfdl-esm2m_rcp60_13',
#  '2010_gfdl-esm2m_rcp26_4',
#  '2010_gfdl-esm2m_rcp26_16',
#  '2010_gfdl-esm2m_rcp26_7',
#  '2010_gfdl-esm2m_rcp60_18',
#  '2010_gfdl-esm2m_rcp26_9',
#  '2010_gfdl-esm2m_rcp26_9',
#  '2010_gfdl-esm2m_rcp60_3',
#  '2010_gfdl-esm2m_rcp26_6',
#  '2010_gfdl-esm2m_rcp60_21',
#  '2010_gfdl-esm2m_rcp60_24',
#  '2010_hadgem2-es_rcp26_10',
#  '2010_hadgem2-es_rcp60_4',
#  '2010_hadgem2-es_rcp60_3',
#  '2010_hadgem2-es_rcp60_16',
#  '2010_hadgem2-es_rcp26_14',
#  '2010_hadgem2-es_rcp26_7',
#  '2010_hadgem2-es_rcp26_9',
#  '2010_hadgem2-es_rcp26_9',
#  '2010_hadgem2-es_rcp26_12',
#  '2010_hadgem2-es_rcp60_21',
#  '2010_hadgem2-es_rcp60_6',
#  '2010_hadgem2-es_rcp60_13',
#  '2010_hadgem2-es_rcp26_8',
#  '2010_hadgem2-es_rcp26_20',
#  '2010_hadgem2-es_rcp60_14',
#  '2010_hadgem2-es_rcp60_16',
#  '2010_hadgem2-es_rcp60_8',
#  '2010_hadgem2-es_rcp26_1',
#  '2010_hadgem2-es_rcp60_4',
#  '2010_hadgem2-es_rcp60_16',
#  '2010_hadgem2-es_rcp60_21',
#  '2010_hadgem2-es_rcp60_25',
#  '2010_hadgem2-es_rcp26_18',
#  '2010_hadgem2-es_rcp26_3',
#  '2010_hadgem2-es_rcp26_8',
#  '2010_hadgem2-es_rcp26_18',
#  '2010_hadgem2-es_rcp60_19',
#  '2010_hadgem2-es_rcp26_2',
#  '2010_hadgem2-es_rcp26_20',
#  '2010_hadgem2-es_rcp26_1',
#  '2010_hadgem2-es_rcp26_17',
#  '2010_hadgem2-es_rcp26_18',
#  '2010_hadgem2-es_rcp26_24',
#  '2010_hadgem2-es_rcp26_3',
#  '2010_hadgem2-es_rcp60_10',
#  '2010_hadgem2-es_rcp60_5',
#  '2010_hadgem2-es_rcp60_22',
#  '2010_hadgem2-es_rcp60_4',
#  '2010_hadgem2-es_rcp26_3',
#  '2010_hadgem2-es_rcp26_24',
#  '2010_hadgem2-es_rcp60_1',
#  '2010_hadgem2-es_rcp26_13',
#  '2010_hadgem2-es_rcp26_11',
#  '2010_hadgem2-es_rcp60_25',
#  '2010_hadgem2-es_rcp26_17',
#  '2010_hadgem2-es_rcp60_14',
#  '2010_hadgem2-es_rcp26_13',
#  '2010_hadgem2-es_rcp26_13',
#  '2010_hadgem2-es_rcp60_23',
#  '2010_hadgem2-es_rcp60_25',
#  '2010_miroc5_rcp26_5',
#  '2010_miroc5_rcp26_24',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_21',
#  '2010_miroc5_rcp26_3',
#  '2010_miroc5_rcp26_5',
#  '2010_miroc5_rcp26_10',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_2',
#  '2010_miroc5_rcp26_2',
#  '2010_miroc5_rcp26_5',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_13',
#  '2010_miroc5_rcp26_25',
#  '2010_miroc5_rcp26_19',
#  '2010_miroc5_rcp26_10',
#  '2010_miroc5_rcp26_24',
#  '2010_miroc5_rcp26_7',
#  '2010_miroc5_rcp26_3',
#  '2010_miroc5_rcp26_17',
#  '2010_miroc5_rcp26_23',
#  '2010_miroc5_rcp26_3',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_5',
#  '2010_miroc5_rcp26_1',
#  '2010_miroc5_rcp26_15',
#  '2010_miroc5_rcp26_21',
#  '2010_miroc5_rcp26_15',
#  '2010_miroc5_rcp26_1',
#  '2010_miroc5_rcp26_24',
#  '2010_miroc5_rcp26_1',
#  '2010_miroc5_rcp26_2',
#  '2010_miroc5_rcp26_18',
#  '2010_miroc5_rcp26_7',
#  '2010_miroc5_rcp26_11',
#  '2010_miroc5_rcp26_23',
#  '2010_miroc5_rcp26_22',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_24',
#  '2010_miroc5_rcp26_15',
#  '2010_miroc5_rcp26_13',
#  '2010_miroc5_rcp26_6',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_7',
#  '2010_miroc5_rcp26_25',
#  '2010_miroc5_rcp26_12',
#  '2010_miroc5_rcp26_10',
#  '2010_miroc5_rcp26_10',
#  '2010_miroc5_rcp26_6',
#  '2010_miroc5_rcp26_0',
#  '2011_gfdl-esm2m_rcp26_13',
#  '2011_gfdl-esm2m_rcp60_20',
#  '2011_gfdl-esm2m_rcp60_15',
#  '2011_gfdl-esm2m_rcp26_13',
#  '2011_gfdl-esm2m_rcp26_13',
#  '2011_gfdl-esm2m_rcp26_23',
#  '2011_gfdl-esm2m_rcp60_13',
#  '2011_gfdl-esm2m_rcp60_4',
#  '2011_gfdl-esm2m_rcp60_8',
#  '2011_gfdl-esm2m_rcp60_23',
#  '2011_gfdl-esm2m_rcp60_7',
#  '2011_gfdl-esm2m_rcp60_4',
#  '2011_gfdl-esm2m_rcp26_4',
#  '2011_gfdl-esm2m_rcp60_14',
#  '2011_gfdl-esm2m_rcp60_12',
#  '2011_gfdl-esm2m_rcp26_3',
#  '2011_gfdl-esm2m_rcp26_16',
#  '2011_gfdl-esm2m_rcp60_22',
#  '2011_gfdl-esm2m_rcp26_0',
#  '2011_gfdl-esm2m_rcp26_19',
#  '2011_gfdl-esm2m_rcp26_16',
#  '2011_gfdl-esm2m_rcp60_23',
#  '2011_gfdl-esm2m_rcp60_23',
#  '2011_gfdl-esm2m_rcp60_19',
#  '2011_gfdl-esm2m_rcp26_21',
#  '2011_gfdl-esm2m_rcp26_8',
#  '2011_gfdl-esm2m_rcp60_17',
#  '2011_gfdl-esm2m_rcp26_24',
#  '2011_gfdl-esm2m_rcp60_24',
#  '2011_gfdl-esm2m_rcp60_21',
#  '2011_gfdl-esm2m_rcp26_25',
#  '2011_gfdl-esm2m_rcp26_19',
#  '2011_gfdl-esm2m_rcp26_23',
#  '2011_gfdl-esm2m_rcp26_9',
#  '2011_gfdl-esm2m_rcp60_14',
#  '2011_gfdl-esm2m_rcp60_23',
#  '2011_gfdl-esm2m_rcp26_23',
#  '2011_gfdl-esm2m_rcp26_18',
#  '2011_gfdl-esm2m_rcp60_13',
#  '2011_gfdl-esm2m_rcp60_19',
#  '2011_gfdl-esm2m_rcp26_11',
#  '2011_gfdl-esm2m_rcp60_25',
#  '2011_gfdl-esm2m_rcp26_21',
#  '2011_gfdl-esm2m_rcp60_6',
#  '2011_gfdl-esm2m_rcp26_11',
#  '2011_gfdl-esm2m_rcp26_18',
#  '2011_gfdl-esm2m_rcp60_9',
#  '2011_gfdl-esm2m_rcp26_8',
#  '2011_gfdl-esm2m_rcp60_13',
#  '2011_gfdl-esm2m_rcp26_6',
#  '2011_hadgem2-es_rcp60_7',
#  '2011_hadgem2-es_rcp26_5',
#  '2011_hadgem2-es_rcp26_7',
#  '2011_hadgem2-es_rcp26_12',
#  '2011_hadgem2-es_rcp60_21',
#  '2011_hadgem2-es_rcp60_23',
#  '2011_hadgem2-es_rcp60_0',
#  '2011_hadgem2-es_rcp60_12',
#  '2011_hadgem2-es_rcp60_23',
#  '2011_hadgem2-es_rcp60_7',
#  '2011_hadgem2-es_rcp60_4',
#  '2011_hadgem2-es_rcp60_8',
#  '2011_hadgem2-es_rcp60_10',
#  '2011_hadgem2-es_rcp60_8',
#  '2011_hadgem2-es_rcp60_21',
#  '2011_hadgem2-es_rcp26_15',
#  '2011_hadgem2-es_rcp60_17',
#  '2011_hadgem2-es_rcp60_16',
#  '2011_hadgem2-es_rcp60_0',
#  '2011_hadgem2-es_rcp60_3',
#  '2011_hadgem2-es_rcp26_8',
#  '2011_hadgem2-es_rcp60_23',
#  '2011_hadgem2-es_rcp26_8',
#  '2011_hadgem2-es_rcp26_0',
#  '2011_hadgem2-es_rcp26_5',
#  '2011_hadgem2-es_rcp60_9',
#  '2011_hadgem2-es_rcp60_2',
#  '2011_hadgem2-es_rcp60_3',
#  '2011_hadgem2-es_rcp26_1',
#  '2011_hadgem2-es_rcp60_19',
#  '2011_hadgem2-es_rcp60_14',
#  '2011_hadgem2-es_rcp60_1',
#  '2011_hadgem2-es_rcp26_7',
#  '2011_hadgem2-es_rcp26_8',
#  '2011_hadgem2-es_rcp26_6',
#  '2011_hadgem2-es_rcp26_4',
#  '2011_hadgem2-es_rcp26_8',
#  '2011_hadgem2-es_rcp26_8',
#  '2011_hadgem2-es_rcp60_12',
#  '2011_hadgem2-es_rcp26_23',
#  '2011_hadgem2-es_rcp26_12',
#  '2011_hadgem2-es_rcp60_11',
#  '2011_hadgem2-es_rcp26_6',
#  '2011_hadgem2-es_rcp26_0',
#  '2011_hadgem2-es_rcp26_7',
#  '2011_hadgem2-es_rcp60_12',
#  '2011_hadgem2-es_rcp26_13',
#  '2011_hadgem2-es_rcp60_5',
#  '2011_hadgem2-es_rcp60_8',
#  '2011_hadgem2-es_rcp60_2',
#  '2011_miroc5_rcp26_23',
#  '2011_miroc5_rcp26_17',
#  '2011_miroc5_rcp26_12',
#  '2011_miroc5_rcp26_10',
#  '2011_miroc5_rcp26_2',
#  '2011_miroc5_rcp26_1',
#  '2011_miroc5_rcp26_16',
#  '2011_miroc5_rcp26_19',
#  '2011_miroc5_rcp26_11',
#  '2011_miroc5_rcp26_10',
#  '2011_miroc5_rcp26_1',
#  '2011_miroc5_rcp26_9',
#  '2011_miroc5_rcp26_15',
#  '2011_miroc5_rcp26_8',
#  '2011_miroc5_rcp26_14',
#  '2011_miroc5_rcp26_20',
#  '2011_miroc5_rcp26_21',
#  '2011_miroc5_rcp26_2',
#  '2011_miroc5_rcp26_2',
#  '2011_miroc5_rcp26_14',
#  '2011_miroc5_rcp26_5',
#  '2011_miroc5_rcp26_10',
#  '2011_miroc5_rcp26_7',
#  '2011_miroc5_rcp26_25',
#  '2011_miroc5_rcp26_15',
#  '2011_miroc5_rcp26_8',
#  '2011_miroc5_rcp26_25',
#  '2011_miroc5_rcp26_20',
#  '2011_miroc5_rcp26_3',
#  '2011_miroc5_rcp26_12',
#  '2011_miroc5_rcp26_21',
#  '2011_miroc5_rcp26_9',
#  '2011_miroc5_rcp26_24',
#  '2011_miroc5_rcp26_9',
#  '2011_miroc5_rcp26_19',
#  '2011_miroc5_rcp26_21',
#  '2011_miroc5_rcp26_7',
#  '2011_miroc5_rcp26_21',
#  '2011_miroc5_rcp26_21',
#  '2011_miroc5_rcp26_9',
#  '2011_miroc5_rcp26_7',
#  '2011_miroc5_rcp26_16',
#  '2011_miroc5_rcp26_12',
#  '2011_miroc5_rcp26_2',
#  '2011_miroc5_rcp26_18',
#  '2011_miroc5_rcp26_12',
#  '2011_miroc5_rcp26_1',
#  '2011_miroc5_rcp26_20',
#  '2011_miroc5_rcp26_16',
#  '2011_miroc5_rcp26_21',
#  '2012_gfdl-esm2m_rcp60_12',
#  '2012_gfdl-esm2m_rcp26_16',
#  '2012_gfdl-esm2m_rcp60_16',
#  '2012_gfdl-esm2m_rcp26_7',
#  '2012_gfdl-esm2m_rcp26_25',
#  '2012_gfdl-esm2m_rcp26_15',
#  '2012_gfdl-esm2m_rcp26_23',
#  '2012_gfdl-esm2m_rcp26_20',
#  '2012_gfdl-esm2m_rcp26_7',
#  '2012_gfdl-esm2m_rcp26_14',
#  '2012_gfdl-esm2m_rcp26_25',
#  '2012_gfdl-esm2m_rcp60_1',
#  '2012_gfdl-esm2m_rcp26_8',
#  '2012_gfdl-esm2m_rcp26_16',
#  '2012_gfdl-esm2m_rcp60_15',
#  '2012_gfdl-esm2m_rcp60_1',
#  '2012_gfdl-esm2m_rcp60_13',
#  '2012_gfdl-esm2m_rcp60_25',
#  '2012_gfdl-esm2m_rcp26_17',
#  '2012_gfdl-esm2m_rcp60_5',
#  '2012_gfdl-esm2m_rcp26_12',
#  '2012_gfdl-esm2m_rcp26_15',
#  '2012_gfdl-esm2m_rcp60_13',
#  '2012_gfdl-esm2m_rcp60_11',
#  '2012_gfdl-esm2m_rcp60_19',
#  '2012_gfdl-esm2m_rcp60_0',
#  '2012_gfdl-esm2m_rcp26_21',
#  '2012_gfdl-esm2m_rcp60_10',
#  '2012_gfdl-esm2m_rcp60_24',
#  '2012_gfdl-esm2m_rcp26_8',
#  '2012_gfdl-esm2m_rcp60_14',
#  '2012_gfdl-esm2m_rcp60_4',
#  '2012_gfdl-esm2m_rcp60_25',
#  '2012_gfdl-esm2m_rcp26_10',
#  '2012_gfdl-esm2m_rcp60_7',
#  '2012_gfdl-esm2m_rcp26_22',
#  '2012_gfdl-esm2m_rcp60_14',
#  '2012_gfdl-esm2m_rcp60_18',
#  '2012_gfdl-esm2m_rcp60_5',
#  '2012_gfdl-esm2m_rcp60_5',
#  '2012_gfdl-esm2m_rcp60_6',
#  '2012_gfdl-esm2m_rcp60_6',
#  '2012_gfdl-esm2m_rcp26_18',
#  '2012_gfdl-esm2m_rcp60_9',
#  '2012_gfdl-esm2m_rcp60_14',
#  '2012_gfdl-esm2m_rcp60_18',
#  '2012_gfdl-esm2m_rcp60_3',
#  '2012_gfdl-esm2m_rcp26_4',
#  '2012_gfdl-esm2m_rcp26_19',
#  '2012_gfdl-esm2m_rcp26_2',
#  '2012_hadgem2-es_rcp26_25',
#  '2012_hadgem2-es_rcp26_2',
#  '2012_hadgem2-es_rcp26_7',
#  '2012_hadgem2-es_rcp26_25',
#  '2012_hadgem2-es_rcp60_16',
#  '2012_hadgem2-es_rcp26_10',
#  '2012_hadgem2-es_rcp60_1',
#  '2012_hadgem2-es_rcp26_12',
#  '2012_hadgem2-es_rcp26_24',
#  '2012_hadgem2-es_rcp60_16',
#  '2012_hadgem2-es_rcp26_4',
#  '2012_hadgem2-es_rcp26_23',
#  '2012_hadgem2-es_rcp60_11',
#  '2012_hadgem2-es_rcp60_24',
#  '2012_hadgem2-es_rcp60_19',
#  '2012_hadgem2-es_rcp26_21',
#  '2012_hadgem2-es_rcp60_13',
#  '2012_hadgem2-es_rcp26_16',
#  '2012_hadgem2-es_rcp60_24',
#  '2012_hadgem2-es_rcp26_9',
#  '2012_hadgem2-es_rcp26_2',
#  '2012_hadgem2-es_rcp26_23',
#  '2012_hadgem2-es_rcp60_12',
#  '2012_hadgem2-es_rcp60_18',
#  '2012_hadgem2-es_rcp60_25',
#  '2012_hadgem2-es_rcp60_5',
#  '2012_hadgem2-es_rcp26_8',
#  '2012_hadgem2-es_rcp60_22',
#  '2012_hadgem2-es_rcp26_2',
#  '2012_hadgem2-es_rcp60_23',
#  '2012_hadgem2-es_rcp60_21',
#  '2012_hadgem2-es_rcp26_14',
#  '2012_hadgem2-es_rcp60_21',
#  '2012_hadgem2-es_rcp60_24',
#  '2012_hadgem2-es_rcp26_11',
#  '2012_hadgem2-es_rcp60_0',
#  '2012_hadgem2-es_rcp26_19',
#  '2012_hadgem2-es_rcp60_15',
#  '2012_hadgem2-es_rcp26_22',
#  '2012_hadgem2-es_rcp26_10',
#  '2012_hadgem2-es_rcp26_11',
#  '2012_hadgem2-es_rcp26_1',
#  '2012_hadgem2-es_rcp26_22',
#  '2012_hadgem2-es_rcp26_18',
#  '2012_hadgem2-es_rcp26_21',
#  '2012_hadgem2-es_rcp60_3',
#  '2012_hadgem2-es_rcp26_13',
#  '2012_hadgem2-es_rcp26_9',
#  '2012_hadgem2-es_rcp26_13',
#  '2012_hadgem2-es_rcp60_9',
#  ...]

# %%
import matplotlib.pyplot as plt
import geopandas as gpd


fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.1)

gdf = impact_combined['1']['pop'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>10]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='purple', markersize=0.0001,marker='.', label='Compound')
lgnd = ax.legend(loc="lower left", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [130]

#plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report/map_compound_pop.jpeg', dpi=1600)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd


fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.1)

gdf = impact_combined_ordered['1']['pop'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>10]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='purple', markersize=0.0001,marker='.', label='Compound ordered')
lgnd = ax.legend(loc="lower left", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [130]

#plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report/map_compound_pop.jpeg', dpi=1600)

# %%
gdf = impact_combined_ordered['1']['pop'][('TC','RF')]._build_exp().gdf
gdf2 = impact_combined['1']['pop'][('TC','RF')]._build_exp().gdf

# %%
mask
# Out:
# [0          False
#  1          False
#  2          False
#  3          False
#  4          False
#             ...
#  8847256    False
#  8847257    False
#  8847258    False
#  8847259    False
#  8847260    False
#  Name: value, Length: 8847261, dtype: bool]

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from matplotlib import colors


fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.1)

gdf = impact_combined_ordered['1']['pop'][('TC','RF')]._build_exp().gdf
gdf2 = impact_combined['1']['pop'][('TC','RF')]._build_exp().gdf
mask = gdf.value>10
gdf2 = gdf2[mask]
gdf = gdf[mask]

gdf['value'] = gdf['value'] -  gdf2['value']
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
divnorm=colors.TwoSlopeNorm(vmin=-15., vcenter=0., vmax=15)

gdf.plot('value', ax=ax, markersize=0.01,marker='.', label='Compound difference', legend=True, cmap='bwr', norm=divnorm)
# lgnd = ax.legend(loc="lower left", scatterpoints=1, fontsize=10)
# lgnd.legendHandles[0]._sizes = [130]

plt.savefig('/Users/szelie/Desktop/compare_map_compound_pop.jpeg', dpi=1600)

# %%
gdf = impact_combined_ordered['1']['pop'][('TC','RF')]._build_exp().gdf
gdf2 = impact_combined['1']['pop'][('TC','RF')]._build_exp().gdf
mask = gdf.value>10
gdf2 = gdf2[mask]
gdf = gdf[mask]

gpd_countries = gpd.sjoin(gdf, world, how="inner", op='within')
gpd_countries = gpd_countries.groupby('iso_a3').agg('sum').reset_index()
gpd_countries = gpd_countries.merge(world[['geometry','iso_a3']], how='inner', on='iso_a3')
gpd_countries = gpd.GeoDataFrame(gpd_countries, geometry=gpd_countries['geometry'])
# Out:
# /Users/szelie/miniconda3/envs/climada_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3318: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [131], line 7
#       4 gdf2 = gdf2[mask]
#       5 gdf = gdf[mask]
# ----> 7 gpd_countries = gpd.sjoin(gdf, world, how="inner", op='within')
#       8 gpd_countries = gpd_countries.groupby('iso_a3').agg('sum').reset_index()
#       9 gpd_countries = gpd_countries.merge(world[['geometry','iso_a3']], how='inner', on='iso_a3')
#
# File ~/miniconda3/envs/climada_env/lib/python3.8/site-packages/geopandas/tools/sjoin.py:122, in sjoin(left_df, right_df, how, predicate, lsuffix, rsuffix, **kwargs)
#     119     first = next(iter(kwargs.keys()))
#     120     raise TypeError(f"sjoin() got an unexpected keyword argument '{first}'")
# --> 122 _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     124 indices = _geom_predicate_query(left_df, right_df, predicate)
#     126 joined = _frame_join(indices, left_df, right_df, how, lsuffix, rsuffix)
#
# File ~/miniconda3/envs/climada_env/lib/python3.8/site-packages/geopandas/tools/sjoin.py:150, in _basic_checks(left_df, right_df, how, lsuffix, rsuffix)
#     132 """Checks the validity of join input parameters.
#     133
#     134 `how` must be one of the valid options.
#    (...)
#     147     right index suffix
#     148 """
#     149 if not isinstance(left_df, GeoDataFrame):
# --> 150     raise ValueError(
#     151         "'left_df' should be GeoDataFrame, got {}".format(type(left_df))
#     152     )
#     154 if not isinstance(right_df, GeoDataFrame):
#     155     raise ValueError(
#     156         "'right_df' should be GeoDataFrame, got {}".format(type(right_df))
#     157     )
#
# ValueError: 'left_df' should be GeoDataFrame, got <class 'pandas.core.frame.DataFrame'>

# %%
gpd_countries.plot('value', label='Compound difference', legend=True, cmap='bwr', norm=divnorm)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from matplotlib import colors


fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.1)

gdf = impact_combined_ordered['1']['assets'][('TC','RF')]._build_exp().gdf
gdf2 = impact_combined['1']['assets'][('TC','RF')]._build_exp().gdf
mask = gdf.value>1000
gdf2 = gdf2[mask]
gdf = gdf[mask]
gdf.merge(world)

gdf['value'] = gdf['value'] -  gdf2['value']
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
divnorm=colors.TwoSlopeNorm(vmin=-1500., vcenter=0., vmax=1500)

gdf.plot('value', ax=ax, markersize=0.002,marker='.', label='Compound difference', legend=True, cmap='bwr', norm=divnorm)
# lgnd = ax.legend(loc="lower left", scatterpoints=1, fontsize=10)
# lgnd.legendHandles[0]._sizes = [130]

plt.savefig('/Users/szelie/Desktop/compare_map_compound_pop.jpeg', dpi=1600)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd


fig, ax = plt.subplots(1, 1, figsize=(8, 4))


world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(color='whitesmoke', ax=ax)
world.boundary.plot(color='lightgrey', ax=ax, linewidth=0.1)


gdf = impacts_yearsets['1']['pop']['TC']._build_exp().gdf
gdf = gdf[gdf.value>100]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
gdf.plot(ax=ax, color='red', markersize=0.0001,marker='.', label='TC', alpha=0.3)

gdf = impacts_yearsets['1']['pop']['RF']._build_exp().gdf
gdf = gdf[gdf.value>100]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
gdf.plot(ax=ax, color='steelblue', markersize=0.0001,marker='.', label='RF', alpha=0.3)


gdf = impact_combined_ordered['1']['pop'][('TC','RF')]._build_exp().gdf
gdf = gdf[gdf.value>10]
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))
#gdf.crs = gdf.set_crs(epsg=4326)
gdf.plot(ax=ax, color='purple', markersize=0.0001,marker='.', label='Compound')
lgnd = ax.legend(loc="lower left", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [130]
lgnd.legendHandles[1]._sizes = [130]
lgnd.legendHandles[2]._sizes = [130]
plt.savefig('/Users/szelie/Dropbox/Applications/Overleaf/multi_risk_scientific_report/map_compound_pop.jpeg', dpi=1600)

# %%
impact_combined_ordered['1']['assets'][('TC','RF')].at_event[impact_combined_ordered['1']['assets'][('TC','RF')].event_name=='2007_gfdl-esm2m_rcp26_54']
# Out:
# array([], shape=(0, 5350), dtype=float64)

# %%
impact_combined_ordered['1']['assets'][('TC','RF')].aai_agg
# Out:
# 8065040365.180067

# %%
impact_combined['1']['assets'][('TC','RF')].aai_agg
# Out:
# 8885801692.969856

# %%
aai_single_hazard = {warming:{exp:{hazard: impacts_yearsets[warming][exp][hazard].aai_agg 
                                  for hazard in impacts_yearsets[warming][exp]} for 
                            exp in impacts_yearsets[warming]} for warming in impacts_yearsets}

aai_ord = {warming:{exp:{combi: impact_combined_ordered[warming][exp][combi].aai_agg 
                                  for combi in impact_combined_ordered[warming][exp]} for 
                            exp in impact_combined_ordered[warming]} for warming in impact_combined_ordered}

y100_single_hazard = {warming:{exp:{hazard: impacts_yearsets[warming][exp][hazard].calc_freq_curve().impact[impacts_yearsets[warming][exp][hazard].calc_freq_curve().return_per>100][0] 
                                  for hazard in impacts_yearsets[warming][exp]} for 
                            exp in impacts_yearsets[warming]} for warming in impacts_yearsets}

y100_aai_ord = {warming:{exp:{combi: impact_combined_ordered[warming][exp][combi].calc_freq_curve().impact[impact_combined_ordered[warming][exp][combi].calc_freq_curve().return_per>100][0] 
                                  for combi in impact_combined_ordered[warming][exp]} for 
                            exp in impact_combined_ordered[warming]} for warming in impact_combined_ordered}

y100_aai = {warming:{exp:{combi: impact_combined[warming][exp][combi].calc_freq_curve().impact[impact_combined[warming][exp][combi].calc_freq_curve().return_per>100][0] 
                                  for combi in impact_combined_ordered[warming][exp]} for 
                            exp in impact_combined_ordered[warming]} for warming in impact_combined_ordered}

aai = {warming:{exp:{combi: impact_combined[warming][exp][combi].aai_agg 
                                  for combi in impact_combined[warming][exp]} for 
                            exp in impact_combined_ordered[warming]} for warming in impact_combined_ordered}

# %%
rel_change_dict = {warming:{exp:{hazard: (np.median(aai_single_hazard[warming][exp][hazard]) - np.median(aai_single_hazard['1'][exp][hazard]))/np.median(aai_single_hazard['1'][exp][hazard])\
    for hazard in aai_single_hazard[warming][exp]} for exp in aai_single_hazard[warming]} \
    for warming in aai_single_hazard}   

rel_change_dict_combined = {warming:{exp:{hazard: (np.median(aai_ord[warming][exp][hazard]) - np.median(aai_ord['1'][exp][hazard]))/np.median(aai_ord['1'][exp][hazard])\
     for hazard in aai_ord[warming][exp]} for exp in aai_ord[warming]} \
     for warming in aai_ord}   

rel_change_dict_100y = {warming:{exp:{hazard: (np.median(y100_single_hazard[warming][exp][hazard]) - np.median(y100_single_hazard['1'][exp][hazard]))/np.median(y100_single_hazard['1'][exp][hazard])\
    for hazard in aai_single_hazard[warming][exp]} for exp in aai_single_hazard[warming]} \
    for warming in aai_single_hazard}   

rel_change_dict_combined_100y = {warming:{exp:{hazard: (np.median(y100_aai_ord[warming][exp][hazard]) - np.median(y100_aai_ord['1'][exp][hazard]))/np.median(y100_aai_ord['1'][exp][hazard])\
     for hazard in y100_aai_ord[warming][exp]} for exp in y100_aai_ord[warming]} \
     for warming in y100_aai_ord}

# %%
rel_diff_dict_combined_ord = {warming:{exp:{hazard: (np.median(aai[warming][exp][hazard]) - np.median(aai_ord[warming][exp][hazard]))/np.median(aai_ord[warming][exp][hazard])\
     for hazard in aai_ord[warming][exp]} for exp in aai_ord[warming]} \
     for warming in aai_ord}

# %%
rel_diff_dict_100y_ord = {warming:{exp:{hazard: (np.median(y100_aai[warming][exp][hazard]) - np.median(y100_aai_ord[warming][exp][hazard]))/np.median(y100_aai_ord[warming][exp][hazard])\
     for hazard in aai_ord[warming][exp]} for exp in aai_ord[warming]} \
     for warming in aai_ord}

# %%
rel_diff_dict_100y_ord
# Out:
# {'1': {'assets': {('TC', 'RF'): 0.12117818308383822},
#   'pop': {('TC', 'RF'): 0.33154444412058715}},
#  '2': {'assets': {('TC', 'RF'): -0.01922544316739781},
#   'pop': {('TC', 'RF'): 0.1858318526746658}}}

# %%
y100_aai_ord
# Out:
# {'1': {'assets': {('TC', 'RF'): 63191511260.03699},
#   'pop': {('TC', 'RF'): 29646138.29766746}},
#  '2': {'assets': {('TC', 'RF'): 86170249238.16853},
#   'pop': {('TC', 'RF'): 36722032.183664925}}}

# %%
rel_change_dict_combined
# Out:
# {'1': {'assets': {('TC', 'RF'): 0.0}, 'pop': {('TC', 'RF'): 0.0}},
#  '2': {'assets': {('TC', 'RF'): 0.38896602071891656},
#   'pop': {('TC', 'RF'): 0.2839506728599998}}}

# %%
rel_change_dict_combined_100y
# Out:
# {'1': {'assets': {('TC', 'RF'): 0.0}, 'pop': {('TC', 'RF'): 0.0}},
#  '2': {'assets': {('TC', 'RF'): 0.36363646825239887},
#   'pop': {('TC', 'RF'): 0.238678434774562}}}
